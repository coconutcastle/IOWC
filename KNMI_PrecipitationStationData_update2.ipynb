# %% [markdown]
# # get_time_series

# %% [markdown]
# # Collect KNMI Climate Explorer Time Series Data
#
# Written by Cecile Dai
#
# Uses data from https://climexp.knmi.nl/start.cgi?id=someone@somewhere
#
# Given a specified or list of coordinate longitude-latitude ranges, this script will collect all the raw monthly, annual cycle, and anomaly data for this range's values in the 20th Century Monthly Reanalysis fields. You may choose to download all this data in separate .csv files, as a single large one, or update an existing file written in the same format.

# %%
# Imports
import numpy as np
import pandas as pd
import sys

from bs4 import BeautifulSoup
from requests_html import HTMLSession
from pprint import pprint

from bs4 import BeautifulSoup
from pprint import pprint
from urllib.parse import urljoin
import webbrowser
import re

import requests
import datetime
import time

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Submit Coordinate Range
#
# This function creates and submits a form to https://climexp.knmi.nl/selectfield_rea.cgi?id=someone@somewhere with a specified latitude-longitude coordinate range for surface precipitation values.

# %%
# Function to create and submit form with selected latitude and longitude ranges
def get_series_submit(lat1, lat2, lon1, lon2, session, convert = 0, demand = 30):
    # the data body we want to submit when selecting the renanalysis field to analyze
    data_select = {}

    # Link to the KNMI page where you select the stations and data to view a monthly time series
    time_series_link = "https://climexp.knmi.nl/selectfield_rea.cgi?id=someone@somewhere"

    data_select["email"] = "someone@somewhere"
    data_select["field"] = "c3prate"

    series_url = urljoin(time_series_link, 'select.cgi')
    res_select = session.post(series_url, data=data_select)

    print(f"Response Status Code: {res_select.status_code}")

    if res_select.status_code != 200:
        print(f"Unable to access page.")
        return -1

    # the data body we want to submit when getting the time series for a particular coordinate range
    data_fields = {}

    data_fields["email"] = "someone@somewhere"
    data_fields["field"] = "c3prate"
    data_fields["maskmetadata"] = "" 
    data_fields["lat1"] = lat1
    data_fields["lat2"] = lat2
    data_fields["lon1"] = lon1
    data_fields["lon2"] = lon2
    data_fields["intertype"] = "nearest"
    data_fields["gridpoints"] = "false"
    data_fields["minfac"] = demand
    data_fields["masktype"] = "all"
    if convert == 0:
        data_fields["standardunits"] = ""
    else:
        data_fields["standardunits"] = "standardunits"

    fields_url = urljoin(series_url, 'get_index.cgi')
    res_fields = session.post(fields_url, data=data_fields)

    print(f"Response Status Code: {res_fields.status_code}")

    if res_fields.status_code != 200:
        print(f"Unable to access page.")
        return -1

    soup = BeautifulSoup(res_fields.content, "html.parser")

    divs = soup.find_all("div", {"class": "bijschrift"})

    return divs

# %% [markdown]
# ### Submit Coordinate Range and Process All Data
#
# This function creates and submits a form to https://climexp.knmi.nl/selectfield_rea.cgi?id=someone@somewhere with a specified latitude-longitude coordinate range as well as processes all the obtained raw, annual cycle, and anomaly data into dataframes. Using this function will allow you to skip over the different function calls but doing this will give you a higher change of missing potential errors. However, it is recommended over the separated approach, as it takes less time overall due to not needing to resubmit data to avoid timeouts.

# %%
def get_series_submit_to_dfs(lat1, lat2, lon1, lon2, session, convert = 0, demand = 30):
    # the data body we want to submit when selecting the renanalysis field to analyze
    data_select = {}

    # Link to the KNMI page where you select the stations and data to view a monthly time series
    time_series_link = "https://climexp.knmi.nl/selectfield_rea.cgi?id=someone@somewhere"

    data_select["email"] = "someone@somewhere"
    data_select["field"] = "c3prate"

    series_url = urljoin(time_series_link, 'select.cgi')
    res_select = session.post(series_url, data=data_select)

    print(f"Response Status Code: {res_select.status_code}")

    if res_select.status_code != 200:
        print(f"Unable to access field select page for lat1: {lat1}, lat2: {lat2}, lon1: {lon1}, lon2: {lon2}.")
        return -1

    # the data body we want to submit when getting the time series for a particular coordinate range
    data_fields = {}

    data_fields["email"] = "someone@somewhere"
    data_fields["field"] = "c3prate"
    data_fields["maskmetadata"] = "" 
    data_fields["lat1"] = lat1
    data_fields["lat2"] = lat2
    data_fields["lon1"] = lon1
    data_fields["lon2"] = lon2
    data_fields["intertype"] = "nearest"
    data_fields["gridpoints"] = "false"
    data_fields["minfac"] = demand
    data_fields["masktype"] = "all"
    if convert == 0:
        data_fields["standardunits"] = ""
    else:
        data_fields["standardunits"] = "standardunits"

    fields_url = urljoin(series_url, 'get_index.cgi')
    res_fields = session.post(fields_url, data=data_fields)

    print(f"Response Status Code: {res_fields.status_code}")

    if res_fields.status_code != 200:
        print(f"Unable to access page for lat1: {lat1}, lat2: {lat2}, lon1: {lon1}, lon2: {lon2}.")
        return -1

    soup = BeautifulSoup(res_fields.content, "html.parser")

    divs = soup.find_all("div", {"class": "bijschrift"})

    lat_min, lat_max, lon_min, lon_max, raw_data_link, annual_data_link, anom_data_link = get_series_links(divs)

    raw_data_link = "https://climexp.knmi.nl/" + raw_data_link
    annual_cycle_link = "https://climexp.knmi.nl/"+ annual_data_link
    anom_link = "https://climexp.knmi.nl/"+ anom_data_link

    raw_df = get_raw_df(raw_data_link, session)
    if raw_df.empty:
        print(f"Problem retrieving raw monthly data. Empty dataframe for lat1: {lat1}, lat2: {lat2}, lon1: {lon1}, lon2: {lon2}.")
    print(raw_df)
    
    annual_df = get_annual_df(annual_cycle_link, session)
    if annual_df.empty:
        print(f"Problem retrieving annual cycle data. Empty dataframe for lat1: {lat1}, lat2: {lat2}, lon1: {lon1}, lon2: {lon2}.")
    print(annual_df)
    
    anom_df = get_anom_df(anom_link, session)
    if anom_df.empty:
        print(f"Problem retrieving anomaly data. Empty dataframe for lat1: {lat1}, lat2: {lat2}, lon1: {lon1}, lon2: {lon2}")
    print(anom_df)

    return lat_min, lat_max, lon_min, lon_max, raw_df, annual_df, anom_df

# %% [markdown]
# ### Get Adjusted Coordinate Ranges and Data Links
#
# This function parses through the data received from the coordinate range submission to return the monthly raw, annual cycle, and anomaly data associated with that range. It also returns the adjusted coordinate ranges as the Monthly Reanalysis queries automatically adjust the user-submitted coordinate range into one fitting pre-determined coordinate boundaries.

# %%
def get_series_links(div_list):
    lat1, lat2, lon1, lon2 = -999, -999, -999, -999
    raw_data_link, annual_data_link, anom_data_link = "", "", ""

    for div in range(len(div_list)):
        # print(div_list[div])
        # print("")

        if div == 0:
            lons = re.search("lon=\s+(-?[0-9]+\.500\s+-?[0-9]+\.500),\s+lat=", str(div_list[0]))
            lats = re.search("lat=\s+(-?[0-9]+\.500\s+-?[0-9]+\.500),\n", str(div_list[0]))
            lons = lons.group(1).split()
            lats = lats.group(1).split()
            print(lons)
            print(lats)
            lat1 = lats[0]
            lat2 = lats[1]
            lon1 = lons[0]
            lon2 = lons[1]

            # raw_data_link = re.search("(data/ic3prate_-?[0-9]+\.?[0-9]+?-{1,2}[0-9]+\.?[0-9]+?E_-?[0-9]+\.?[0-9]+?-{1,2}[0-9]+\.?[0-9]+?N_n.dat)", str(div_list[0]))
            raw_data_link = re.search(">metadata</a>, <a href=(.*)>raw data<", str(div_list[0]))
            raw_data_link = raw_data_link.group(1).replace("\"", '')
            print(raw_data_link)
        elif div == 1:
            # annual_data_link = re.search("(data/ic3prate_-?[0-9]+--?[0-9]+E_-?[0-9]+--?[0-9]+N_n__yr.txt)", str(div_list[1]))
            annual_data_link = re.search(">pdf</a>,\s*\n<a href=(.*)>raw data<", str(div_list[1]))
            annual_data_link = annual_data_link.group(1).replace("\"", '')
            print(annual_data_link)
        elif div == 2:
            # anom_data_link = re.search("(data/ic3prate_-?[0-9]+--?[0-9]+E_-?[0-9]+--?[0-9]+N_n_a.txt)", str(div_list[2]))
            anom_data_link = re.search(">pdf</a>,\s*\n<a href=(.*)>raw data<", str(div_list[2]))
            anom_data_link = anom_data_link.group(1).replace("\"", '')
            print(anom_data_link)
        else:
            break

    return lat1, lat2, lon1, lon2, raw_data_link, annual_data_link, anom_data_link

# %% [markdown]
# ### Get Raw Monthly, Annual Cycle, and Anomaly Data
#
# These functions take links to the raw monthly, annual cycle, and anomaly data and return the information in separate dataframes.

# %%
def get_raw_df(raw_data_link, session):

    datapage = session.get(raw_data_link)
    # print(datapage)
        
    print("Response Status: {a}\n".format(a=datapage.status_code))
    if datapage.status_code != 200:
        return pd.DataFrame()

    # print(datapage.text)
    # raw_data_headers = ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    raw_data_list = []
    lines = datapage.text.split("\n")
    for line in lines:
        elements = line.split()
        # print(elements)
        if len(elements) == 0:
            continue
        if elements[0] == "#":
            continue
        else:
            # csvline = ','.join(elements)
            # print(csvline)
            raw_data_list.append(elements)
    raw_data_df = pd.DataFrame(raw_data_list, columns=['Year', 'January', 'February', 'March', 'April', 'May', 'June',
                                                       'July', 'August', 'September', 'October', 'November',
                                                       'December'])
    # print(raw_data_df)
    # print("confirm")
    return raw_data_df


def get_annual_df(annual_cycle_link, session):

    annualpage = session.get(annual_cycle_link)

    print("Response Status: {a}\n".format(a=annualpage.status_code))
    if annualpage.status_code != 200:
        return pd.DataFrame()

    # annualpage = requests.get(annual_cycle_link)
    # print(annualpage.text)
    raw_data_yr_list = []
    lines = annualpage.text.split("\n")
    for line in lines:
        elements = line.split()
        if len(elements) == 0:
            continue
        if elements[0] == "#":
            continue
        else:
            monthint = re.findall('2{1}0{3,4}([1-9]{1}[012]?)01', elements[0])
            # print(monthint)
            if monthint and len(monthint) != 0:
                elements[0] = datetime.date(1900, int(monthint[0]), 1).strftime('%B')
                # print(len(elements))
                # print(elements)
                raw_data_yr_list.append(elements)
    raw_data_yr_df = pd.DataFrame(raw_data_yr_list, columns=['Month', 'Mean', '2.5%', '17%', '50%', '83%', '97.5%'])
    # print(raw_data_yr_df)
    # print("confirm")
    return raw_data_yr_df


def get_anom_df(anom_link, session):

    anompage = session.get(anom_link)

    print("Response Status: {a}\n".format(a=anompage.status_code))
    if anompage.status_code != 200:
        return pd.DataFrame()

    # anompage = requests.get(anom_link)
    # print(anompage.text)
    raw_data_anom_dict = {}
    raw_data_anom_list = []
    lines = anompage.text.split("\n")
    for line in lines:
        elements = line.split()
        if len(elements) == 0:
            continue
        if elements[0] == "#":
            continue
        else:
            date = re.findall('([0-9]{4})\.([0-9]{4})', elements[0])
            if date and len(date[0]) == 2:
                # Not all months included
                if date[0][0] not in raw_data_anom_dict:
                    # Initialize with invalid numbers
                    raw_data_anom_dict[date[0][0]] = {'January': '-999.9', 'February': '-999.9', 'March': '-999.9',
                                                      'April': '-999.9', 'May': '-999.9', 'June': '-999.9',
                                                      'July': '-999.9', 'August': '-999.9', 'September': '-999.9',
                                                      'October': '-999.9', 'November': '-999.9', 'December': '-999.9'}
                monthint = round((float('0.' + date[0][1]) * 12) + 1)   # Multiply by 12 to get the actual month integer
                monthint = datetime.date(1900, int(monthint), 1).strftime('%B')
                raw_data_anom_dict[date[0][0]][monthint] = elements[1]
    for key in raw_data_anom_dict:
        dlist = []
        dlist.append(key)
        for d in raw_data_anom_dict[key]:
            dlist.append(raw_data_anom_dict[key][d])
        raw_data_anom_list.append(dlist)
    raw_data_anom_df = pd.DataFrame(raw_data_anom_list, columns=['Year', 'January', 'February', 'March', 'April', 'May',
                                                                 'June', 'July', 'August', 'September', 'October',
                                                                 'November', 'December'])
    return raw_data_anom_df

# %% [markdown]
# ### Dataframe Compiler
#
# This function compiles a list of dataframes of the same format into a single large dataframe, adding its associated coordinate range as new identifier columns.

# %%
# Reformats all the dataframes in the input list and adds station codes. Note that this assumes that everything was processed in the same order.
def concat_format_wide(df_list, lat_min_list, lat_max_list, lon_min_list, lon_max_list, existing_file=''):
    full_list_df = []
    dfs = []    #list of dataframes to concatenate
    for box in range(len(df_list)):
        lat_mins = [lat_min_list[box] for row in range(df_list[box].shape[0])]
        lat_maxes = [lat_max_list[box] for row in range(df_list[box].shape[0])]
        lon_mins = [lon_min_list[box] for row in range(df_list[box].shape[0])]
        lon_maxes = [lon_max_list[box] for row in range(df_list[box].shape[0])]
        new_df = df_list[box].copy()
        new_df.insert(0, 'Minimum Latitude', lat_mins)
        new_df.insert(1, 'Maximum Latitude', lat_maxes)
        new_df.insert(2, 'Minimum Longitude', lon_mins)
        new_df.insert(3, 'Maximum Longitude', lon_maxes)
        dfs.append(new_df)
    if len(existing_file) != 0:
        existing_df = pd.read_csv(existing_file)
        # Check if this data already exists in the file, remove from list to be concatenated if so
        for coord in range(len(df_list)):
            if not existing_df.loc(lat_min_list[coord]).loc(lat_max_list[coord]).loc(lon_min_list[coord].loc(lon_max_list[coord])).empty:
                dfs.remove(dfs[box])
        dfs.append(existing_df)
    full_list_df = pd.concat(dfs)
    return full_list_df
    # print(full_raw_list)

# %% [markdown]
# # Run Functions
# Run the functions on the data to analyze, create and/or update the files with the desired data.
#
# Upload Coordinate Boxes to Analyze

# %%
coordinates = pd.read_csv("for_analysis/BoxCoordinates.csv")
print(coordinates)
# Out:
#      Lat min  Lat max  Long min  Long max
# 0        2.5      3.5      29.5      30.5
# 1        2.5      3.5      30.5      31.5
# 2        2.5      3.5      31.5      32.5
# 3        2.5      3.5      32.5      33.5
# 4        2.5      3.5      33.5      34.5
# ..       ...      ...       ...       ...
# 122     -9.5     -8.5      32.5      33.5
# 123     -9.5     -8.5      33.5      34.5
# 124     -9.5     -8.5      34.5      35.5
# 125     -9.5     -8.5      35.5      36.5
# 126     -9.5     -8.5      36.5      37.5
#
# [127 rows x 4 columns]

# %%
# initialize HTTP session so data/cookies are persisted
session = HTMLSession()
series_div_list = []

# %% [markdown]
# ### Run Separately
#
# Run the blocks below to submit data, process responses, and get dataframes in separate function calls. This will let you view the return values of each function in between the functions and potentially catch problems more easily as well as validate the responses. However, there may be computational difficulties or timeouts.

# %%
for index in range(coordinates.shape[0]):
    lat1 = coordinates.iloc[index]["Lat min"]
    lat2 = coordinates.iloc[index]["Lat max"]
    lon1 = coordinates.iloc[index]["Long min"]
    lon2 = coordinates.iloc[index]["Long max"]

    print(f"Processing page {index + 1} of {coordinates.shape[0]}: lat1: {lat1}, lat2: {lat2}, lon1: {lon1}, lon2: {lon2}")

    series_divs = (get_series_submit(lat1, lat2, lon1, lon2, session))

    if series_divs == -1:
        print(f"Bad response. Ending loop on index {index}...")
        break
    else:
        print("Success")
        series_div_list.append(series_divs)
    
print("Done getting coordinate box data.")
# Out:
# Processing page 1 of 127: lat1: 2.5, lat2: 3.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 2 of 127: lat1: 2.5, lat2: 3.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 3 of 127: lat1: 2.5, lat2: 3.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 4 of 127: lat1: 2.5, lat2: 3.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 5 of 127: lat1: 2.5, lat2: 3.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 6 of 127: lat1: 2.5, lat2: 3.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 7 of 127: lat1: 2.5, lat2: 3.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 8 of 127: lat1: 2.5, lat2: 3.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 9 of 127: lat1: 1.5, lat2: 2.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 10 of 127: lat1: 1.5, lat2: 2.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 11 of 127: lat1: 1.5, lat2: 2.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 12 of 127: lat1: 1.5, lat2: 2.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 13 of 127: lat1: 1.5, lat2: 2.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 14 of 127: lat1: 1.5, lat2: 2.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 15 of 127: lat1: 1.5, lat2: 2.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 16 of 127: lat1: 1.5, lat2: 2.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 17 of 127: lat1: 0.5, lat2: 1.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 18 of 127: lat1: 0.5, lat2: 1.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 19 of 127: lat1: 0.5, lat2: 1.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 20 of 127: lat1: 0.5, lat2: 1.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 21 of 127: lat1: 0.5, lat2: 1.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 22 of 127: lat1: 0.5, lat2: 1.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 23 of 127: lat1: 0.5, lat2: 1.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 24 of 127: lat1: 0.5, lat2: 1.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 25 of 127: lat1: 0.5, lat2: 1.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 26 of 127: lat1: -0.5, lat2: 0.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 27 of 127: lat1: -0.5, lat2: 0.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 28 of 127: lat1: -0.5, lat2: 0.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 29 of 127: lat1: -0.5, lat2: 0.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 30 of 127: lat1: -0.5, lat2: 0.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 31 of 127: lat1: -0.5, lat2: 0.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 32 of 127: lat1: -0.5, lat2: 0.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 33 of 127: lat1: -0.5, lat2: 0.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 34 of 127: lat1: -0.5, lat2: 0.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 35 of 127: lat1: -1.5, lat2: -0.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 36 of 127: lat1: -1.5, lat2: -0.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 37 of 127: lat1: -1.5, lat2: -0.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 38 of 127: lat1: -1.5, lat2: -0.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 39 of 127: lat1: -1.5, lat2: -0.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 40 of 127: lat1: -1.5, lat2: -0.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 41 of 127: lat1: -1.5, lat2: -0.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 42 of 127: lat1: -1.5, lat2: -0.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 43 of 127: lat1: -1.5, lat2: -0.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 44 of 127: lat1: -2.5, lat2: -1.5, lon1: 27.5, lon2: 28.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 45 of 127: lat1: -2.5, lat2: -1.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 46 of 127: lat1: -2.5, lat2: -1.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 47 of 127: lat1: -2.5, lat2: -1.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 48 of 127: lat1: -2.5, lat2: -1.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 49 of 127: lat1: -2.5, lat2: -1.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 50 of 127: lat1: -2.5, lat2: -1.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 51 of 127: lat1: -2.5, lat2: -1.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 52 of 127: lat1: -2.5, lat2: -1.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 53 of 127: lat1: -2.5, lat2: -1.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 54 of 127: lat1: -3.5, lat2: -2.5, lon1: 27.5, lon2: 28.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 55 of 127: lat1: -3.5, lat2: -2.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 56 of 127: lat1: -3.5, lat2: -2.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 57 of 127: lat1: -3.5, lat2: -2.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 58 of 127: lat1: -3.5, lat2: -2.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 59 of 127: lat1: -3.5, lat2: -2.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 60 of 127: lat1: -3.5, lat2: -2.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 61 of 127: lat1: -3.5, lat2: -2.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 62 of 127: lat1: -3.5, lat2: -2.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 63 of 127: lat1: -3.5, lat2: -2.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 64 of 127: lat1: -4.5, lat2: -3.5, lon1: 27.5, lon2: 28.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 65 of 127: lat1: -4.5, lat2: -3.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 66 of 127: lat1: -4.5, lat2: -3.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 67 of 127: lat1: -4.5, lat2: -3.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 68 of 127: lat1: -4.5, lat2: -3.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 69 of 127: lat1: -4.5, lat2: -3.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 70 of 127: lat1: -4.5, lat2: -3.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 71 of 127: lat1: -4.5, lat2: -3.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 72 of 127: lat1: -4.5, lat2: -3.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 73 of 127: lat1: -4.5, lat2: -3.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 74 of 127: lat1: -5.5, lat2: -4.5, lon1: 24.5, lon2: 25.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 75 of 127: lat1: -5.5, lat2: -4.5, lon1: 25.5, lon2: 26.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 76 of 127: lat1: -5.5, lat2: -4.5, lon1: 26.5, lon2: 27.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 77 of 127: lat1: -5.5, lat2: -4.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 78 of 127: lat1: -5.5, lat2: -4.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 79 of 127: lat1: -5.5, lat2: -4.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 80 of 127: lat1: -5.5, lat2: -4.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 81 of 127: lat1: -5.5, lat2: -4.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 82 of 127: lat1: -5.5, lat2: -4.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 83 of 127: lat1: -5.5, lat2: -4.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 84 of 127: lat1: -5.5, lat2: -4.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 85 of 127: lat1: -5.5, lat2: -4.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 86 of 127: lat1: -6.5, lat2: -5.5, lon1: 24.5, lon2: 25.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 87 of 127: lat1: -6.5, lat2: -5.5, lon1: 25.5, lon2: 26.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 88 of 127: lat1: -6.5, lat2: -5.5, lon1: 26.5, lon2: 27.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 89 of 127: lat1: -6.5, lat2: -5.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 90 of 127: lat1: -6.5, lat2: -5.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 91 of 127: lat1: -6.5, lat2: -5.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 92 of 127: lat1: -6.5, lat2: -5.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 93 of 127: lat1: -6.5, lat2: -5.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 94 of 127: lat1: -6.5, lat2: -5.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 95 of 127: lat1: -6.5, lat2: -5.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 96 of 127: lat1: -6.5, lat2: -5.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 97 of 127: lat1: -6.5, lat2: -5.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 98 of 127: lat1: -7.5, lat2: -6.5, lon1: 26.5, lon2: 27.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 99 of 127: lat1: -7.5, lat2: -6.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 100 of 127: lat1: -7.5, lat2: -6.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 101 of 127: lat1: -7.5, lat2: -6.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 102 of 127: lat1: -7.5, lat2: -6.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 103 of 127: lat1: -7.5, lat2: -6.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 104 of 127: lat1: -7.5, lat2: -6.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 105 of 127: lat1: -7.5, lat2: -6.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 106 of 127: lat1: -7.5, lat2: -6.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 107 of 127: lat1: -7.5, lat2: -6.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 108 of 127: lat1: -8.5, lat2: -7.5, lon1: 26.5, lon2: 27.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 109 of 127: lat1: -8.5, lat2: -7.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 110 of 127: lat1: -8.5, lat2: -7.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 111 of 127: lat1: -8.5, lat2: -7.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 112 of 127: lat1: -8.5, lat2: -7.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 113 of 127: lat1: -8.5, lat2: -7.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 114 of 127: lat1: -8.5, lat2: -7.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 115 of 127: lat1: -8.5, lat2: -7.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 116 of 127: lat1: -8.5, lat2: -7.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 117 of 127: lat1: -8.5, lat2: -7.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 118 of 127: lat1: -9.5, lat2: -8.5, lon1: 26.5, lon2: 27.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 119 of 127: lat1: -9.5, lat2: -8.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 120 of 127: lat1: -9.5, lat2: -8.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 121 of 127: lat1: -9.5, lat2: -8.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 122 of 127: lat1: -9.5, lat2: -8.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 123 of 127: lat1: -9.5, lat2: -8.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 124 of 127: lat1: -9.5, lat2: -8.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 125 of 127: lat1: -9.5, lat2: -8.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 126 of 127: lat1: -9.5, lat2: -8.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Processing page 127 of 127: lat1: -9.5, lat2: -8.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# Success
# Done getting coorinate box data.

# %%
lat_mins = []
lat_maxes = []
lon_mins = []
lon_maxes = []
raw_data_link_list = []
annual_data_link_list = []
anom_data_link_list = []

for index in range(coordinates.shape[0]):

    lat_min, lat_max, lon_min, lon_max, raw_data_link, annual_data_link, anom_data_link = get_series_links(series_div_list[index])
                                                                                                           
    if lat_min or lat_max or lon_min or lon_max == -999:
        print(f"Bad response. Ending loop on index {index}...")
        break
    if len(raw_data_link) or len(annual_data_link) or len(anom_data_link) == 0:
        print(f"Bad response. Ending loop on index {index}...")
        break
    else:
        lat_mins.append(lat_min)
        lat_maxes.append(lat_max)
        lon_mins.append(lon_min)
        lon_maxes.append(lon_maxes)
        raw_data_link_list.append(raw_data_link)
        annual_data_link_list.append(annual_data_link)
        anom_data_link_list.append(anom_data_link)
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 9 in <module>
# NameError: name 'coordinates' is not defined

# %%
all_raw_df_list = []
all_annual_df_list = []
all_anom_df_list = []

# %%
for index in range(len(raw_data_link_list)): #all_stations.shape[0]
    raw_data_link = "https://climexp.knmi.nl/" + raw_data_link_list[index]
    annual_cycle_link = "https://climexp.knmi.nl/"+ annual_data_link_list[index]
    anom_link = "https://climexp.knmi.nl/"+ anom_data_link_list[index]

    print(f'Now processing coordinate box {index} of {len(raw_data_link_list)}...')
    print(raw_data_link)
    print(annual_cycle_link)
    print(anom_link)
    print('')

    raw_df = get_raw_df(raw_data_link, session)
    if raw_df.empty:
        print(f"Problem retrieving raw monthly data. Ending on loop {index}...")
        break
    print(raw_df)
    all_raw_df_list.append(raw_df)
    
    annual_df = get_annual_df(annual_cycle_link, session)
    if annual_df.empty:
        print(f"Problem retrieving annual cycle data. Ending on loop {index}...")
        break
    print(annual_df)
    all_annual_df_list.append(annual_df)
    
    anom_df = get_anom_df(anom_link, session)
    if anom_df.empty:
        print(f"Problem retrieving anomaly data. Ending on loop {index}...")
        break
    print(anom_df)
    all_anom_df_list.append(anom_df)

print("Done retrieving data from all stations.")
print(f"Raw DF List: {len(all_raw_df_list)} of {len(raw_data_link_list)}\nAnnual Cycle DF List: {len(all_annual_df_list)} of {len(raw_data_link_list)}\nAnomaly DF List: {len(all_anom_df_list)} of {len(raw_data_link_list)}")
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
# NameError: name 'raw_data_link_list' is not defined

# %% [markdown]
# ### Run Together (recommended)
#
# Alternatively, run the blocks below to get all the data frames from website submission in one function call.

# %%
lat_mins = []
lat_maxes = []
lon_mins = []
lon_maxes = []

all_raw_df_list = []
all_annual_df_list = []
all_anom_df_list = []

# %%
for index in range(coordinates.shape[0]):
    lat1 = coordinates.iloc[index]["Lat min"]
    lat2 = coordinates.iloc[index]["Lat max"]
    lon1 = coordinates.iloc[index]["Long min"]
    lon2 = coordinates.iloc[index]["Long max"]

    print("\n=====================================================================")
    print(f"Processing page {index + 1} of {coordinates.shape[0]}: lat1: {lat1}, lat2: {lat2}, lon1: {lon1}, lon2: {lon2}")

    lat_min, lat_max, lon_min, lon_max, raw_data_df, annual_df, anom_df = get_series_submit_to_dfs(lat1, lat2, lon1, lon2, session)

    print(f"lat_min: {lat_min}, lat_max: {lat_max}, lon_min: {lon_min}, lon_max: {lon_max}, raw_data_df: {raw_data_df.shape}, annual_df: {annual_df.shape}, anom_df: {anom_df.shape}")

    if lat_min == -999 or lat_max == -999 or lon_min == -999 or lon_max == -999:
        print(f"Bad response. Ending loop on index {index}...")
        break
    if raw_data_df.empty or annual_df.empty or anom_df.empty:
        print(f"Bad response. Ending loop on index {index}...")
        break
    else:
        lat_mins.append(lat_min)
        lat_maxes.append(lat_max)
        lon_mins.append(lon_min)
        lon_maxes.append(lon_max)
        all_raw_df_list.append(raw_data_df)
        all_annual_df_list.append(annual_df)
        all_anom_df_list.append(anom_df)

    print(f"Successfully processed coordinate box {index + 1} of {coordinates.shape[0]}")

print("Done processing all coordinate boxes.")
# Out:
# =====================================================================
# Processing page 1 of 127: lat1: 2.5, lat2: 3.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Response Status Code: 200
# ['29.500', '30.500']
# ['2.500', '3.500']
# data/ic3prate_29.5-30.5E_2.5-3.5N_n.dat
# data/ic3prate_29.5-30.5E_2.5-3.5N_n__yr.txt
# data/ic3prate_29.5-30.5E_2.5-3.5N_n_a.txt
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  0.9459678E-05  0.1894828E-04  0.7164517E-04  0.1020292E-03
# 1    1837  0.1689919E-04  0.3032589E-04  0.8032661E-04  0.1148792E-03
# 2    1838  0.1727419E-04  0.3991518E-04  0.8220968E-04  0.1119792E-03
# 3    1839  0.1911290E-04  0.2697768E-04  0.7022177E-04  0.1225333E-03
# 4    1840  0.1995564E-04  0.1775431E-04  0.7165727E-04  0.1119583E-03
# ..    ...            ...            ...            ...            ...
# 175  2011  0.8358870E-05  0.1036607E-04  0.2770968E-04  0.6302082E-04
# 176  2012  0.3068548E-05  0.1193104E-04  0.3188306E-04  0.8372917E-04
# 177  2013  0.1506452E-04  0.1697768E-04  0.6724193E-04  0.9539166E-04
# 178  2014  0.1425403E-04  0.2108482E-04  0.9043547E-04  0.1151542E-03
# 179  2015  0.3616935E-05  0.1418304E-04  0.5000000E-04  0.1133875E-03
#
#                May           June           July         August  \
# 0    0.1022782E-03  0.6811249E-04  0.5208871E-04  0.8679436E-04
# 1    0.1263790E-03  0.7709583E-04  0.6755242E-04  0.9494356E-04
# 2    0.1086613E-03  0.8036250E-04  0.6890322E-04  0.8293547E-04
# 3    0.1028911E-03  0.7647084E-04  0.7093145E-04  0.9277822E-04
# 4    0.1091169E-03  0.8166666E-04  0.6290323E-04  0.8976209E-04
# ..             ...            ...            ...            ...
# 175  0.8968952E-04  0.7449999E-04  0.5724192E-04  0.6692743E-04
# 176  0.1182500E-03  0.7877083E-04  0.4497580E-04  0.5774597E-04
# 177  0.1114758E-03  0.4783333E-04  0.5354033E-04  0.3507259E-04
# 178  0.1227097E-03  0.8277083E-04  0.4489517E-04  0.7591533E-04
# 179  0.1275605E-03  0.7192917E-04  0.4068145E-04  0.5241532E-04
#
#          September        October       November       December
# 0    0.1211292E-03  0.1284637E-03  0.7446668E-04  0.2822984E-04
# 1    0.1167792E-03  0.1322137E-03  0.8359167E-04  0.2754838E-04
# 2    0.1142583E-03  0.1481653E-03  0.9050834E-04  0.4544758E-04
# 3    0.1326500E-03  0.1354556E-03  0.8949998E-04  0.4124192E-04
# 4    0.1287542E-03  0.1247984E-03  0.8210001E-04  0.2794758E-04
# ..             ...            ...            ...            ...
# 175  0.1140042E-03  0.1110363E-03  0.7208750E-04  0.2978629E-04
# 176  0.1105833E-03  0.1282540E-03  0.8610834E-04  0.3248790E-04
# 177  0.8806250E-04  0.1285524E-03  0.6714167E-04  0.1520161E-04
# 178  0.1171542E-03  0.1316049E-03  0.7517082E-04  0.2623790E-04
# 179  0.8503751E-04  0.1291371E-03  0.1004833E-03  0.3734274E-04
#
# [180 rows x 13 columns]
# Response Status: 200
#
#         Month          Mean          2.5%           17%           50%  \
# 0     January  0.176168E-04  0.275003E-05  0.800484E-05  0.167782E-04
# 1    February  0.298919E-04  0.596558E-05  0.142000E-04  0.277366E-04
# 2       March  0.667827E-04  0.264358E-04  0.481770E-04  0.665746E-04
# 3       April  0.109476E-03  0.679007E-04  0.927233E-04  0.109990E-03
# 4         May  0.117282E-03  0.807911E-04  0.986113E-04  0.117952E-03
# 5        June  0.876172E-04  0.552172E-04  0.721879E-04  0.856958E-04
# 6        July  0.691009E-04  0.332100E-04  0.498415E-04  0.679113E-04
# 7      August  0.919284E-04  0.416214E-04  0.674177E-04  0.932702E-04
# 8   September  0.119142E-03  0.705257E-04  0.964908E-04  0.118481E-03
# 9     October  0.111955E-03  0.650208E-04  0.917343E-04  0.111690E-03
# 10   November  0.723828E-04  0.369545E-04  0.561021E-04  0.701479E-04
# 11   December  0.301770E-04  0.114477E-04  0.191456E-04  0.290101E-04
#
#              83%         97.5%
# 0   0.261048E-04  0.404190E-04
# 1   0.446707E-04  0.693743E-04
# 2   0.834786E-04  0.107253E-03
# 3   0.127718E-03  0.146415E-03
# 4   0.135572E-03  0.160349E-03
# 5   0.103445E-03  0.136219E-03
# 6   0.848181E-04  0.112358E-03
# 7   0.116277E-03  0.140523E-03
# 8   0.143201E-03  0.167507E-03
# 9   0.133987E-03  0.159216E-03
# 10  0.894850E-04  0.119003E-03
# 11  0.402032E-04  0.552374E-04
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  -0.815715E-05  -0.109436E-04   0.486246E-05  -0.744720E-05
# 1    1837  -0.717639E-06   0.434013E-06   0.135439E-04   0.540280E-05
# 2    1838  -0.342639E-06   0.100233E-04   0.154270E-04   0.250280E-05
# 3    1839   0.149607E-05  -0.291420E-05   0.343907E-05   0.130569E-04
# 4    1840   0.233881E-05  -0.121376E-04   0.487456E-05   0.248190E-05
# ..    ...            ...            ...            ...            ...
# 175  2011  -0.925796E-05  -0.195258E-04  -0.390730E-04  -0.464556E-04
# 176  2012  -0.145483E-04  -0.179608E-04  -0.348996E-04  -0.257472E-04
# 177  2013  -0.255231E-05  -0.129142E-04   0.459222E-06  -0.140847E-04
# 178  2014  -0.336280E-05  -0.880706E-05   0.236528E-04   0.567780E-05
# 179  2015  -0.139999E-04  -0.157088E-04  -0.167827E-04   0.391110E-05
#
#                May           June           July         August  \
# 0    -0.150035E-04  -0.195047E-04  -0.170122E-04  -0.513405E-05
# 1     0.909730E-05  -0.105213E-04  -0.154850E-05   0.301516E-05
# 2    -0.862040E-05  -0.725466E-05  -0.197702E-06  -0.899294E-05
# 3    -0.143906E-04  -0.111463E-04   0.183053E-05   0.849810E-06
# 4    -0.816480E-05  -0.595050E-05  -0.619769E-05  -0.216631E-05
# ..             ...            ...            ...            ...
# 175  -0.275922E-04  -0.131172E-04  -0.118590E-04  -0.250010E-04
# 176   0.968299E-06  -0.884633E-05  -0.241251E-04  -0.341824E-04
# 177  -0.580590E-05  -0.397838E-04  -0.155606E-04  -0.568558E-04
# 178   0.542800E-05  -0.484633E-05  -0.242058E-04  -0.160131E-04
# 179   0.102788E-04  -0.156880E-04  -0.284195E-04  -0.395131E-04
#
#          September        October       November       December
# 0     0.198728E-05   0.165085E-04   0.208391E-05  -0.194716E-05
# 1    -0.236271E-05   0.202585E-04   0.112089E-04  -0.262862E-05
# 2    -0.488362E-05   0.362101E-04   0.181256E-04   0.152706E-04
# 3     0.135081E-04   0.235004E-04   0.171172E-04   0.110649E-04
# 4     0.961228E-05   0.128432E-04   0.971723E-05  -0.222942E-05
# ..             ...            ...            ...            ...
# 175  -0.513771E-05  -0.918873E-06  -0.295273E-06  -0.390706E-06
# 176  -0.855861E-05   0.162988E-04   0.137256E-04   0.231090E-05
# 177  -0.310794E-04   0.165972E-04  -0.524111E-05  -0.149754E-04
# 178  -0.198771E-05   0.196497E-04   0.278805E-05  -0.393910E-05
# 179  -0.341044E-04   0.171819E-04   0.281005E-04   0.716574E-05
#
# [180 rows x 13 columns]
# lat_min: 2.500, lat_max: 3.500, lon_min: 29.500, lon_max: 30.500, raw_data_df: (180, 13), annual_df: (12, 7), anom_df: (180, 13)
# Successfully processed coordinate box 1 of 127
#
# =====================================================================
# Processing page 2 of 127: lat1: 2.5, lat2: 3.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Response Status Code: 200
# ['30.500', '31.500']
# ['2.500', '3.500']
# data/ic3prate_30.5-31.5E_2.5-3.5N_n.dat
# data/ic3prate_30.5-31.5E_2.5-3.5N_n__yr.txt
# data/ic3prate_30.5-31.5E_2.5-3.5N_n_a.txt
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  0.4298387E-05  0.9633620E-05  0.5132259E-04  0.7053333E-04
# 1    1837  0.8217741E-05  0.1516964E-04  0.5298790E-04  0.8242916E-04
# 2    1838  0.7794356E-05  0.2514286E-04  0.5611693E-04  0.7692084E-04
# 3    1839  0.8907259E-05  0.1341964E-04  0.4332258E-04  0.8637084E-04
# 4    1840  0.1009274E-04  0.8814654E-05  0.4317742E-04  0.7904168E-04
# ..    ...            ...            ...            ...            ...
# 175  2011  0.4919354E-05  0.3758928E-05  0.1725403E-04  0.2950418E-04
# 176  2012  0.1286290E-05  0.5163793E-05  0.1447581E-04  0.6315835E-04
# 177  2013  0.7330646E-05  0.6540179E-05  0.4601613E-04  0.6965001E-04
# 178  2014  0.5778226E-05  0.1242411E-04  0.5795162E-04  0.7140834E-04
# 179  2015  0.1197580E-05  0.4901785E-05  0.2742742E-04  0.8432502E-04
#
#                May           June           July         August  \
# 0    0.7031453E-04  0.5240000E-04  0.4974597E-04  0.8350403E-04
# 1    0.8053629E-04  0.5560417E-04  0.6588306E-04  0.8743146E-04
# 2    0.6997176E-04  0.7069168E-04  0.7094355E-04  0.8362096E-04
# 3    0.6843548E-04  0.5845417E-04  0.7243145E-04  0.8007258E-04
# 4    0.7402822E-04  0.7018333E-04  0.6125000E-04  0.8985081E-04
# ..             ...            ...            ...            ...
# 175  0.5071371E-04  0.5956251E-04  0.5037500E-04  0.5740322E-04
# 176  0.8808064E-04  0.6436250E-04  0.4850806E-04  0.5371775E-04
# 177  0.7670162E-04  0.4417916E-04  0.5172580E-04  0.3152419E-04
# 178  0.8000806E-04  0.6426251E-04  0.4470968E-04  0.6753226E-04
# 179  0.9438307E-04  0.6327919E-04  0.2911290E-04  0.3231048E-04
#
#          September        October       November       December
# 0    0.1030958E-03  0.8729839E-04  0.4990417E-04  0.1431855E-04
# 1    0.9016666E-04  0.9859678E-04  0.5759584E-04  0.1385081E-04
# 2    0.9723333E-04  0.1052984E-03  0.5703333E-04  0.2316129E-04
# 3    0.1021792E-03  0.9261693E-04  0.5795000E-04  0.2219759E-04
# 4    0.1147625E-03  0.9769759E-04  0.5369167E-04  0.1413307E-04
# ..             ...            ...            ...            ...
# 175  0.8649167E-04  0.7304839E-04  0.5145416E-04  0.1725807E-04
# 176  0.8054168E-04  0.8497580E-04  0.6138333E-04  0.1541129E-04
# 177  0.6581667E-04  0.9060483E-04  0.3595833E-04  0.6911290E-05
# 178  0.8647083E-04  0.9251208E-04  0.4720000E-04  0.1294355E-04
# 179  0.5455000E-04  0.8551613E-04  0.6590415E-04  0.2510081E-04
#
# [180 rows x 13 columns]
# Response Status: 200
#
#         Month          Mean          2.5%           17%           50%  \
# 0     January  0.819915E-05  0.830653E-06  0.316774E-05  0.738911E-05
# 1    February  0.159991E-04  0.236163E-05  0.656786E-05  0.134442E-04
# 2       March  0.404472E-04  0.139276E-04  0.251411E-04  0.388387E-04
# 3       April  0.743345E-04  0.379545E-04  0.578646E-04  0.739813E-04
# 4         May  0.785142E-04  0.458432E-04  0.599956E-04  0.787540E-04
# 5        June  0.677417E-04  0.366920E-04  0.514954E-04  0.664250E-04
# 6        July  0.627283E-04  0.241333E-04  0.471113E-04  0.626814E-04
# 7      August  0.756237E-04  0.358229E-04  0.516298E-04  0.773609E-04
# 8   September  0.845141E-04  0.418462E-04  0.628883E-04  0.827438E-04
# 9     October  0.712524E-04  0.308955E-04  0.543706E-04  0.708629E-04
# 10   November  0.425181E-04  0.150085E-04  0.283500E-04  0.420208E-04
# 11   December  0.144701E-04  0.406052E-05  0.778307E-05  0.134133E-04
#
#              83%         97.5%
# 0   0.126391E-04  0.222659E-04
# 1   0.260039E-04  0.433835E-04
# 2   0.550758E-04  0.744428E-04
# 3   0.921046E-04  0.109341E-03
# 4   0.963403E-04  0.115023E-03
# 5   0.837067E-04  0.104003E-03
# 6   0.769149E-04  0.106281E-03
# 7   0.962028E-04  0.112096E-03
# 8   0.106297E-03  0.125186E-03
# 9   0.892669E-04  0.114059E-03
# 10  0.571421E-04  0.781700E-04
# 11  0.202802E-04  0.310118E-04
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  -0.390076E-05  -0.636548E-05   0.108754E-04  -0.380121E-05
# 1    1837   0.185910E-07  -0.829456E-06   0.125407E-04   0.809461E-05
# 2    1838  -0.404794E-06   0.914376E-05   0.156697E-04   0.258630E-05
# 3    1839   0.708109E-06  -0.257946E-05   0.287539E-05   0.120363E-04
# 4    1840   0.189359E-05  -0.718444E-05   0.273023E-05   0.470714E-05
# ..    ...            ...            ...            ...            ...
# 175  2011  -0.327980E-05  -0.122402E-04  -0.231932E-04  -0.448304E-04
# 176  2012  -0.691286E-05  -0.108353E-04  -0.259714E-04  -0.111762E-04
# 177  2013  -0.868504E-06  -0.945892E-05   0.556894E-05  -0.468454E-05
# 178  2014  -0.242092E-05  -0.357499E-05   0.175044E-04  -0.292620E-05
# 179  2015  -0.700157E-05  -0.110973E-04  -0.130198E-04   0.999048E-05
#
#                May           June           July         August  \
# 0    -0.819965E-05  -0.153417E-04  -0.129824E-04   0.788036E-05
# 1     0.202211E-05  -0.121375E-04   0.315473E-05   0.118078E-04
# 2    -0.854242E-05   0.295002E-05   0.821522E-05   0.799729E-05
# 3    -0.100787E-04  -0.928750E-05   0.970312E-05   0.444891E-05
# 4    -0.448596E-05   0.244166E-05  -0.147833E-05   0.142271E-04
# ..             ...            ...            ...            ...
# 175  -0.278005E-04  -0.817916E-05  -0.123533E-04  -0.182204E-04
# 176   0.956647E-05  -0.337917E-05  -0.142203E-04  -0.219059E-04
# 177  -0.181256E-05  -0.235625E-04  -0.110025E-04  -0.440995E-04
# 178   0.149389E-05  -0.347916E-05  -0.180187E-04  -0.809141E-05
# 179   0.158689E-04  -0.446248E-05  -0.336154E-04  -0.433132E-04
#
#          September       October       November       December
# 0     0.185817E-04  0.160460E-04   0.738605E-05  -0.151572E-06
# 1     0.565251E-05  0.273444E-04   0.150777E-04  -0.619311E-06
# 2     0.127192E-04  0.340460E-04   0.145152E-04   0.869117E-05
# 3     0.176651E-04  0.213645E-04   0.154319E-04   0.772747E-05
# 4     0.302484E-04  0.264452E-04   0.111735E-04  -0.337051E-06
# ..             ...           ...            ...            ...
# 175   0.197753E-05  0.179600E-05   0.893604E-05   0.278795E-05
# 176  -0.397247E-05  0.137234E-04   0.188652E-04   0.941168E-06
# 177  -0.186975E-04  0.193524E-04  -0.655979E-05  -0.755883E-05
# 178   0.195668E-05  0.212597E-04   0.468188E-05  -0.152657E-05
# 179  -0.299641E-04  0.142637E-04   0.233860E-04   0.106307E-04
#
# [180 rows x 13 columns]
# lat_min: 2.500, lat_max: 3.500, lon_min: 30.500, lon_max: 31.500, raw_data_df: (180, 13), annual_df: (12, 7), anom_df: (180, 13)
# Successfully processed coordinate box 2 of 127
#
# =====================================================================
# Processing page 3 of 127: lat1: 2.5, lat2: 3.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Response Status Code: 200
# ['31.500', '32.500']
# ['2.500', '3.500']
# data/ic3prate_31.5-32.5E_2.5-3.5N_n.dat
# data/ic3prate_31.5-32.5E_2.5-3.5N_n__yr.txt
# data/ic3prate_31.5-32.5E_2.5-3.5N_n_a.txt
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  0.1612903E-05  0.3607759E-05  0.2372177E-04  0.3266250E-04
# 1    1837  0.2580645E-05  0.4348214E-05  0.2320565E-04  0.4158750E-04
# 2    1838  0.2939516E-05  0.1033482E-04  0.2468952E-04  0.3915000E-04
# 3    1839  0.3318548E-05  0.4928572E-05  0.1862097E-04  0.4620417E-04
# 4    1840  0.4314516E-05  0.3038793E-05  0.1894758E-04  0.3985000E-04
# ..    ...            ...            ...            ...            ...
# 175  2011  0.1508064E-05  0.8616071E-06  0.9677419E-05  0.1117917E-04
# 176  2012  0.4959677E-06  0.1431034E-05  0.5830646E-05  0.3659167E-04
# 177  2013  0.2197580E-05  0.1437500E-05  0.2305645E-04  0.3527918E-04
# 178  2014  0.1362903E-05  0.4241072E-05  0.2811290E-04  0.2970417E-04
# 179  2015  0.4475808E-06  0.1035715E-05  0.1222581E-04  0.5385417E-04
#
#                May           June           July         August  \
# 0    0.3451210E-04  0.2566667E-04  0.2255645E-04  0.4222984E-04
# 1    0.3704032E-04  0.2591250E-04  0.3029032E-04  0.4104032E-04
# 2    0.3084677E-04  0.3527916E-04  0.3354032E-04  0.4159274E-04
# 3    0.3070161E-04  0.2844166E-04  0.3497581E-04  0.3690322E-04
# 4    0.3532661E-04  0.3497083E-04  0.2859677E-04  0.4230242E-04
# ..             ...            ...            ...            ...
# 175  0.2011694E-04  0.2826250E-04  0.2454435E-04  0.2812097E-04
# 176  0.4965322E-04  0.3047916E-04  0.2277420E-04  0.2515725E-04
# 177  0.3422984E-04  0.1974583E-04  0.2395968E-04  0.1363307E-04
# 178  0.3547580E-04  0.3083333E-04  0.2380242E-04  0.3429032E-04
# 179  0.4745161E-04  0.3104167E-04  0.1149193E-04  0.1358468E-04
#
#          September        October       November       December
# 0    0.5189584E-04  0.4531452E-04  0.2258750E-04  0.5201613E-05
# 1    0.4089583E-04  0.4930242E-04  0.2818334E-04  0.4895162E-05
# 2    0.5117083E-04  0.5013710E-04  0.2498750E-04  0.8552421E-05
# 3    0.5013750E-04  0.4362097E-04  0.2628333E-04  0.8548388E-05
# 4    0.6199583E-04  0.5153227E-04  0.2460833E-04  0.5024194E-05
# ..             ...            ...            ...            ...
# 175  0.3810000E-04  0.2971774E-04  0.2888333E-04  0.8717741E-05
# 176  0.3833334E-04  0.3519355E-04  0.2962917E-04  0.6318548E-05
# 177  0.2897500E-04  0.3464919E-04  0.1211250E-04  0.1693549E-05
# 178  0.4032083E-04  0.3775403E-04  0.1759584E-04  0.4971776E-05
# 179  0.1979583E-04  0.3787903E-04  0.3305834E-04  0.1255645E-04
#
# [180 rows x 13 columns]
# Response Status: 200
#
#         Month          Mean          2.5%           17%           50%  \
# 0     January  0.295551E-05  0.298390E-06  0.980242E-06  0.234476E-05
# 1    February  0.585479E-05  0.580363E-06  0.203170E-05  0.469643E-05
# 2       March  0.173837E-04  0.462908E-05  0.958468E-05  0.165645E-04
# 3       April  0.368546E-04  0.121835E-04  0.242442E-04  0.353729E-04
# 4         May  0.376864E-04  0.179599E-04  0.244113E-04  0.359173E-04
# 5        June  0.324898E-04  0.140585E-04  0.229804E-04  0.310979E-04
# 6        July  0.297526E-04  0.101291E-04  0.211101E-04  0.293891E-04
# 7      August  0.349075E-04  0.136332E-04  0.223589E-04  0.349234E-04
# 8   September  0.378031E-04  0.122501E-04  0.230392E-04  0.350771E-04
# 9     October  0.285578E-04  0.783879E-05  0.171597E-04  0.267218E-04
# 10   November  0.170799E-04  0.412088E-05  0.893458E-05  0.161521E-04
# 11   December  0.517061E-05  0.110485E-05  0.207823E-05  0.474395E-05
#
#              83%         97.5%
# 0   0.479839E-05  0.918136E-05
# 1   0.101469E-04  0.188927E-04
# 2   0.245778E-04  0.372174E-04
# 3   0.486475E-04  0.661952E-04
# 4   0.501798E-04  0.640478E-04
# 5   0.410950E-04  0.561244E-04
# 6   0.371222E-04  0.525116E-04
# 7   0.465383E-04  0.544309E-04
# 8   0.531413E-04  0.720201E-04
# 9   0.397436E-04  0.592212E-04
# 10  0.248983E-04  0.413038E-04
# 11  0.828589E-05  0.133507E-04
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  -0.134261E-05  -0.224703E-05   0.633803E-05  -0.419208E-05
# 1    1837  -0.374866E-06  -0.150658E-05   0.582191E-05   0.473292E-05
# 2    1838  -0.159948E-07   0.448003E-05   0.730578E-05   0.229542E-05
# 3    1839   0.363037E-06  -0.926219E-06   0.123723E-05   0.934959E-05
# 4    1840   0.135901E-05  -0.281600E-05   0.156384E-05   0.299542E-05
# ..    ...            ...            ...            ...            ...
# 175  2011  -0.144745E-05  -0.499318E-05  -0.770632E-05  -0.256754E-04
# 176  2012  -0.245954E-05  -0.442376E-05  -0.115531E-04  -0.262906E-06
# 177  2013  -0.757931E-06  -0.441729E-05   0.567271E-05  -0.157540E-05
# 178  2014  -0.159261E-05  -0.161372E-05   0.107292E-04  -0.715041E-05
# 179  2015  -0.250793E-05  -0.481908E-05  -0.515793E-05   0.169996E-04
#
#                May           June           July         August  \
# 0    -0.317430E-05  -0.682309E-05  -0.719617E-05   0.732232E-05
# 1    -0.646076E-06  -0.657726E-05   0.537702E-06   0.613280E-05
# 2    -0.683963E-05   0.278940E-05   0.378770E-05   0.668522E-05
# 3    -0.698479E-05  -0.404810E-05   0.522319E-05   0.199570E-05
# 4    -0.235979E-05   0.248107E-05  -0.115585E-05   0.739490E-05
# ..             ...            ...            ...            ...
# 175  -0.175695E-04  -0.422726E-05  -0.520827E-05  -0.678655E-05
# 176   0.119668E-04  -0.201060E-05  -0.697842E-05  -0.975027E-05
# 177  -0.345656E-05  -0.127439E-04  -0.579294E-05  -0.212745E-04
# 178  -0.221060E-05  -0.165643E-05  -0.595020E-05  -0.617205E-06
# 179   0.976521E-05  -0.144809E-05  -0.182607E-04  -0.213228E-04
#
#          September       October       November       December
# 0     0.140927E-04  0.167567E-04   0.550757E-05   0.310042E-07
# 1     0.309271E-05  0.207446E-04   0.111034E-04  -0.275447E-06
# 2     0.133677E-04  0.215793E-04   0.790757E-05   0.338181E-05
# 3     0.123344E-04  0.150632E-04   0.920340E-05   0.337778E-05
# 4     0.241927E-04  0.229745E-04   0.752840E-05  -0.146415E-06
# ..             ...           ...            ...            ...
# 175   0.296877E-06  0.115994E-05   0.118034E-04   0.354713E-05
# 176   0.530217E-06  0.663575E-05   0.125492E-04   0.114794E-05
# 177  -0.882812E-05  0.609139E-05  -0.496743E-05  -0.347706E-05
# 178   0.251771E-05  0.919623E-05   0.515907E-06  -0.198833E-06
# 179  -0.180073E-04  0.932123E-05   0.159784E-04   0.738584E-05
#
# [180 rows x 13 columns]
# lat_min: 2.500, lat_max: 3.500, lon_min: 31.500, lon_max: 32.500, raw_data_df: (180, 13), annual_df: (12, 7), anom_df: (180, 13)
# Successfully processed coordinate box 3 of 127
#
# =====================================================================
# Processing page 4 of 127: lat1: 2.5, lat2: 3.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Response Status Code: 200
# ['32.500', '33.500']
# ['2.500', '3.500']
# data/ic3prate_32.5-33.5E_2.5-3.5N_n.dat
# data/ic3prate_32.5-33.5E_2.5-3.5N_n__yr.txt
# data/ic3prate_32.5-33.5E_2.5-3.5N_n_a.txt
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  0.4193548E-05  0.8056036E-05  0.3918548E-04  0.4869582E-04
# 1    1837  0.6379033E-05  0.8959822E-05  0.3689920E-04  0.6132083E-04
# 2    1838  0.6552419E-05  0.2022322E-04  0.3826210E-04  0.5695000E-04
# 3    1839  0.8580644E-05  0.1083482E-04  0.3087500E-04  0.6483751E-04
# 4    1840  0.9165323E-05  0.6732759E-05  0.3100403E-04  0.5606666E-04
# ..    ...            ...            ...            ...            ...
# 175  2011  0.3854839E-05  0.1607143E-05  0.2041935E-04  0.2285416E-04
# 176  2012  0.9475807E-06  0.2133622E-05  0.1072984E-04  0.5577916E-04
# 177  2013  0.4838711E-05  0.2852679E-05  0.4077823E-04  0.5645834E-04
# 178  2014  0.3100807E-05  0.8321429E-05  0.4399194E-04  0.4852917E-04
# 179  2015  0.8830648E-06  0.2263393E-05  0.1661694E-04  0.7997498E-04
#
#                May           June           July         August  \
# 0    0.4962500E-04  0.3530834E-04  0.2954436E-04  0.4524598E-04
# 1    0.5137501E-04  0.3476250E-04  0.3470565E-04  0.4399194E-04
# 2    0.4247983E-04  0.4077083E-04  0.3706048E-04  0.4312097E-04
# 3    0.4693145E-04  0.3715834E-04  0.3605645E-04  0.4232661E-04
# 4    0.5112097E-04  0.3940000E-04  0.3218952E-04  0.4343953E-04
# ..             ...            ...            ...            ...
# 175  0.4003225E-04  0.4689583E-04  0.3683871E-04  0.3806855E-04
# 176  0.6588709E-04  0.4359167E-04  0.3107257E-04  0.3318951E-04
# 177  0.5549999E-04  0.3587500E-04  0.3546775E-04  0.2505645E-04
# 178  0.5729032E-04  0.4910833E-04  0.3612903E-04  0.4477016E-04
# 179  0.6805646E-04  0.4137083E-04  0.1808064E-04  0.2272984E-04
#
#          September        October       November       December
# 0    0.5972501E-04  0.5815726E-04  0.3885000E-04  0.1121371E-04
# 1    0.4854166E-04  0.6752420E-04  0.4807917E-04  0.1064113E-04
# 2    0.6076666E-04  0.6316129E-04  0.4017500E-04  0.1627823E-04
# 3    0.5703334E-04  0.5978225E-04  0.4419167E-04  0.1772178E-04
# 4    0.6769167E-04  0.6694758E-04  0.4338333E-04  0.1125000E-04
# ..             ...            ...            ...            ...
# 175  0.5010000E-04  0.4641129E-04  0.5193750E-04  0.1792742E-04
# 176  0.4880834E-04  0.5357258E-04  0.4610833E-04  0.1480242E-04
# 177  0.4434583E-04  0.5342339E-04  0.2193334E-04  0.3713710E-05
# 178  0.5479167E-04  0.5603629E-04  0.3350834E-04  0.1279839E-04
# 179  0.2900833E-04  0.5633871E-04  0.5280833E-04  0.2716936E-04
#
# [180 rows x 13 columns]
# Response Status: 200
#
#         Month          Mean          2.5%           17%           50%  \
# 0     January  0.651568E-05  0.834686E-06  0.229234E-05  0.504234E-05
# 1    February  0.112415E-04  0.146876E-05  0.436697E-05  0.901008E-05
# 2       March  0.282332E-04  0.918558E-05  0.174492E-04  0.274436E-04
# 3       April  0.540066E-04  0.210210E-04  0.396646E-04  0.520500E-04
# 4         May  0.533722E-04  0.295447E-04  0.400322E-04  0.524677E-04
# 5        June  0.430883E-04  0.242586E-04  0.340446E-04  0.416500E-04
# 6        July  0.356188E-04  0.180647E-04  0.289040E-04  0.351270E-04
# 7      August  0.396679E-04  0.206938E-04  0.300891E-04  0.409315E-04
# 8   September  0.461252E-04  0.186835E-04  0.310192E-04  0.445646E-04
# 9     October  0.408211E-04  0.113429E-04  0.264403E-04  0.389496E-04
# 10   November  0.286231E-04  0.664173E-05  0.157008E-04  0.271625E-04
# 11   December  0.106298E-04  0.256454E-05  0.438992E-05  0.100645E-04
#
#              83%         97.5%
# 0   0.112617E-04  0.177861E-04
# 1   0.194339E-04  0.319221E-04
# 2   0.384617E-04  0.543099E-04
# 3   0.693325E-04  0.883241E-04
# 4   0.662613E-04  0.823661E-04
# 5   0.508012E-04  0.633952E-04
# 6   0.422020E-04  0.563583E-04
# 7   0.476738E-04  0.553462E-04
# 8   0.627975E-04  0.786034E-04
# 9   0.555589E-04  0.787049E-04
# 10  0.409542E-04  0.609577E-04
# 11  0.158012E-04  0.242699E-04
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  -0.232213E-05  -0.318550E-05   0.109523E-04  -0.531082E-05
# 1    1837  -0.136648E-06  -0.228171E-05   0.866597E-05   0.731419E-05
# 2    1838   0.367381E-07   0.898169E-05   0.100289E-04   0.294336E-05
# 3    1839   0.206496E-05  -0.406712E-06   0.264177E-05   0.108309E-04
# 4    1840   0.264964E-05  -0.450877E-05   0.277080E-05   0.206002E-05
# ..    ...            ...            ...            ...            ...
# 175  2011  -0.266084E-05  -0.963439E-05  -0.781388E-05  -0.311525E-04
# 176  2012  -0.556810E-05  -0.910791E-05  -0.175034E-04   0.177252E-05
# 177  2013  -0.167697E-05  -0.838885E-05   0.125450E-04   0.245170E-05
# 178  2014  -0.341487E-05  -0.292010E-05   0.157587E-04  -0.547747E-05
# 179  2015  -0.563262E-05  -0.897814E-05  -0.116163E-04   0.259683E-04
#
#                May           June           July         August  \
# 0    -0.374715E-05  -0.777995E-05  -0.607444E-05   0.557808E-05
# 1    -0.199714E-05  -0.832579E-05  -0.913147E-06   0.432404E-05
# 2    -0.108923E-04  -0.231746E-05   0.144168E-05   0.345307E-05
# 3    -0.644070E-05  -0.592995E-05   0.437656E-06   0.265871E-05
# 4    -0.225118E-05  -0.368829E-05  -0.342928E-05   0.377163E-05
# ..             ...            ...            ...            ...
# 175  -0.133399E-04   0.380754E-05   0.121991E-05  -0.159935E-05
# 176   0.125149E-04   0.503380E-06  -0.454623E-05  -0.647839E-05
# 177   0.212784E-05  -0.721329E-05  -0.151045E-06  -0.146114E-04
# 178   0.391817E-05   0.602004E-05   0.510234E-06   0.510227E-05
# 179   0.146843E-04  -0.171746E-05  -0.175382E-04  -0.169381E-04
#
#          September       October       November       December
# 0     0.135998E-04  0.173362E-04   0.102269E-04   0.583871E-06
# 1     0.241643E-05  0.267031E-04   0.194561E-04   0.112905E-07
# 2     0.146414E-04  0.223402E-04   0.115519E-04   0.564839E-05
# 3     0.109081E-04  0.189612E-04   0.155686E-04   0.709194E-05
# 4     0.215664E-04  0.261265E-04   0.147603E-04   0.620161E-06
# ..             ...           ...            ...            ...
# 175   0.397476E-05  0.559019E-05   0.233144E-04   0.729758E-05
# 176   0.268310E-05  0.127515E-04   0.174853E-04   0.417258E-05
# 177  -0.177940E-05  0.126023E-04  -0.668971E-05  -0.691613E-05
# 178   0.866644E-05  0.152152E-04   0.488529E-05   0.216855E-05
# 179  -0.171169E-04  0.155176E-04   0.241853E-04   0.165395E-04
#
# [180 rows x 13 columns]
# lat_min: 2.500, lat_max: 3.500, lon_min: 32.500, lon_max: 33.500, raw_data_df: (180, 13), annual_df: (12, 7), anom_df: (180, 13)
# Successfully processed coordinate box 4 of 127
#
# =====================================================================
# Processing page 5 of 127: lat1: 2.5, lat2: 3.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Response Status Code: 200
# ['33.500', '34.500']
# ['2.500', '3.500']
# data/ic3prate_33.5-34.5E_2.5-3.5N_n.dat
# data/ic3prate_33.5-34.5E_2.5-3.5N_n__yr.txt
# data/ic3prate_33.5-34.5E_2.5-3.5N_n_a.txt
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  0.5322580E-05  0.1059052E-04  0.3983871E-04  0.4744583E-04
# 1    1837  0.7366936E-05  0.1016071E-04  0.3394355E-04  0.5426667E-04
# 2    1838  0.7834677E-05  0.2160714E-04  0.3902822E-04  0.5256666E-04
# 3    1839  0.1131855E-04  0.1413393E-04  0.3368952E-04  0.6250833E-04
# 4    1840  0.1141129E-04  0.8034483E-05  0.2848387E-04  0.4736667E-04
# ..    ...            ...            ...            ...            ...
# 175  2011  0.4451612E-05  0.1892857E-05  0.2355645E-04  0.2107083E-04
# 176  2012  0.5645161E-06  0.3431034E-05  0.1069355E-04  0.6661249E-04
# 177  2013  0.5770161E-05  0.2446428E-05  0.4456049E-04  0.7160832E-04
# 178  2014  0.2282258E-05  0.8285715E-05  0.5342742E-04  0.4502501E-04
# 179  2015  0.9516129E-06  0.2214285E-05  0.1833871E-04  0.9905000E-04
#
#                May           June           July         August  \
# 0    0.4543951E-04  0.3944167E-04  0.3806452E-04  0.5658870E-04
# 1    0.4316532E-04  0.3320000E-04  0.4470565E-04  0.5373791E-04
# 2    0.3624597E-04  0.4618750E-04  0.4950000E-04  0.5458871E-04
# 3    0.4270967E-04  0.3980834E-04  0.4604032E-04  0.4591936E-04
# 4    0.4852420E-04  0.4394167E-04  0.4209274E-04  0.5407258E-04
# ..             ...            ...            ...            ...
# 175  0.3670565E-04  0.4987916E-04  0.4951210E-04  0.4632662E-04
# 176  0.7225000E-04  0.5221666E-04  0.4266129E-04  0.4288710E-04
# 177  0.5417338E-04  0.4555833E-04  0.4624193E-04  0.3135887E-04
# 178  0.5243952E-04  0.4941667E-04  0.4807662E-04  0.5572176E-04
# 179  0.7213308E-04  0.5687917E-04  0.1906855E-04  0.2231451E-04
#
#          September        October       November       December
# 0    0.6797082E-04  0.5008468E-04  0.3691250E-04  0.1164919E-04
# 1    0.4630833E-04  0.6368951E-04  0.4708749E-04  0.1174193E-04
# 2    0.6342083E-04  0.6008468E-04  0.3317500E-04  0.1559274E-04
# 3    0.5319583E-04  0.5515726E-04  0.4381250E-04  0.2083871E-04
# 4    0.8226666E-04  0.6620566E-04  0.4620000E-04  0.1093952E-04
# ..             ...            ...            ...            ...
# 175  0.4735833E-04  0.4162097E-04  0.6501250E-04  0.2083871E-04
# 176  0.5465417E-04  0.4933468E-04  0.4312916E-04  0.1804839E-04
# 177  0.4419167E-04  0.4010887E-04  0.2021250E-04  0.3479838E-05
# 178  0.5045832E-04  0.5088710E-04  0.4069167E-04  0.1558468E-04
# 179  0.2019166E-04  0.4868548E-04  0.5840833E-04  0.3754436E-04
#
# [180 rows x 13 columns]
# Response Status: 200
#
#         Month          Mean          2.5%           17%           50%  \
# 0     January  0.728226E-05  0.737911E-06  0.206008E-05  0.541331E-05
# 1    February  0.124013E-04  0.163795E-05  0.398125E-05  0.102211E-04
# 2       March  0.285975E-04  0.703233E-05  0.162694E-04  0.274093E-04
# 3       April  0.513571E-04  0.161835E-04  0.353854E-04  0.502208E-04
# 4         May  0.494466E-04  0.225889E-04  0.342234E-04  0.474738E-04
# 5        June  0.456803E-04  0.197752E-04  0.335633E-04  0.452313E-04
# 6        July  0.417716E-04  0.185808E-04  0.312806E-04  0.418629E-04
# 7      August  0.427461E-04  0.169881E-04  0.309032E-04  0.442036E-04
# 8   September  0.432775E-04  0.903759E-05  0.241612E-04  0.404208E-04
# 9     October  0.337675E-04  0.510489E-05  0.165355E-04  0.304214E-04
# 10   November  0.246016E-04  0.352920E-05  0.995208E-05  0.209167E-04
# 11   December  0.105418E-04  0.141130E-05  0.336250E-05  0.878629E-05
#
#              83%         97.5%
# 0   0.134169E-04  0.211812E-04
# 1   0.213835E-04  0.318617E-04
# 2   0.413012E-04  0.541769E-04
# 3   0.690446E-04  0.912949E-04
# 4   0.657274E-04  0.838137E-04
# 5   0.584196E-04  0.729451E-04
# 6   0.511939E-04  0.674671E-04
# 7   0.545480E-04  0.651889E-04
# 8   0.633012E-04  0.919491E-04
# 9   0.496649E-04  0.793178E-04
# 10  0.406217E-04  0.616161E-04
# 11  0.182044E-04  0.269070E-04
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  -0.195968E-05  -0.181079E-05   0.112412E-04  -0.391125E-05
# 1    1837   0.846799E-07  -0.224060E-05   0.534602E-05   0.290959E-05
# 2    1838   0.552420E-06   0.920583E-05   0.104307E-04   0.120958E-05
# 3    1839   0.403629E-05   0.173262E-05   0.509199E-05   0.111512E-04
# 4    1840   0.412903E-05  -0.436682E-05  -0.113665E-06  -0.399041E-05
# ..    ...            ...            ...            ...            ...
# 175  2011  -0.283064E-05  -0.105085E-04  -0.504109E-05  -0.302863E-04
# 176  2012  -0.671774E-05  -0.897027E-05  -0.179040E-04   0.152554E-04
# 177  2013  -0.151210E-05  -0.995488E-05   0.159630E-04   0.202512E-04
# 178  2014  -0.500000E-05  -0.411559E-05   0.248299E-04  -0.633207E-05
# 179  2015  -0.633064E-05  -0.101870E-04  -0.102588E-04   0.476929E-04
#
#                May           June           July         August  \
# 0    -0.400706E-05  -0.623862E-05  -0.370705E-05   0.138426E-04
# 1    -0.628125E-05  -0.124803E-04   0.293408E-05   0.109918E-04
# 2    -0.132006E-04   0.507203E-06   0.772842E-05   0.118426E-04
# 3    -0.673690E-05  -0.587196E-05   0.426875E-05   0.317325E-05
# 4    -0.922370E-06  -0.173863E-05   0.321164E-06   0.113265E-04
# ..             ...            ...            ...            ...
# 175  -0.127409E-04   0.419886E-05   0.774052E-05   0.358050E-05
# 176   0.228034E-04   0.653636E-05   0.889715E-06   0.140983E-06
# 177   0.472681E-05  -0.121967E-06   0.447036E-05  -0.113872E-04
# 178   0.299295E-05   0.373638E-05   0.630505E-05   0.129756E-04
# 179   0.226865E-04   0.111989E-04  -0.227030E-04  -0.204316E-04
#
#          September       October       November       December
# 0     0.246933E-04  0.163172E-04   0.123109E-04   0.110744E-05
# 1     0.303086E-05  0.299220E-04   0.224859E-04   0.120018E-05
# 2     0.201434E-04  0.263172E-04   0.857338E-05   0.505098E-05
# 3     0.991836E-05  0.213898E-04   0.192109E-04   0.102970E-04
# 4     0.389892E-04  0.324382E-04   0.215984E-04   0.397765E-06
# ..             ...           ...            ...            ...
# 175   0.408086E-05  0.785348E-05   0.404109E-04   0.102970E-04
# 176   0.113767E-04  0.155672E-04   0.185275E-04   0.750663E-05
# 177   0.914202E-06  0.634138E-05  -0.438912E-05  -0.706192E-05
# 178   0.718085E-05  0.171196E-04   0.160901E-04   0.504292E-05
# 179  -0.230858E-04  0.149180E-04   0.338067E-04   0.270026E-04
#
# [180 rows x 13 columns]
# lat_min: 2.500, lat_max: 3.500, lon_min: 33.500, lon_max: 34.500, raw_data_df: (180, 13), annual_df: (12, 7), anom_df: (180, 13)
# Successfully processed coordinate box 5 of 127
#
# =====================================================================
# Processing page 6 of 127: lat1: 2.5, lat2: 3.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Response Status Code: 200
# ['34.500', '35.500']
# ['2.500', '3.500']
# data/ic3prate_34.5-35.5E_2.5-3.5N_n.dat
# data/ic3prate_34.5-35.5E_2.5-3.5N_n__yr.txt
# data/ic3prate_34.5-35.5E_2.5-3.5N_n_a.txt
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  0.2245968E-05  0.5211206E-05  0.2172580E-04  0.2649167E-04
# 1    1837  0.3250000E-05  0.4232143E-05  0.1647581E-04  0.2907500E-04
# 2    1838  0.3366935E-05  0.1075893E-04  0.2015726E-04  0.2879583E-04
# 3    1839  0.5124999E-05  0.6950894E-05  0.1700403E-04  0.3533751E-04
# 4    1840  0.5076612E-05  0.3568965E-05  0.1411694E-04  0.2392500E-04
# ..    ...            ...            ...            ...            ...
# 175  2011  0.1879032E-05  0.6785713E-06  0.1017742E-04  0.7879167E-05
# 176  2012  0.7258063E-07  0.1331896E-05  0.5161290E-05  0.5012917E-04
# 177  2013  0.1967742E-05  0.9687496E-06  0.2395565E-04  0.4347500E-04
# 178  2014  0.5806448E-06  0.3437500E-05  0.2531855E-04  0.1914583E-04
# 179  2015  0.3145160E-06  0.6116070E-06  0.9060484E-05  0.6460832E-04
#
#                May           June           July         August  \
# 0    0.2565323E-04  0.2422917E-04  0.2393549E-04  0.4180241E-04
# 1    0.1964516E-04  0.1684167E-04  0.3170161E-04  0.3597177E-04
# 2    0.1808468E-04  0.3337084E-04  0.3598791E-04  0.3930645E-04
# 3    0.2228226E-04  0.2361667E-04  0.3372984E-04  0.2339919E-04
# 4    0.2326210E-04  0.2934167E-04  0.2891532E-04  0.3732258E-04
# ..             ...            ...            ...            ...
# 175  0.1376210E-04  0.2392500E-04  0.3089919E-04  0.2259677E-04
# 176  0.4639919E-04  0.3370001E-04  0.2774194E-04  0.2408065E-04
# 177  0.2364516E-04  0.3127917E-04  0.2790323E-04  0.1446371E-04
# 178  0.2012500E-04  0.2336250E-04  0.2816532E-04  0.3500807E-04
# 179  0.4319355E-04  0.4455417E-04  0.8250001E-05  0.6459677E-05
#
#          September        October       November       December
# 0    0.4278334E-04  0.2307661E-04  0.1993334E-04  0.4762096E-05
# 1    0.2359167E-04  0.3260888E-04  0.2524583E-04  0.5419354E-05
# 2    0.3827917E-04  0.3116532E-04  0.1571667E-04  0.7270161E-05
# 3    0.2427917E-04  0.2483065E-04  0.2172083E-04  0.1007258E-04
# 4    0.5608333E-04  0.3908065E-04  0.2602917E-04  0.4431452E-05
# ..             ...            ...            ...            ...
# 175  0.2127501E-04  0.1612500E-04  0.4022917E-04  0.9766130E-05
# 176  0.2852501E-04  0.2110887E-04  0.2353333E-04  0.7951612E-05
# 177  0.1667083E-04  0.1307661E-04  0.7975000E-05  0.1346774E-05
# 178  0.2248333E-04  0.1774597E-04  0.2369167E-04  0.7620968E-05
# 179  0.5504168E-05  0.1708871E-04  0.3155000E-04  0.1946775E-04
#
# [180 rows x 13 columns]
# Response Status: 200
#
#         Month          Mean          2.5%           17%           50%  \
# 0     January  0.317735E-05  0.169356E-06  0.639516E-06  0.211693E-05
# 1    February  0.564321E-05  0.571434E-06  0.135937E-05  0.435045E-05
# 2       March  0.139873E-04  0.230648E-05  0.639113E-05  0.130766E-04
# 3       April  0.276755E-04  0.575839E-05  0.158467E-04  0.262292E-04
# 4         May  0.252951E-04  0.778234E-05  0.133649E-04  0.225766E-04
# 5        June  0.271060E-04  0.558339E-05  0.145200E-04  0.260354E-04
# 6        July  0.262279E-04  0.501618E-05  0.127782E-04  0.255444E-04
# 7      August  0.233150E-04  0.402423E-05  0.116145E-04  0.214577E-04
# 8   September  0.202347E-04  0.130835E-05  0.599083E-05  0.147521E-04
# 9     October  0.135155E-04  0.951622E-06  0.449476E-05  0.102540E-04
# 10   November  0.113841E-04  0.958342E-06  0.348792E-05  0.820208E-05
# 11   December  0.456125E-05  0.362907E-06  0.108306E-05  0.340121E-05
#
#              83%         97.5%
# 0   0.585363E-05  0.119515E-04
# 1   0.103728E-04  0.167722E-04
# 2   0.216847E-04  0.292376E-04
# 3   0.391550E-04  0.581994E-04
# 4   0.374855E-04  0.562252E-04
# 5   0.394442E-04  0.561369E-04
# 6   0.369689E-04  0.536527E-04
# 7   0.341214E-04  0.538543E-04
# 8   0.367312E-04  0.737659E-04
# 9   0.217189E-04  0.467576E-04
# 10  0.194800E-04  0.374413E-04
# 11  0.802863E-05  0.132902E-04
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  -0.931384E-06  -0.432005E-06   0.773852E-05  -0.118386E-05
# 1    1837   0.726484E-07  -0.141107E-05   0.248853E-05   0.139947E-05
# 2    1838   0.189583E-06   0.511572E-05   0.616998E-05   0.112030E-05
# 3    1839   0.194765E-05   0.130768E-05   0.301675E-05   0.766198E-05
# 4    1840   0.189926E-05  -0.207425E-05   0.129660E-06  -0.375053E-05
# ..    ...            ...            ...            ...            ...
# 175  2011  -0.129832E-05  -0.496464E-05  -0.380986E-05  -0.197964E-04
# 176  2012  -0.310477E-05  -0.431132E-05  -0.882599E-05   0.224536E-04
# 177  2013  -0.120961E-05  -0.467446E-05   0.996837E-05   0.157995E-04
# 178  2014  -0.259671E-05  -0.220571E-05   0.113313E-04  -0.852970E-05
# 179  2015  -0.286284E-05  -0.503160E-05  -0.492680E-05   0.369328E-04
#
#                May           June           July         August  \
# 0     0.358092E-06  -0.287684E-05  -0.229242E-05   0.184874E-04
# 1    -0.564998E-05  -0.102643E-04   0.547370E-05   0.126568E-04
# 2    -0.721046E-05   0.626483E-05   0.976000E-05   0.159914E-04
# 3    -0.301288E-05  -0.348934E-05   0.750193E-05   0.841865E-07
# 4    -0.203304E-05   0.223566E-05   0.268741E-05   0.140076E-04
# ..             ...            ...            ...            ...
# 175  -0.115330E-04  -0.318101E-05   0.467128E-05  -0.718233E-06
# 176   0.211041E-04   0.659400E-05   0.151403E-05   0.765645E-06
# 177  -0.164998E-05   0.417316E-05   0.167532E-05  -0.885129E-05
# 178  -0.517014E-05  -0.374351E-05   0.193741E-05   0.116931E-04
# 179   0.178984E-04   0.174482E-04  -0.179779E-04  -0.168553E-04
#
#          September        October       November       December
# 0     0.225486E-04   0.956113E-05   0.854927E-05   0.200850E-06
# 1     0.335697E-05   0.190934E-04   0.138618E-04   0.858108E-06
# 2     0.180445E-04   0.176498E-04   0.433260E-05   0.270891E-05
# 3     0.404447E-05   0.113152E-04   0.103368E-04   0.551133E-05
# 4     0.358486E-04   0.255652E-04   0.146451E-04  -0.129794E-06
# ..             ...            ...            ...            ...
# 175   0.104031E-05   0.260952E-05   0.288451E-04   0.520488E-05
# 176   0.829031E-05   0.759339E-05   0.121493E-04   0.339037E-05
# 177  -0.356387E-05  -0.438868E-06  -0.340907E-05  -0.321447E-05
# 178   0.224863E-05   0.423049E-05   0.123076E-04   0.305972E-05
# 179  -0.147305E-04   0.357323E-05   0.201659E-04   0.149065E-04
#
# [180 rows x 13 columns]
# lat_min: 2.500, lat_max: 3.500, lon_min: 34.500, lon_max: 35.500, raw_data_df: (180, 13), annual_df: (12, 7), anom_df: (180, 13)
# Successfully processed coordinate box 6 of 127
#
# =====================================================================
# Processing page 7 of 127: lat1: 2.5, lat2: 3.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# ['35.500', '36.500']
# ['2.500', '3.500']
# data/ic3prate_35.5-36.5E_2.5-3.5N_n.dat
# data/ic3prate_35.5-36.5E_2.5-3.5N_n__yr.txt
# data/ic3prate_35.5-36.5E_2.5-3.5N_n_a.txt
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  0.1270161E-05  0.2107759E-05  0.8431452E-05  0.1282500E-04
# 1    1837  0.1161290E-05  0.1575893E-05  0.6455646E-05  0.1207083E-04
# 2    1838  0.1237903E-05  0.3486608E-05  0.8822581E-05  0.1320833E-04
# 3    1839  0.2411290E-05  0.3022322E-05  0.7532259E-05  0.1750000E-04
# 4    1840  0.2165322E-05  0.1301724E-05  0.5399194E-05  0.1096667E-04
# ..    ...            ...            ...            ...            ...
# 175  2011  0.6653225E-06  0.2142858E-06  0.3548387E-05  0.1416667E-05
# 176  2012  0.6048390E-07  0.3965517E-06  0.4169356E-05  0.3552917E-04
# 177  2013  0.6129032E-06  0.5223217E-06  0.8883065E-05  0.1937916E-04
# 178  2014  0.5241930E-07  0.1388393E-05  0.9879031E-05  0.5033334E-05
# 179  2015  0.2177419E-06  0.1160715E-06  0.4721775E-05  0.3874167E-04
#
#                May           June           July         August  \
# 0    0.1056855E-04  0.9633334E-05  0.1110887E-04  0.2153629E-04
# 1    0.7604840E-05  0.5387500E-05  0.1468548E-04  0.1586291E-04
# 2    0.7459677E-05  0.1720000E-04  0.1727419E-04  0.1991129E-04
# 3    0.8137097E-05  0.9445834E-05  0.1612500E-04  0.7766130E-05
# 4    0.8737903E-05  0.1344167E-04  0.1404839E-04  0.1695565E-04
# ..             ...            ...            ...            ...
# 175  0.3491936E-05  0.6437501E-05  0.9919356E-05  0.6024194E-05
# 176  0.2075000E-04  0.1095833E-04  0.8576611E-05  0.8000002E-05
# 177  0.5278227E-05  0.9954167E-05  0.8657258E-05  0.2987904E-05
# 178  0.4963709E-05  0.5804168E-05  0.7842742E-05  0.1471371E-04
# 179  0.2082661E-04  0.1692917E-04  0.2556451E-05  0.8830648E-06
#
#          September        October       November       December
# 0    0.1984583E-04  0.8213709E-05  0.8533332E-05  0.1951613E-05
# 1    0.8745832E-05  0.1320564E-04  0.1182917E-04  0.2241936E-05
# 2    0.1616666E-04  0.1450403E-04  0.7674999E-05  0.4205645E-05
# 3    0.7470834E-05  0.9133066E-05  0.9395835E-05  0.5052420E-05
# 4    0.2700417E-04  0.1708065E-04  0.1222500E-04  0.1685484E-05
# ..             ...            ...            ...            ...
# 175  0.5741667E-05  0.6604839E-05  0.2160416E-04  0.4032258E-05
# 176  0.7220833E-05  0.5745968E-05  0.9895835E-05  0.2495968E-05
# 177  0.3733333E-05  0.2689516E-05  0.2816667E-05  0.2943549E-06
# 178  0.8100002E-05  0.4032258E-05  0.1054583E-04  0.2580645E-05
# 179  0.9208329E-06  0.4439516E-05  0.1390834E-04  0.8483872E-05
#
# [180 rows x 13 columns]
# Response Status: 200
#
#         Month          Mean          2.5%           17%           50%  \
# 0     January  0.140278E-05  0.483875E-07  0.217742E-06  0.826613E-06
# 1    February  0.222440E-05  0.982153E-07  0.439886E-06  0.158836E-05
# 2       March  0.605952E-05  0.516134E-06  0.198629E-05  0.531855E-05
# 3       April  0.128599E-04  0.141668E-05  0.500333E-05  0.109625E-04
# 4         May  0.990565E-05  0.152824E-05  0.347379E-05  0.695161E-05
# 5        June  0.104684E-04  0.787508E-06  0.328000E-05  0.860000E-05
# 6        July  0.112593E-04  0.842751E-06  0.304919E-05  0.987299E-05
# 7      August  0.908349E-05  0.483876E-06  0.222097E-05  0.710081E-05
# 8   September  0.715335E-05  0.750009E-07  0.851250E-06  0.302708E-05
# 9     October  0.456109E-05  0.153227E-06  0.792339E-06  0.249597E-05
# 10   November  0.507014E-05  0.400004E-06  0.137917E-05  0.306667E-05
# 11   December  0.215325E-05  0.229841E-06  0.461290E-06  0.145565E-05
#
#              83%         97.5%
# 0   0.280968E-05  0.568946E-05
# 1   0.446830E-05  0.705596E-05
# 2   0.100157E-04  0.160603E-04
# 3   0.200167E-04  0.334622E-04
# 4   0.166722E-04  0.298666E-04
# 5   0.171075E-04  0.338788E-04
# 6   0.194056E-04  0.334593E-04
# 7   0.146935E-04  0.316569E-04
# 8   0.131733E-04  0.376288E-04
# 9   0.790766E-05  0.220966E-04
# 10  0.946708E-05  0.205790E-04
# 11  0.404315E-05  0.789105E-05
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  -0.132617E-06  -0.116640E-06   0.237193E-05  -0.348637E-07
# 1    1837  -0.241488E-06  -0.648506E-06   0.396127E-06  -0.789034E-06
# 2    1838  -0.164875E-06   0.126221E-05   0.276306E-05   0.348466E-06
# 3    1839   0.100851E-05   0.797923E-06   0.147274E-05   0.464014E-05
# 4    1840   0.762544E-06  -0.922675E-06  -0.660325E-06  -0.189319E-05
# ..    ...            ...            ...            ...            ...
# 175  2011  -0.737455E-06  -0.201011E-05  -0.251113E-05  -0.114432E-04
# 176  2012  -0.134229E-05  -0.182785E-05  -0.189016E-05   0.226693E-04
# 177  2013  -0.789875E-06  -0.170208E-05   0.282355E-05   0.651930E-05
# 178  2014  -0.135036E-05  -0.836006E-06   0.381951E-05  -0.782653E-05
# 179  2015  -0.118504E-05  -0.210833E-05  -0.133774E-05   0.258818E-04
#
#                May           June           July         August  \
# 0     0.662903E-06  -0.835071E-06  -0.150424E-06   0.124528E-04
# 1    -0.230081E-05  -0.508090E-05   0.342619E-05   0.677942E-05
# 2    -0.244597E-05   0.673160E-05   0.601490E-05   0.108278E-04
# 3    -0.176855E-05  -0.102257E-05   0.486570E-05  -0.131736E-05
# 4    -0.116774E-05   0.297326E-05   0.278910E-05   0.787216E-05
# ..             ...            ...            ...            ...
# 175  -0.641371E-05  -0.403090E-05  -0.133994E-05  -0.305930E-05
# 176   0.108444E-04   0.489925E-06  -0.268268E-05  -0.108349E-05
# 177  -0.462742E-05  -0.514238E-06  -0.260204E-05  -0.609559E-05
# 178  -0.494194E-05  -0.466424E-05  -0.341655E-05   0.563022E-05
# 179   0.109210E-04   0.646077E-05  -0.870284E-05  -0.820043E-05
#
#          September        October       November       December
# 0     0.126925E-04   0.365262E-05   0.346319E-05  -0.201635E-06
# ...
# 178  2014  -0.683343E-05   0.199570E-04  -0.264665E-04   0.951045E-05
# 179  2015  -0.179786E-04  -0.100743E-04  -0.218012E-04  -0.604787E-05
#
#                May           June           July         August  \
# 0     0.252550E-05  -0.974675E-06  -0.728069E-06  -0.404351E-07
# 1     0.205372E-05   0.554491E-06  -0.562746E-06  -0.221887E-06
# 2     0.440856E-05  -0.628842E-06  -0.211940E-06  -0.278338E-06
# 3     0.236824E-05   0.787824E-06   0.420927E-07  -0.665435E-06
# 4    -0.223257E-05   0.433658E-06   0.134835E-06  -0.270274E-06
# ..             ...            ...            ...            ...
# 175  -0.249063E-05  -0.169551E-05  -0.756294E-06  -0.713822E-06
# 176   0.265453E-05   0.354492E-06  -0.631294E-06  -0.778338E-06
# 177  -0.405918E-05  -0.219134E-05  -0.994198E-06  -0.221886E-06
# 178  -0.398257E-05   0.150032E-05  -0.732101E-06  -0.100919E-06
# 179  -0.476079E-05  -0.263718E-05  -0.566778E-06  -0.625112E-06
#
#          September        October       November       December
# 0    -0.541899E-06  -0.212455E-06   0.179749E-04   0.145528E-04
# 1    -0.266899E-06   0.147706E-05   0.104665E-04   0.211738E-04
# 2    -0.429399E-06  -0.938261E-06   0.486236E-05   0.146813E-05
# 3    -0.562732E-06  -0.249875E-05   0.634152E-05   0.259843E-04
# 4    -0.279399E-06   0.364159E-06   0.199582E-04   0.220488E-04
# ..             ...            ...            ...            ...
# 175  -0.960656E-07  -0.193020E-05  -0.613348E-05   0.221939E-04
# 176  -0.100440E-05  -0.381809E-06   0.553319E-05   0.223023E-05
# 177  -0.101273E-05  -0.206729E-05  -0.123585E-04  -0.115802E-04
# 178  -0.291899E-06   0.527142E-05  -0.777514E-05   0.121738E-04
# 179  -0.116690E-05  -0.293020E-05   0.125415E-04   0.393185E-05
#
# [180 rows x 13 columns]
# lat_min: -9.500, lat_max: -8.500, lon_min: 34.500, lon_max: 35.500, raw_data_df: (180, 13), annual_df: (12, 7), anom_df: (180, 13)
# Successfully processed coordinate box 125 of 127
#
# =====================================================================
# Processing page 126 of 127: lat1: -9.5, lat2: -8.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Response Status Code: 200
# ['35.500', '36.500']
# ['-9.500', '-8.500']
# data/ic3prate_35.5-36.5E_-9.5--8.5N_n.dat
# data/ic3prate_35.5-36.5E_-9.5--8.5N_n__yr.txt
# data/ic3prate_35.5-36.5E_-9.5--8.5N_n_a.txt
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  0.7751209E-04  0.6823707E-04  0.5295162E-04  0.2636250E-04
# 1    1837  0.6159274E-04  0.6585268E-04  0.4596370E-04  0.2613333E-04
# 2    1838  0.7079436E-04  0.6502232E-04  0.5562500E-04  0.2707917E-04
# 3    1839  0.7197580E-04  0.6681251E-04  0.6541532E-04  0.3176250E-04
# 4    1840  0.7945564E-04  0.9109911E-04  0.5018547E-04  0.2398750E-04
# ..    ...            ...            ...            ...            ...
# 175  2011  0.3685484E-04  0.7283482E-04  0.5839112E-04  0.4084584E-04
# 176  2012  0.4372984E-04  0.5482759E-04  0.7252824E-04  0.3819999E-04
# 177  2013  0.4373789E-04  0.3594197E-04  0.5503226E-04  0.1802500E-04
# 178  2014  0.3468951E-04  0.7037946E-04  0.3196774E-04  0.2958333E-04
# 179  2015  0.4163306E-04  0.4325446E-04  0.3566129E-04  0.1733333E-04
#
#                May           June           July         August  \
# 0    0.8233871E-05  0.1158333E-05  0.6693549E-06  0.8346773E-06
# 1    0.8254031E-05  0.2033333E-05  0.5725807E-06  0.7459677E-06
# 2    0.9012098E-05  0.1129167E-05  0.8427419E-06  0.6209677E-06
# 3    0.8125002E-05  0.1854167E-05  0.1076613E-05  0.3427420E-06
# 4    0.6262097E-05  0.1941666E-05  0.1217742E-05  0.6048388E-06
# ..             ...            ...            ...            ...
# 175  0.5008064E-05  0.7000000E-06  0.5080645E-06  0.3991936E-06
# 176  0.8342741E-05  0.1591667E-05  0.8185484E-06  0.3669355E-06
# 177  0.4592742E-05  0.5833334E-06  0.5000000E-06  0.5604839E-06
# 178  0.4181452E-05  0.2083333E-05  0.5161291E-06  0.7540324E-06
# 179  0.4745968E-05  0.3416667E-06  0.8911288E-06  0.5282258E-06
#
#          September        October       November       December
# 0    0.5791668E-06  0.2008064E-05  0.1730000E-04  0.4571371E-04
# 1    0.7041668E-06  0.2798387E-05  0.1405833E-04  0.4750403E-04
# 2    0.7125001E-06  0.1838710E-05  0.9770833E-05  0.3348790E-04
# 3    0.5583335E-06  0.1213710E-05  0.1056667E-04  0.5273790E-04
# 4    0.6416667E-06  0.2233871E-05  0.1771250E-04  0.4857662E-04
# ..             ...            ...            ...            ...
# 175  0.9749999E-06  0.1463710E-05  0.4495834E-05  0.3888307E-04
# 176  0.2583334E-06  0.1612903E-05  0.9766668E-05  0.3229436E-04
# 177  0.4791667E-06  0.1955645E-05  0.3637500E-05  0.1417339E-04
# 178  0.8333333E-06  0.3794354E-05  0.5879167E-05  0.3608871E-04
# 179  0.3458334E-06  0.8951611E-06  0.1156250E-04  0.2801210E-04
#
# [180 rows x 13 columns]
# Response Status: 200
#
#         Month          Mean          2.5%           17%           50%  \
# 0     January  0.514640E-04  0.106695E-04  0.243927E-04  0.505585E-04
# 1    February  0.576284E-04  0.831705E-05  0.291013E-04  0.518929E-04
# 2       March  0.508227E-04  0.921784E-05  0.253190E-04  0.454395E-04
# 3       April  0.247048E-04  0.114001E-04  0.175442E-04  0.239292E-04
# 4         May  0.719812E-05  0.211696E-05  0.459395E-05  0.699798E-05
# 5        June  0.163993E-05  0.312503E-06  0.908750E-06  0.149583E-05
# 6        July  0.104563E-05  0.254035E-06  0.608871E-06  0.923387E-06
# 7      August  0.852531E-06  0.193550E-06  0.443548E-06  0.752016E-06
# 8   September  0.104181E-05  0.258336E-06  0.550000E-06  0.941667E-06
# 9     October  0.236729E-05  0.588716E-06  0.118548E-05  0.194355E-05
# 10   November  0.855539E-05  0.163752E-05  0.344875E-05  0.711250E-05
# 11   December  0.336880E-04  0.303229E-05  0.123702E-04  0.296210E-04
#
#              83%         97.5%
# 0   0.771327E-04  0.113745E-03
# 1   0.862643E-04  0.118848E-03
# 2   0.761774E-04  0.110184E-03
# 3   0.307688E-04  0.419621E-04
# 4   0.931048E-05  0.128466E-04
# 5   0.237458E-05  0.364163E-05
# 6   0.149556E-05  0.233465E-05
# 7   0.128185E-05  0.184272E-05
# 8   0.144542E-05  0.236664E-05
# 9   0.364113E-05  0.587898E-05
# 10  0.132975E-04  0.239039E-04
# 11  0.523496E-04  0.898257E-04
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836   0.260481E-04   0.106087E-04   0.212895E-05   0.165771E-05
# 1    1837   0.101287E-04   0.822427E-05  -0.485896E-05   0.142854E-05
# 2    1838   0.193303E-04   0.739392E-05   0.480234E-05   0.237438E-05
# 3    1839   0.205118E-04   0.918410E-05   0.145927E-04   0.705771E-05
# 4    1840   0.279916E-04   0.334707E-04  -0.637196E-06  -0.717288E-06
# ..    ...            ...            ...            ...            ...
# 175  2011  -0.146092E-04   0.152064E-04   0.756845E-05   0.161411E-04
# 176  2012  -0.773418E-05  -0.280081E-05   0.217056E-04   0.134952E-04
# 177  2013  -0.772613E-05  -0.216864E-04   0.420959E-05  -0.667979E-05
# 178  2014  -0.167745E-04   0.127511E-04  -0.188549E-04   0.487854E-05
# 179  2015  -0.983096E-05  -0.143739E-04  -0.151614E-04  -0.737146E-05
#
#                May           June           July         August  \
# 0     0.103576E-05  -0.481597E-06  -0.376277E-06  -0.178541E-07
# 1     0.105592E-05   0.393403E-06  -0.473051E-06  -0.106564E-06
# 2     0.181398E-05  -0.510763E-06  -0.202890E-06  -0.231564E-06
# 3     0.926886E-06   0.214237E-06   0.309811E-07  -0.509789E-06
# 4    -0.936019E-06   0.301736E-06   0.172110E-06  -0.247693E-06
# ..             ...            ...            ...            ...
# 175  -0.219005E-05  -0.939930E-06  -0.537567E-06  -0.453338E-06
# 176   0.114463E-05  -0.482634E-07  -0.227083E-06  -0.485596E-06
# 177  -0.260537E-05  -0.105660E-05  -0.545632E-06  -0.292048E-06
# 178  -0.301666E-05   0.443403E-06  -0.529503E-06  -0.984990E-07
# 179  -0.245215E-05  -0.129826E-05  -0.154503E-06  -0.324306E-06
#
#          September        October       November       December
# 0    -0.462639E-06  -0.359230E-06   0.874461E-05   0.120257E-04
# 1    -0.337639E-06   0.431093E-06   0.550294E-05   0.138160E-04
# 2    -0.329306E-06  -0.528584E-06   0.121544E-05  -0.200089E-06
# 3    -0.483472E-06  -0.115358E-05   0.201128E-05   0.190499E-04
# 4    -0.400139E-06  -0.133423E-06   0.915711E-05   0.148886E-04
# ..             ...            ...            ...            ...
# 175  -0.668057E-07  -0.903584E-06  -0.405956E-05   0.519508E-05
# 176  -0.783472E-06  -0.754391E-06   0.121128E-05  -0.139363E-05
# 177  -0.562639E-06  -0.411649E-06  -0.491789E-05  -0.195146E-04
# 178  -0.208472E-06   0.142706E-05  -0.267622E-05   0.240072E-05
# 179  -0.695972E-06  -0.147213E-05   0.300711E-05  -0.567589E-05
#
# [180 rows x 13 columns]
# lat_min: -9.500, lat_max: -8.500, lon_min: 35.500, lon_max: 36.500, raw_data_df: (180, 13), annual_df: (12, 7), anom_df: (180, 13)
# Successfully processed coordinate box 126 of 127
#
# =====================================================================
# Processing page 127 of 127: lat1: -9.5, lat2: -8.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Response Status Code: 200
# ['36.500', '37.500']
# ['-9.500', '-8.500']
# data/ic3prate_36.5-37.5E_-9.5--8.5N_n.dat
# data/ic3prate_36.5-37.5E_-9.5--8.5N_n__yr.txt
# data/ic3prate_36.5-37.5E_-9.5--8.5N_n_a.txt
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836  0.6121774E-04  0.5874138E-04  0.7486695E-04  0.6190834E-04
# 1    1837  0.5023790E-04  0.6001339E-04  0.7338711E-04  0.7053334E-04
# 2    1838  0.5404033E-04  0.6152233E-04  0.7393145E-04  0.6811249E-04
# 3    1839  0.5454032E-04  0.5590179E-04  0.7701208E-04  0.6718333E-04
# 4    1840  0.5808468E-04  0.7527586E-04  0.7943146E-04  0.6363334E-04
# ..    ...            ...            ...            ...            ...
# 175  2011  0.2817339E-04  0.6325893E-04  0.8888306E-04  0.8692916E-04
# 176  2012  0.2792742E-04  0.4781465E-04  0.8166935E-04  0.5067500E-04
# 177  2013  0.3706855E-04  0.2890625E-04  0.1050968E-03  0.3861666E-04
# 178  2014  0.2093146E-04  0.4255357E-04  0.4581048E-04  0.6072501E-04
# 179  2015  0.2939919E-04  0.3512500E-04  0.7002822E-04  0.4441666E-04
#
#                May           June           July         August  \
# 0    0.2327823E-04  0.4241666E-05  0.3189516E-05  0.4629033E-05
# 1    0.2638710E-04  0.7629167E-05  0.2645161E-05  0.5092742E-05
# 2    0.2758065E-04  0.4245833E-05  0.3665323E-05  0.3862903E-05
# 3    0.2396371E-04  0.5787500E-05  0.4423387E-05  0.3052419E-05
# 4    0.1969758E-04  0.6862500E-05  0.5012097E-05  0.4463710E-05
# ..             ...            ...            ...            ...
# 175  0.2258871E-04  0.4858335E-05  0.2290324E-05  0.3427419E-05
# 176  0.2250403E-04  0.6345833E-05  0.5282259E-05  0.2455645E-05
# 177  0.1615323E-04  0.3566666E-05  0.3221774E-05  0.3979839E-05
# 178  0.1489920E-04  0.9204166E-05  0.3915323E-05  0.7782258E-05
# 179  0.1534274E-04  0.2612500E-05  0.4810483E-05  0.2955645E-05
#
#          September        October       November       December
# 0    0.4350000E-05  0.8500001E-05  0.2570416E-04  0.4058065E-04
# 1    0.5408333E-05  0.8439517E-05  0.2169167E-04  0.4135081E-04
# 2    0.5037500E-05  0.7770162E-05  0.1791250E-04  0.3174194E-04
# 3    0.4966667E-05  0.6596775E-05  0.1709583E-04  0.4504435E-04
# 4    0.5129167E-05  0.9467742E-05  0.2336667E-04  0.4027823E-04
# ..             ...            ...            ...            ...
# 175  0.6720833E-05  0.7161290E-05  0.1008750E-04  0.2933468E-04
# 176  0.3654167E-05  0.1011694E-04  0.2347500E-04  0.4187903E-04
# 177  0.3595833E-05  0.1116935E-04  0.1077917E-04  0.2308064E-04
# 178  0.4808333E-05  0.1131855E-04  0.1277083E-04  0.3037097E-04
# 179  0.2308333E-05  0.5282258E-05  0.1933750E-04  0.2704839E-04
#
# [180 rows x 13 columns]
# Response Status: 200
#
#         Month          Mean          2.5%           17%           50%  \
# 0     January  0.397447E-04  0.104598E-04  0.201665E-04  0.385827E-04
# 1    February  0.491939E-04  0.152933E-04  0.288701E-04  0.475234E-04
# 2       March  0.695117E-04  0.261454E-04  0.500786E-04  0.701613E-04
# 3       April  0.604462E-04  0.354587E-04  0.485679E-04  0.615833E-04
# 4         May  0.219145E-04  0.813718E-05  0.153617E-04  0.215464E-04
# 5        June  0.646486E-05  0.164585E-05  0.415167E-05  0.578125E-05
# 6        July  0.525858E-05  0.214922E-05  0.335242E-05  0.495766E-05
# 7      August  0.540439E-05  0.200405E-05  0.352419E-05  0.509677E-05
# 8   September  0.633331E-05  0.274586E-05  0.419542E-05  0.607083E-05
# 9     October  0.106231E-04  0.391133E-05  0.617298E-05  0.948186E-05
# 10   November  0.175337E-04  0.519588E-05  0.903375E-05  0.163542E-04
# 11   December  0.305571E-04  0.448392E-05  0.128528E-04  0.289536E-04
#
#              83%         97.5%
# 0   0.596956E-04  0.794347E-04
# 1   0.674515E-04  0.102236E-03
# 2   0.869593E-04  0.111358E-03
# 3   0.699063E-04  0.841117E-04
# 4   0.279327E-04  0.383746E-04
# 5   0.918375E-05  0.138957E-04
# 6   0.684919E-05  0.107741E-04
# 7   0.725807E-05  0.103668E-04
# 8   0.827417E-05  0.122749E-04
# 9   0.150093E-04  0.230159E-04
# 10  0.256262E-04  0.356705E-04
# 11  0.474496E-04  0.675679E-04
# Response Status: 200
#
#      Year        January       February          March          April  \
# 0    1836   0.214730E-04   0.954748E-05   0.535523E-05   0.146212E-05
# 1    1837   0.104932E-04   0.108195E-04   0.387539E-05   0.100871E-04
# 2    1838   0.142956E-04   0.123284E-04   0.441973E-05   0.766627E-05
# 3    1839   0.147956E-04   0.670788E-05   0.750036E-05   0.673712E-05
# 4    1840   0.183400E-04   0.260820E-04   0.991974E-05   0.318713E-05
# ..    ...            ...            ...            ...            ...
# 175  2011  -0.115713E-04   0.140650E-04   0.193713E-04   0.264829E-04
# 176  2012  -0.118173E-04  -0.137926E-05   0.121576E-04  -0.977121E-05
# 177  2013  -0.267616E-05  -0.202877E-04   0.355851E-04  -0.218296E-04
# 178  2014  -0.188132E-04  -0.664034E-05  -0.237012E-04   0.278797E-06
# 179  2015  -0.103455E-04  -0.140689E-04   0.516498E-06  -0.160296E-04
#
#                May           June           July         August  \
# 0     0.136371E-05  -0.222320E-05  -0.206906E-05  -0.775358E-06
# 1     0.447259E-05   0.116431E-05  -0.261342E-05  -0.311649E-06
# 2     0.566614E-05  -0.221903E-05  -0.159326E-05  -0.154149E-05
# 3     0.204920E-05  -0.677361E-06  -0.835192E-06  -0.235197E-05
# 4    -0.221694E-05   0.397639E-06  -0.246482E-06  -0.940681E-06
# ..             ...            ...            ...            ...
# 175   0.674196E-06  -0.160653E-05  -0.296826E-05  -0.197697E-05
# 176   0.589514E-06  -0.119028E-06   0.236796E-07  -0.294875E-05
# 177  -0.576129E-05  -0.289820E-05  -0.203681E-05  -0.142455E-05
# 178  -0.701531E-05   0.273931E-05  -0.134326E-05   0.237787E-05
# 179  -0.657177E-05  -0.385236E-05  -0.448096E-06  -0.244875E-05
#
#          September        October       November       December
# 0    -0.198331E-05  -0.212311E-05   0.817041E-05   0.100235E-04
# 1    -0.924977E-06  -0.218360E-05   0.415793E-05   0.107937E-04
# 2    -0.129581E-05  -0.285295E-05   0.378755E-06   0.118484E-05
# 3    -0.136664E-05  -0.402634E-05  -0.437914E-06   0.144873E-04
# 4    -0.120414E-05  -0.115537E-05   0.583293E-05   0.972113E-05
# ..             ...            ...            ...            ...
# 175   0.387523E-06  -0.346183E-05  -0.744624E-05  -0.122242E-05
# 176  -0.267914E-05  -0.506176E-06   0.594126E-05   0.113219E-04
# 177  -0.273748E-05   0.546234E-06  -0.675457E-05  -0.747646E-05
# 178  -0.152498E-05   0.695434E-06  -0.476291E-05  -0.186132E-06
# 179  -0.402498E-05  -0.534086E-05   0.180376E-05  -0.350871E-05
#
# [180 rows x 13 columns]
# lat_min: -9.500, lat_max: -8.500, lon_min: 36.500, lon_max: 37.500, raw_data_df: (180, 13), annual_df: (12, 7), anom_df: (180, 13)
# Successfully processed coordinate box 127 of 127
# Done processing all coordinate boxes.

# %%
all_raw_series_df = concat_format_wide(all_raw_df_list, lat_mins, lat_maxes, lon_mins, lon_maxes)
all_annual_series_df = concat_format_wide(all_annual_df_list, lat_mins, lat_maxes, lon_mins, lon_maxes)
all_anom_series_df = concat_format_wide(all_anom_df_list, lat_mins, lat_maxes, lon_mins, lon_maxes)

# %% [markdown]
# ## Download as .csv

# %% [markdown]
# Run the block below to download all raw monthly data as separate .csv files.

# %%
for df in range(len(all_raw_df_list)):
    # Change the path variable to download to another location
    path = "for_analysis/"
    filename = f"{path}lat={lat_mins[df]}to{lat_maxes[df]}_lon={lon_mins[df]}to{lon_maxes[df]}timeseries_monthly_raw.csv"
    all_raw_df_list[df].to_csv(filename, index=False)

# %% [markdown]
# Run the block below to download all raw annual cycle data as separate .csv files.

# %%
for df in range(len(all_raw_df_list)):
    # Change the path variable to download to another location
    path = "for_analysis/"
    filename = f"{path}lat={lat_mins[df]}to{lat_maxes[df]}_lon={lon_mins[df]}to{lon_maxes[df]}timeseries_annual.csv"
    all_annual_df_list[df].to_csv(filename, index=False)

# %% [markdown]
# Run the block below to download all raw anomaly data as separate .csv files.

# %%
for df in range(len(all_raw_df_list)):
    # Change the path variable to download to another location
    path = "for_analysis/"
    filename = f"{path}lat={lat_mins[df]}to{lat_maxes[df]}_lon={lon_mins[df]}to{lon_maxes[df]}timeseries_monthly_raw.csv"
    all_anom_df_list[df].to_csv(filename, index=False)

# %% [markdown]
# Run the cell below to download the concatenated time series dataframes as separate .csv files.

# %%
path = "for_analysis/"
filename = f"{path}all_timeseries_monthly_raw.csv"
all_raw_series_df.to_csv(filename, index=False)

path = "for_analysis/"
filename = f"{path}all_timeseries_annual_cycle.csv"
all_annual_series_df.to_csv(filename, index=False)

path = "for_analysis/"
filename = f"{path}all_timeseries_anomaly.csv"
all_anom_series_df.to_csv(filename, index=False)

# %% [markdown]
# # get_monthly_station_data

# %% [markdown]
# # Collect KNMI Climate Explorer Monthly Station Data
#
# Written by Cecile Dai
#
# Uses data from https://climexp.knmi.nl/start.cgi?id=someone@somewhere
#
# Given a specified or list of coordinate longitude-latitude ranges, this script will collect all the stations located here, raw monthly, annual cycle, and anomaly data for this range. You may choose to download all this data in separate .csv files, as a single large one, or update an existing file written in the same format.

# %%
 # Imports
import numpy as np
import pandas as pd
import sys

from bs4 import BeautifulSoup
from requests_html import HTMLSession
from pprint import pprint

from bs4 import BeautifulSoup
from pprint import pprint
from urllib.parse import urljoin
import webbrowser
import re

import requests
import datetime
import time

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Submit Coordinate Range
#
# This function creates and submits a form to https://climexp.knmi.nl/selectstation.cgi?id=someone@somewhere with a specified latitude-longitude coordinate range for surface precipitation values.

# %%
# Function to create and submit form with selected latitude and longitude ranges
def get_stations_submit(lat1, lat2, lon1, lon2, session):
    # the data body we want to submit
    data = {}

    # Link to the KNMI page where you select the stations and data to view a monthly time series
    station_link = 'https://climexp.knmi.nl/selectstation.cgi?id=someone@somewhere'

    data["email"] = "someone@somewhere"
    data["climate"] = "precipitation_all"
    data["name"] = ""
    data["num"] = 10
    data["lat"] = ""
    data["lon"] = ""
    data["lat1"] = lat1
    data["lat2"] = lat2
    data["lon1"] = lon1
    data["lon2"] = lon2
    data["list"] = """# lon1 lon2 lat1 lat2 (optional)
    station number (one per line)"""
    data["min"] = 10
    data["sum"] = 1
    data["month"] = -1
    data["yr1"] = ""
    data["yr2"] = ""
    data["dist"] = ""
    data["elevmin"] = ""
    data["elevmax"] = ""

    # print("Submission body:")
    # for key in data.keys():
    #     print(f"{key}: {data[key]}")

    # join the url with the action (form request URL)
    # url = urljoin(station_link, form_details["action"])
    url = urljoin(station_link, 'getstations.cgi')
    res = session.post(url, data=data)

    print(f"Response Status Code: {res.status_code}")

    if res.status_code != 200:
        print(f"Unable to access page. Stopped at lat1: {lat1}, lat2: {lat2}, lon1: {lon1}, lon2: {lon2}")
        return -1

    soup = BeautifulSoup(res.content, "html.parser")

    start = re.search('</div>\n</form>', res.text)
    stop = re.search('</div>\n<div class="col-md-4">', res.text)

    # I will admit this is not the prettiest way to extract the desired text but the pure regex method just wasn't working :(
    limit1 = re.split(', ', str(start.span()))
    limit2 = re.split(', ', str(stop.span()))
    l1 = int(limit1[1].replace(')', ''))
    l2 = int(limit2[0].replace('(', ''))

    # print(res.text[l1:l2])

    relevant_text = res.text[l1:l2]

    return relevant_text

# %% [markdown]
# ### Get Stations
#
# This function parses through the text obtained running the get_station_submit function to retrieve all the climate stations and their information in a dataframe.

# %%
def get_stations_df(text):
    lines = text.replace('\n', '').split('<br>')
        
    header = ["Station Name", "Latitude", "Longitude", "Elevation", "Station Code", "Starting Year", "Ending Year", "Monthly Series Link"]
    station_names = []
    lats = []
    lons = []
    elevs = []
    codes = []
    start_year = []
    end_year = []
    links = []

    stripped_lines = []

    for i in range(len(lines)):
        if len("".join(lines[i].split())) != 0 and i >= 3:
            stripped_lines.append(lines[i])
            # print(lines[i])
        else:
            continue

    for j in range(len(stripped_lines)):
        # Station names
        if j%4 == 0:
            # print(" ".join(stripped_lines[j].split()))
            station_names.append(" ".join(stripped_lines[j].split()))

        # Coordinates and elevation
        elif j%4 == 1:
            latitude = re.search('\s+(.*)N', stripped_lines[j])
            # print(latitude.group(0).strip())
            lats.append(latitude.group(0).strip())

            longitude = re.search(',\s+(.*)E', stripped_lines[j])
            # print(longitude.group(0).replace(',','').strip())
            lons.append(longitude.group(0).replace(',','').strip())

            elevation = re.search('E,\s+(.*m)', stripped_lines[j])
            # print(elevation.group(0).replace("E,", '').strip())
            elevs.append(elevation.group(0).replace("E,", '').strip())

        # Station code and monthly series link
        elif j%4 == 2:
            code = re.search('([0-9\.]+)', stripped_lines[j])
            # print(code.group(0))
            codes.append(code.group(0))

            link = re.search('\"(.*)\"', stripped_lines[j])
            # print(link.group(0).replace('"', ''))
            links.append(link.group(0).replace('"', ''))

        # Data start and end year
        elif j%4 == 3:
            years = re.search('([0-9]{4}\-[0-9]{4})', stripped_lines[j])
            # print(years.group(0))
            # print(years.group(0)[:4])
            # print(years.group(0)[5:])
            start_year.append(years.group(0)[:4])
            end_year.append(years.group(0)[5:])

    data = {'Station Name': station_names, 'Latitude': lats, 'Longitude': lons, 'Elevation': elevs, 'Station Code': codes, 'Starting Year': start_year, 'Ending Year': end_year, 'Monthly Series Link': links}

    df = pd.DataFrame(data)
    # print(df)
    return df

# %% [markdown]
# ### Get All Station Data Links
#
# This function takes a list of climate stations and returns separate lists of dataframes of all the raw monthly, annual cycle, and anomaly data at these stations.

# %%
def get_station_data(links, station_names, codes):

    raw_df_list = []
    annual_df_list = []
    anom_df_list = []

    # Visit all links, use array indices to keep track of stations
    for i in range(len(links)):
        station_data_url = "https://climexp.knmi.nl/" + links[i]
        station_data_name = station_names[i]
        station_data_code = codes[i]
        print("{a} | {b} | {c}".format(a=station_data_name, b=station_data_code, c=station_data_url))
        print("================================================================")

        raw_data_link = "https://climexp.knmi.nl/data/pa" + station_data_code + ".dat"
        annual_cycle_link = "https://climexp.knmi.nl/data/pa"+ station_data_code +"__yr.txt"
        anom_link = "https://climexp.knmi.nl/data/pa"+ station_data_code +"_a.txt"

        print("Station {a} of {b}".format(a = i + 1, b = len(links)))

        visit = requests.get(station_data_url)

        # wait if there is no response (due to timeouts)
        code = requests.head(raw_data_link)
        print("Response Status: {a}\n".format(a=code.status_code))
        if code.status_code != 200:
            print("Issue accessing raw monthly data. Waiting...")
            time.sleep(60)

        datapage = requests.get(raw_data_link)

        # print(datapage.text)
        # raw_data_headers = ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
        raw_data_list = []
        lines = datapage.text.split("\n")
        for line in lines:
            elements = line.split()
            # print(elements)
            if len(elements) == 0:
                continue
            if elements[0] == "#":
                continue
            else:
                # csvline = ','.join(elements)
                # print(csvline)
                raw_data_list.append(elements)
        raw_data_df = pd.DataFrame(raw_data_list, columns = ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
        raw_df_list.append(raw_data_df)
        print(raw_data_df)
        # print("confirm")

        # wait if there is no response (due to timeouts)
        code = requests.head(annual_cycle_link)
        print("Response Status: {a}\n".format(a=code.status_code))
        if code.status_code != 200:
            print("Issue accessing annual cycle data. Waiting...")
            time.sleep(60)

        annualpage = requests.get(annual_cycle_link)
        # print(annualpage.text)
        raw_data_yr_list = []
        lines = annualpage.text.split("\n")
        for line in lines:
            elements = line.split()
            if len(elements) == 0:
                continue
            if elements[0] == "#":
                continue
            else:
                monthint = re.findall('2{1}0{3,4}([1-9]{1}[012]?)01', elements[0])
                # print(monthint)
                if monthint and len(monthint) != 0:
                    elements[0] = datetime.date(1900, int(monthint[0]), 1).strftime('%B')
                    # print(len(elements))
                    # print(elements)
                    raw_data_yr_list.append(elements)
        raw_data_yr_df = pd.DataFrame(raw_data_yr_list, columns = ['Month', 'Mean', '2.5%', '17%', '50%', '83%', '97.5%'])
        annual_df_list.append(raw_data_yr_df)
        print(raw_data_yr_df)
        # print("confirm")

        # wait if there is no response (due to timeouts)
        code = requests.head(anom_link)
        print("Response Status: {a}\n".format(a=code.status_code))
        if code.status_code != 200:
            print("Issue accessing anomaly data. Waiting...")
            time.sleep(60)

        anompage = requests.get(anom_link)
        # print(anompage.text)
        # raw_data_anom_list = {'Year': [], 'January': [], 'February': [], 'March': [], 'April': [], 'May': [], 'June': [], 'July': [], 'August': [], 'September': [], 'October': [], 'November': [], 'December': []}
        raw_data_anom_dict = {}
        raw_data_anom_list = []
        lines = anompage.text.split("\n")
        for line in lines:
            elements = line.split()
            if len(elements) == 0:
                continue
            if elements[0] == "#":
                continue
            else:
                date = re.findall('([0-9]{4})\.([0-9]{4})', elements[0])
                if date and len(date[0]) == 2:
                    if date[0][0] not in raw_data_anom_dict:
                        raw_data_anom_dict[date[0][0]] = {'January': '-999.9', 'February': '-999.9', 'March':'-999.9', 'April': '-999.9', 'May': '-999.9', 'June': '-999.9', 'July': '-999.9', 'August': '-999.9', 'September': '-999.9', 'October': '-999.9', 'November': '-999.9', 'December': '-999.9'}
                    monthint = round((float('0.' + date[0][1]) * 12) + 1)
                    monthint = datetime.date(1900, int(monthint), 1).strftime('%B')
                    raw_data_anom_dict[date[0][0]][monthint] = elements[1]
        for key in raw_data_anom_dict:
            dlist = []
            dlist.append(key)
            for d in raw_data_anom_dict[key]:
                dlist.append(raw_data_anom_dict[key][d])
            raw_data_anom_list.append(dlist)
        raw_data_anom_df = pd.DataFrame(raw_data_anom_list, columns = ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
        anom_df_list.append(raw_data_anom_df)
        print(raw_data_anom_df)
        # print("confirm")
    
    return raw_df_list, annual_df_list, anom_df_list

# %% [markdown]
# ### Get Station Data Separately
#
# The cell below contains functions to obtain the raw, annual cycle, and anomaly data individually given their associated links.

# %%
def get_raw_df(raw_data_link, session):
    # wait if there is no response (due to timeouts)
    # code = requests.head(raw_data_link)
    # print("Response Status: {a}\n".format(a=code.status_code))
    # if code.status_code != 200:
    #     # print("Issue accessing raw monthly data. Waiting...")
    #     # time.sleep(60)
    #     return pd.DataFrame()

    datapage = session.get(raw_data_link)
    # datapage = requests.get(raw_data_link)
    # if datapage.status_code

    # print(datapage)
        
    print("Response Status: {a}\n".format(a=datapage.status_code))
    if datapage.status_code != 200:
        return pd.DataFrame()

    # print(datapage.text)
    # raw_data_headers = ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    raw_data_list = []
    lines = datapage.text.split("\n")
    for line in lines:
        elements = line.split()
        # print(elements)
        if len(elements) == 0:
            continue
        if elements[0] == "#":
            continue
        else:
            # csvline = ','.join(elements)
            # print(csvline)
            raw_data_list.append(elements)
    raw_data_df = pd.DataFrame(raw_data_list, columns=['Year', 'January', 'February', 'March', 'April', 'May', 'June',
                                                       'July', 'August', 'September', 'October', 'November',
                                                       'December'])
    # print(raw_data_df)
    # print("confirm")
    return raw_data_df


def get_annual_df(annual_cycle_link, session):
    # wait if there is no response (due to timeouts)
    # code = requests.head(annual_cycle_link)
    # print("Response Status: {a}\n".format(a=code.status_code))
    # if code.status_code != 200:
    #     # print("Issue accessing annual cycle data. Waiting...")
    #     # time.sleep(60)
    #     return pd.DataFrame()

    annualpage = session.get(annual_cycle_link)

    print("Response Status: {a}\n".format(a=annualpage.status_code))
    if annualpage.status_code != 200:
        return pd.DataFrame()

    # annualpage = requests.get(annual_cycle_link)
    # print(annualpage.text)
    raw_data_yr_list = []
    lines = annualpage.text.split("\n")
    for line in lines:
        elements = line.split()
        if len(elements) == 0:
            continue
        if elements[0] == "#":
            continue
        else:
            monthint = re.findall('2{1}0{3,4}([1-9]{1}[012]?)01', elements[0])
            # print(monthint)
            if monthint and len(monthint) != 0:
                elements[0] = datetime.date(1900, int(monthint[0]), 1).strftime('%B')
                # print(len(elements))
                # print(elements)
                raw_data_yr_list.append(elements)
    raw_data_yr_df = pd.DataFrame(raw_data_yr_list, columns=['Month', 'Mean', '2.5%', '17%', '50%', '83%', '97.5%'])
    # print(raw_data_yr_df)
    # print("confirm")
    return raw_data_yr_df


def get_anom_df(anom_link, session):
    # wait if there is no response (due to timeouts)
    # code = requests.head(anom_link)
    # print("Response Status: {a}\n".format(a=code.status_code))
    # if code.status_code != 200:
    #     # print("Issue accessing anomaly data. Waiting...")
    #     # time.sleep(60)
    #     return pd.DataFrame()

    anompage = session.get(anom_link)

    print("Response Status: {a}\n".format(a=anompage.status_code))
    if anompage.status_code != 200:
        return pd.DataFrame()

    # anompage = requests.get(anom_link)
    # print(anompage.text)
    # raw_data_anom_list = {'Year': [], 'January': [], 'February': [], 'March': [], 'April': [], 'May': [], 'June': [], 'July': [], 'August': [], 'September': [], 'October': [], 'November': [], 'December': []}
    raw_data_anom_dict = {}
    raw_data_anom_list = []
    lines = anompage.text.split("\n")
    for line in lines:
        elements = line.split()
        if len(elements) == 0:
            continue
        if elements[0] == "#":
            continue
        else:
            date = re.findall('([0-9]{4})\.([0-9]{4})', elements[0])
            if date and len(date[0]) == 2:
                # Not all months included
                if date[0][0] not in raw_data_anom_dict:
                    # Initialize with invalid numbers
                    raw_data_anom_dict[date[0][0]] = {'January': '-999.9', 'February': '-999.9', 'March': '-999.9',
                                                      'April': '-999.9', 'May': '-999.9', 'June': '-999.9',
                                                      'July': '-999.9', 'August': '-999.9', 'September': '-999.9',
                                                      'October': '-999.9', 'November': '-999.9', 'December': '-999.9'}
                monthint = round((float('0.' + date[0][1]) * 12) + 1)   # Multiply by 12 to get the actual month integer
                monthint = datetime.date(1900, int(monthint), 1).strftime('%B')
                raw_data_anom_dict[date[0][0]][monthint] = elements[1]
    for key in raw_data_anom_dict:
        dlist = []
        dlist.append(key)
        for d in raw_data_anom_dict[key]:
            dlist.append(raw_data_anom_dict[key][d])
        raw_data_anom_list.append(dlist)
    raw_data_anom_df = pd.DataFrame(raw_data_anom_list, columns=['Year', 'January', 'February', 'March', 'April', 'May',
                                                                 'June', 'July', 'August', 'September', 'October',
                                                                 'November', 'December'])
    return raw_data_anom_df

# %% [markdown]
# ### Dataframe Compiler
#
# This function concatenates a list of dataframes of the same format into a single large dataframe, adding their associated station names for each as a new identifier column.

# %%
# Reformats all the dataframes in the input list and adds station codes. Note that this assumes that everything was processed in the same order.
def concat_format_wide(df_list, station_list, existing_file=''):
    full_list_df = []
    dfs = []    #list of dataframes to concatenate
    for station_df in range(len(station_list)):
        codes = [station_list[station_df] for row in range(df_list[station_df].shape[0])]
        new_df = df_list[station_df].copy()
        new_df.insert(0, 'Station', codes)
        dfs.append(new_df)
    if len(existing_file) != 0:
        existing_df = pd.read_csv(existing_file)
        # Check if this data already exists in the file, remove from list to be concatenated if so
        for station in range(len(station_list)):
            if not existing_df.loc(station_list[station]):
                dfs.remove(dfs[station])
        dfs.append(existing_df)
    full_list_df = pd.concat(dfs)
    return full_list_df
    # print(full_raw_list)

# %% [markdown]
# ## Run Functions
# Run the functions on the data to analyze, create and/or update the files with the desired data.
#
# Upload Coordinate Boxes to Analyze

# %%
coordinates = pd.read_csv("for_analysis/BoxCoordinates.csv")
print(coordinates)
# Out:
#      Lat min  Lat max  Long min  Long max
# 0        2.5      3.5      29.5      30.5
# 1        2.5      3.5      30.5      31.5
# 2        2.5      3.5      31.5      32.5
# 3        2.5      3.5      32.5      33.5
# 4        2.5      3.5      33.5      34.5
# ..       ...      ...       ...       ...
# 122     -9.5     -8.5      32.5      33.5
# 123     -9.5     -8.5      33.5      34.5
# 124     -9.5     -8.5      34.5      35.5
# 125     -9.5     -8.5      35.5      36.5
# 126     -9.5     -8.5      36.5      37.5
#
# [127 rows x 4 columns]

# %% [markdown]
# Start session and submit data.

# %%
# initialize HTTP session so data/cookies are persisted
session = HTMLSession()

stations_df_list = []

for index in range(coordinates.shape[0]):
    lat1 = coordinates.iloc[index]["Lat min"]
    lat2 = coordinates.iloc[index]["Lat max"]
    lon1 = coordinates.iloc[index]["Long min"]
    lon2 = coordinates.iloc[index]["Long max"]

    print(f"Processing page {index + 1} of {coordinates.shape[0]}: lat1: {lat1}, lat2: {lat2}, lon1: {lon1}, lon2: {lon2}")

    pagetext = get_stations_submit(lat1, lat2, lon1, lon2, session)
    # print(pagetext)

    if pagetext == -1:
        print(f"Bad response. Ending loop on index {index}...")
        break
    else:
        print("Success")
        df = get_stations_df(pagetext)
        stations_df_list.append(df)
    
print("Done getting station data.")
# Out:
# Processing page 1 of 127: lat1: 2.5, lat2: 3.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 2 of 127: lat1: 2.5, lat2: 3.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 3 of 127: lat1: 2.5, lat2: 3.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 4 of 127: lat1: 2.5, lat2: 3.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 5 of 127: lat1: 2.5, lat2: 3.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 6 of 127: lat1: 2.5, lat2: 3.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 7 of 127: lat1: 2.5, lat2: 3.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 8 of 127: lat1: 2.5, lat2: 3.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 9 of 127: lat1: 1.5, lat2: 2.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 10 of 127: lat1: 1.5, lat2: 2.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 11 of 127: lat1: 1.5, lat2: 2.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 12 of 127: lat1: 1.5, lat2: 2.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 13 of 127: lat1: 1.5, lat2: 2.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 14 of 127: lat1: 1.5, lat2: 2.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 15 of 127: lat1: 1.5, lat2: 2.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 16 of 127: lat1: 1.5, lat2: 2.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 17 of 127: lat1: 0.5, lat2: 1.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Success
# Processing page 18 of 127: lat1: 0.5, lat2: 1.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 19 of 127: lat1: 0.5, lat2: 1.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 20 of 127: lat1: 0.5, lat2: 1.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 21 of 127: lat1: 0.5, lat2: 1.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 22 of 127: lat1: 0.5, lat2: 1.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 23 of 127: lat1: 0.5, lat2: 1.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 24 of 127: lat1: 0.5, lat2: 1.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 25 of 127: lat1: 0.5, lat2: 1.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 26 of 127: lat1: -0.5, lat2: 0.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Success
# Processing page 27 of 127: lat1: -0.5, lat2: 0.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 28 of 127: lat1: -0.5, lat2: 0.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 29 of 127: lat1: -0.5, lat2: 0.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 30 of 127: lat1: -0.5, lat2: 0.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 31 of 127: lat1: -0.5, lat2: 0.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 32 of 127: lat1: -0.5, lat2: 0.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 33 of 127: lat1: -0.5, lat2: 0.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 34 of 127: lat1: -0.5, lat2: 0.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 35 of 127: lat1: -1.5, lat2: -0.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Success
# Processing page 36 of 127: lat1: -1.5, lat2: -0.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 37 of 127: lat1: -1.5, lat2: -0.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 38 of 127: lat1: -1.5, lat2: -0.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 39 of 127: lat1: -1.5, lat2: -0.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 40 of 127: lat1: -1.5, lat2: -0.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 41 of 127: lat1: -1.5, lat2: -0.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 42 of 127: lat1: -1.5, lat2: -0.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 43 of 127: lat1: -1.5, lat2: -0.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 44 of 127: lat1: -2.5, lat2: -1.5, lon1: 27.5, lon2: 28.5
# Response Status Code: 200
# Success
# Processing page 45 of 127: lat1: -2.5, lat2: -1.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Success
# Processing page 46 of 127: lat1: -2.5, lat2: -1.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 47 of 127: lat1: -2.5, lat2: -1.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 48 of 127: lat1: -2.5, lat2: -1.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 49 of 127: lat1: -2.5, lat2: -1.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 50 of 127: lat1: -2.5, lat2: -1.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 51 of 127: lat1: -2.5, lat2: -1.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 52 of 127: lat1: -2.5, lat2: -1.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 53 of 127: lat1: -2.5, lat2: -1.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 54 of 127: lat1: -3.5, lat2: -2.5, lon1: 27.5, lon2: 28.5
# Response Status Code: 200
# Success
# Processing page 55 of 127: lat1: -3.5, lat2: -2.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Success
# Processing page 56 of 127: lat1: -3.5, lat2: -2.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 57 of 127: lat1: -3.5, lat2: -2.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 58 of 127: lat1: -3.5, lat2: -2.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 59 of 127: lat1: -3.5, lat2: -2.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 60 of 127: lat1: -3.5, lat2: -2.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 61 of 127: lat1: -3.5, lat2: -2.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 62 of 127: lat1: -3.5, lat2: -2.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 63 of 127: lat1: -3.5, lat2: -2.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 64 of 127: lat1: -4.5, lat2: -3.5, lon1: 27.5, lon2: 28.5
# Response Status Code: 200
# Success
# Processing page 65 of 127: lat1: -4.5, lat2: -3.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Success
# Processing page 66 of 127: lat1: -4.5, lat2: -3.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 67 of 127: lat1: -4.5, lat2: -3.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 68 of 127: lat1: -4.5, lat2: -3.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 69 of 127: lat1: -4.5, lat2: -3.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 70 of 127: lat1: -4.5, lat2: -3.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 71 of 127: lat1: -4.5, lat2: -3.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 72 of 127: lat1: -4.5, lat2: -3.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 73 of 127: lat1: -4.5, lat2: -3.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 74 of 127: lat1: -5.5, lat2: -4.5, lon1: 24.5, lon2: 25.5
# Response Status Code: 200
# Success
# Processing page 75 of 127: lat1: -5.5, lat2: -4.5, lon1: 25.5, lon2: 26.5
# Response Status Code: 200
# Success
# Processing page 76 of 127: lat1: -5.5, lat2: -4.5, lon1: 26.5, lon2: 27.5
# Response Status Code: 200
# Success
# Processing page 77 of 127: lat1: -5.5, lat2: -4.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Success
# Processing page 78 of 127: lat1: -5.5, lat2: -4.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 79 of 127: lat1: -5.5, lat2: -4.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 80 of 127: lat1: -5.5, lat2: -4.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 81 of 127: lat1: -5.5, lat2: -4.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 82 of 127: lat1: -5.5, lat2: -4.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 83 of 127: lat1: -5.5, lat2: -4.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 84 of 127: lat1: -5.5, lat2: -4.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 85 of 127: lat1: -5.5, lat2: -4.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 86 of 127: lat1: -6.5, lat2: -5.5, lon1: 24.5, lon2: 25.5
# Response Status Code: 200
# Success
# Processing page 87 of 127: lat1: -6.5, lat2: -5.5, lon1: 25.5, lon2: 26.5
# Response Status Code: 200
# Success
# Processing page 88 of 127: lat1: -6.5, lat2: -5.5, lon1: 26.5, lon2: 27.5
# Response Status Code: 200
# Success
# Processing page 89 of 127: lat1: -6.5, lat2: -5.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Success
# Processing page 90 of 127: lat1: -6.5, lat2: -5.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 91 of 127: lat1: -6.5, lat2: -5.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 92 of 127: lat1: -6.5, lat2: -5.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 93 of 127: lat1: -6.5, lat2: -5.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 94 of 127: lat1: -6.5, lat2: -5.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 95 of 127: lat1: -6.5, lat2: -5.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 96 of 127: lat1: -6.5, lat2: -5.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 97 of 127: lat1: -6.5, lat2: -5.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 98 of 127: lat1: -7.5, lat2: -6.5, lon1: 26.5, lon2: 27.5
# Response Status Code: 200
# Success
# Processing page 99 of 127: lat1: -7.5, lat2: -6.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Success
# Processing page 100 of 127: lat1: -7.5, lat2: -6.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 101 of 127: lat1: -7.5, lat2: -6.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 102 of 127: lat1: -7.5, lat2: -6.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 103 of 127: lat1: -7.5, lat2: -6.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 104 of 127: lat1: -7.5, lat2: -6.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 105 of 127: lat1: -7.5, lat2: -6.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 106 of 127: lat1: -7.5, lat2: -6.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 107 of 127: lat1: -7.5, lat2: -6.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 108 of 127: lat1: -8.5, lat2: -7.5, lon1: 26.5, lon2: 27.5
# Response Status Code: 200
# Success
# Processing page 109 of 127: lat1: -8.5, lat2: -7.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Success
# Processing page 110 of 127: lat1: -8.5, lat2: -7.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 111 of 127: lat1: -8.5, lat2: -7.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 112 of 127: lat1: -8.5, lat2: -7.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 113 of 127: lat1: -8.5, lat2: -7.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 114 of 127: lat1: -8.5, lat2: -7.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 115 of 127: lat1: -8.5, lat2: -7.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 116 of 127: lat1: -8.5, lat2: -7.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 117 of 127: lat1: -8.5, lat2: -7.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Processing page 118 of 127: lat1: -9.5, lat2: -8.5, lon1: 26.5, lon2: 27.5
# Response Status Code: 200
# Success
# Processing page 119 of 127: lat1: -9.5, lat2: -8.5, lon1: 28.5, lon2: 29.5
# Response Status Code: 200
# Success
# Processing page 120 of 127: lat1: -9.5, lat2: -8.5, lon1: 29.5, lon2: 30.5
# Response Status Code: 200
# Success
# Processing page 121 of 127: lat1: -9.5, lat2: -8.5, lon1: 30.5, lon2: 31.5
# Response Status Code: 200
# Success
# Processing page 122 of 127: lat1: -9.5, lat2: -8.5, lon1: 31.5, lon2: 32.5
# Response Status Code: 200
# Success
# Processing page 123 of 127: lat1: -9.5, lat2: -8.5, lon1: 32.5, lon2: 33.5
# Response Status Code: 200
# Success
# Processing page 124 of 127: lat1: -9.5, lat2: -8.5, lon1: 33.5, lon2: 34.5
# Response Status Code: 200
# Success
# Processing page 125 of 127: lat1: -9.5, lat2: -8.5, lon1: 34.5, lon2: 35.5
# Response Status Code: 200
# Success
# Processing page 126 of 127: lat1: -9.5, lat2: -8.5, lon1: 35.5, lon2: 36.5
# Response Status Code: 200
# Success
# Processing page 127 of 127: lat1: -9.5, lat2: -8.5, lon1: 36.5, lon2: 37.5
# Response Status Code: 200
# Success
# Done getting station data.

# %% [markdown]
# Run cell below to save all stations in the specified coordinate ranges to a .csv file.

# %%
path = "for_analysis/"
filename = f"{path}box_coordinate_stations.csv"
all_stations = pd.concat(stations_df_list)
all_stations.to_csv(filename, index=False)

# %% [markdown]
# Get data from all stations in coordinate range.

# %%
all_raw_df_list = []
all_annual_df_list = []
all_anom_df_list = []

# %%
for station in range(all_stations.shape[0]): #all_stations.shape[0]
    station_data_code = all_stations.iloc[station]["Station Code"]
    raw_data_link = "https://climexp.knmi.nl/data/pa" + station_data_code + ".dat"
    annual_cycle_link = "https://climexp.knmi.nl/data/pa"+ station_data_code +"__yr.txt"
    anom_link = "https://climexp.knmi.nl/data/pa"+ station_data_code +"_a.txt"
    page_link = "https://climexp.knmi.nl/" + all_stations.iloc[station]["Monthly Series Link"]

    print(f'Now processing station {index} of {all_stations.shape[0]}...')
    print(raw_data_link)
    print(annual_cycle_link)
    print(anom_link)
    print('')

    visit_page = session.get(page_link)

    raw_df = get_raw_df(raw_data_link, session)
    if raw_df.empty:
        print(f"Problem retrieving raw monthly data. Ending on loop {station}...")
        break
    all_raw_df_list.append(raw_df)
    
    annual_df = get_annual_df(annual_cycle_link, session)
    if annual_df.empty:
        print(f"Problem retrieving annual cycle data. Ending on loop {station}...")
        break
    all_annual_df_list.append(annual_df)
    
    anom_df = get_anom_df(anom_link, session)
    if anom_df.empty:
        print(f"Problem retrieving anomaly data. Ending on loop {station}...")
        break
    all_anom_df_list.append(anom_df)

print("Done retrieving data from all stations.")
print(f"Raw DF List: {len(all_raw_df_list)} of {all_stations.shape[0]}\nAnnual Cycle DF List: {len(all_annual_df_list)} of {all_stations.shape[0]}\nAnomaly DF List: {len(all_anom_df_list)} of {all_stations.shape[0]}\n")
# Out:
# Now processing...
# https://climexp.knmi.nl/data/pa63630.1.dat
# https://climexp.knmi.nl/data/pa63630.1__yr.txt
# https://climexp.knmi.nl/data/pa63630.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63630.5.dat
# https://climexp.knmi.nl/data/pa63630.5__yr.txt
# https://climexp.knmi.nl/data/pa63630.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63658.3.dat
# https://climexp.knmi.nl/data/pa63658.3__yr.txt
# https://climexp.knmi.nl/data/pa63658.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63612.dat
# https://climexp.knmi.nl/data/pa63612__yr.txt
# https://climexp.knmi.nl/data/pa63612_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63628.1.dat
# https://climexp.knmi.nl/data/pa63628.1__yr.txt
# https://climexp.knmi.nl/data/pa63628.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63654.1.dat
# https://climexp.knmi.nl/data/pa63654.1__yr.txt
# https://climexp.knmi.nl/data/pa63654.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64077.1.dat
# https://climexp.knmi.nl/data/pa64077.1__yr.txt
# https://climexp.knmi.nl/data/pa64077.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64077.2.dat
# https://climexp.knmi.nl/data/pa64077.2__yr.txt
# https://climexp.knmi.nl/data/pa64077.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64077.3.dat
# https://climexp.knmi.nl/data/pa64077.3__yr.txt
# https://climexp.knmi.nl/data/pa64077.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63654.dat
# https://climexp.knmi.nl/data/pa63654__yr.txt
# https://climexp.knmi.nl/data/pa63654_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63630.2.dat
# https://climexp.knmi.nl/data/pa63630.2__yr.txt
# https://climexp.knmi.nl/data/pa63630.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63658.4.dat
# https://climexp.knmi.nl/data/pa63658.4__yr.txt
# https://climexp.knmi.nl/data/pa63658.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63658.9.dat
# https://climexp.knmi.nl/data/pa63658.9__yr.txt
# https://climexp.knmi.nl/data/pa63658.9_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63658.1.dat
# https://climexp.knmi.nl/data/pa63658.1__yr.txt
# https://climexp.knmi.nl/data/pa63658.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63658.2.dat
# https://climexp.knmi.nl/data/pa63658.2__yr.txt
# https://climexp.knmi.nl/data/pa63658.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63658.5.dat
# https://climexp.knmi.nl/data/pa63658.5__yr.txt
# https://climexp.knmi.nl/data/pa63658.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63674.2.dat
# https://climexp.knmi.nl/data/pa63674.2__yr.txt
# https://climexp.knmi.nl/data/pa63674.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63674.6.dat
# https://climexp.knmi.nl/data/pa63674.6__yr.txt
# https://climexp.knmi.nl/data/pa63674.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63674.7.dat
# https://climexp.knmi.nl/data/pa63674.7__yr.txt
# https://climexp.knmi.nl/data/pa63674.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63674.8.dat
# https://climexp.knmi.nl/data/pa63674.8__yr.txt
# https://climexp.knmi.nl/data/pa63674.8_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63654.3.dat
# https://climexp.knmi.nl/data/pa63654.3__yr.txt
# https://climexp.knmi.nl/data/pa63654.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63654.2.dat
# https://climexp.knmi.nl/data/pa63654.2__yr.txt
# https://climexp.knmi.nl/data/pa63654.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63682.1.dat
# https://climexp.knmi.nl/data/pa63682.1__yr.txt
# https://climexp.knmi.nl/data/pa63682.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63682.2.dat
# https://climexp.knmi.nl/data/pa63682.2__yr.txt
# https://climexp.knmi.nl/data/pa63682.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63682.4.dat
# https://climexp.knmi.nl/data/pa63682.4__yr.txt
# https://climexp.knmi.nl/data/pa63682.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63684.5.dat
# https://climexp.knmi.nl/data/pa63684.5__yr.txt
# https://climexp.knmi.nl/data/pa63684.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63684.7.dat
# https://climexp.knmi.nl/data/pa63684.7__yr.txt
# https://climexp.knmi.nl/data/pa63684.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63658.8.dat
# https://climexp.knmi.nl/data/pa63658.8__yr.txt
# https://climexp.knmi.nl/data/pa63658.8_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63684.dat
# https://climexp.knmi.nl/data/pa63684__yr.txt
# https://climexp.knmi.nl/data/pa63684_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63684.1.dat
# https://climexp.knmi.nl/data/pa63684.1__yr.txt
# https://climexp.knmi.nl/data/pa63684.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63661.dat
# https://climexp.knmi.nl/data/pa63661__yr.txt
# https://climexp.knmi.nl/data/pa63661_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63661.1.dat
# https://climexp.knmi.nl/data/pa63661.1__yr.txt
# https://climexp.knmi.nl/data/pa63661.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63661.2.dat
# https://climexp.knmi.nl/data/pa63661.2__yr.txt
# https://climexp.knmi.nl/data/pa63661.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63661.3.dat
# https://climexp.knmi.nl/data/pa63661.3__yr.txt
# https://climexp.knmi.nl/data/pa63661.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63661.4.dat
# https://climexp.knmi.nl/data/pa63661.4__yr.txt
# https://climexp.knmi.nl/data/pa63661.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63687.5.dat
# https://climexp.knmi.nl/data/pa63687.5__yr.txt
# https://climexp.knmi.nl/data/pa63687.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63686.2.dat
# https://climexp.knmi.nl/data/pa63686.2__yr.txt
# https://climexp.knmi.nl/data/pa63686.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63686.5.dat
# https://climexp.knmi.nl/data/pa63686.5__yr.txt
# https://climexp.knmi.nl/data/pa63686.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63695.2.dat
# https://climexp.knmi.nl/data/pa63695.2__yr.txt
# https://climexp.knmi.nl/data/pa63695.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64072.1.dat
# https://climexp.knmi.nl/data/pa64072.1__yr.txt
# https://climexp.knmi.nl/data/pa64072.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63674.dat
# https://climexp.knmi.nl/data/pa63674__yr.txt
# https://climexp.knmi.nl/data/pa63674_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63674.3.dat
# https://climexp.knmi.nl/data/pa63674.3__yr.txt
# https://climexp.knmi.nl/data/pa63674.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63674.9.dat
# https://climexp.knmi.nl/data/pa63674.9__yr.txt
# https://climexp.knmi.nl/data/pa63674.9_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63705.1.dat
# https://climexp.knmi.nl/data/pa63705.1__yr.txt
# https://climexp.knmi.nl/data/pa63705.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63705.2.dat
# https://climexp.knmi.nl/data/pa63705.2__yr.txt
# https://climexp.knmi.nl/data/pa63705.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63705.3.dat
# https://climexp.knmi.nl/data/pa63705.3__yr.txt
# https://climexp.knmi.nl/data/pa63705.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63705.4.dat
# https://climexp.knmi.nl/data/pa63705.4__yr.txt
# https://climexp.knmi.nl/data/pa63705.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63680.dat
# https://climexp.knmi.nl/data/pa63680__yr.txt
# https://climexp.knmi.nl/data/pa63680_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63680.3.dat
# https://climexp.knmi.nl/data/pa63680.3__yr.txt
# https://climexp.knmi.nl/data/pa63680.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63680.7.dat
# https://climexp.knmi.nl/data/pa63680.7__yr.txt
# https://climexp.knmi.nl/data/pa63680.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63682.dat
# https://climexp.knmi.nl/data/pa63682__yr.txt
# https://climexp.knmi.nl/data/pa63682_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63682.3.dat
# https://climexp.knmi.nl/data/pa63682.3__yr.txt
# https://climexp.knmi.nl/data/pa63682.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63684.3.dat
# https://climexp.knmi.nl/data/pa63684.3__yr.txt
# https://climexp.knmi.nl/data/pa63684.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63684.4.dat
# https://climexp.knmi.nl/data/pa63684.4__yr.txt
# https://climexp.knmi.nl/data/pa63684.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63684.8.dat
# https://climexp.knmi.nl/data/pa63684.8__yr.txt
# https://climexp.knmi.nl/data/pa63684.8_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63708.3.dat
# https://climexp.knmi.nl/data/pa63708.3__yr.txt
# https://climexp.knmi.nl/data/pa63708.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63684.2.dat
# https://climexp.knmi.nl/data/pa63684.2__yr.txt
# https://climexp.knmi.nl/data/pa63684.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63687.1.dat
# https://climexp.knmi.nl/data/pa63687.1__yr.txt
# https://climexp.knmi.nl/data/pa63687.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63687.3.dat
# https://climexp.knmi.nl/data/pa63687.3__yr.txt
# https://climexp.knmi.nl/data/pa63687.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63687.4.dat
# https://climexp.knmi.nl/data/pa63687.4__yr.txt
# https://climexp.knmi.nl/data/pa63687.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63687.6.dat
# https://climexp.knmi.nl/data/pa63687.6__yr.txt
# https://climexp.knmi.nl/data/pa63687.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63687.7.dat
# https://climexp.knmi.nl/data/pa63687.7__yr.txt
# https://climexp.knmi.nl/data/pa63687.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63708.dat
# https://climexp.knmi.nl/data/pa63708__yr.txt
# https://climexp.knmi.nl/data/pa63708_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63708.4.dat
# https://climexp.knmi.nl/data/pa63708.4__yr.txt
# https://climexp.knmi.nl/data/pa63708.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63708.5.dat
# https://climexp.knmi.nl/data/pa63708.5__yr.txt
# https://climexp.knmi.nl/data/pa63708.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63710.1.dat
# https://climexp.knmi.nl/data/pa63710.1__yr.txt
# https://climexp.knmi.nl/data/pa63710.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63714.dat
# https://climexp.knmi.nl/data/pa63714__yr.txt
# https://climexp.knmi.nl/data/pa63714_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63714.1.dat
# https://climexp.knmi.nl/data/pa63714.1__yr.txt
# https://climexp.knmi.nl/data/pa63714.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63714.2.dat
# https://climexp.knmi.nl/data/pa63714.2__yr.txt
# https://climexp.knmi.nl/data/pa63714.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63714.3.dat
# https://climexp.knmi.nl/data/pa63714.3__yr.txt
# https://climexp.knmi.nl/data/pa63714.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63714.4.dat
# https://climexp.knmi.nl/data/pa63714.4__yr.txt
# https://climexp.knmi.nl/data/pa63714.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63714.6.dat
# https://climexp.knmi.nl/data/pa63714.6__yr.txt
# https://climexp.knmi.nl/data/pa63714.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63714.7.dat
# https://climexp.knmi.nl/data/pa63714.7__yr.txt
# https://climexp.knmi.nl/data/pa63714.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63714.8.dat
# https://climexp.knmi.nl/data/pa63714.8__yr.txt
# https://climexp.knmi.nl/data/pa63714.8_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63714.5.dat
# https://climexp.knmi.nl/data/pa63714.5__yr.txt
# https://climexp.knmi.nl/data/pa63714.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63717.1.dat
# https://climexp.knmi.nl/data/pa63717.1__yr.txt
# https://climexp.knmi.nl/data/pa63717.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63717.2.dat
# https://climexp.knmi.nl/data/pa63717.2__yr.txt
# https://climexp.knmi.nl/data/pa63717.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63717.5.dat
# https://climexp.knmi.nl/data/pa63717.5__yr.txt
# https://climexp.knmi.nl/data/pa63717.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63717.7.dat
# https://climexp.knmi.nl/data/pa63717.7__yr.txt
# https://climexp.knmi.nl/data/pa63717.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63717.9.dat
# https://climexp.knmi.nl/data/pa63717.9__yr.txt
# https://climexp.knmi.nl/data/pa63717.9_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63720.5.dat
# https://climexp.knmi.nl/data/pa63720.5__yr.txt
# https://climexp.knmi.nl/data/pa63720.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63720.6.dat
# https://climexp.knmi.nl/data/pa63720.6__yr.txt
# https://climexp.knmi.nl/data/pa63720.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63726.dat
# https://climexp.knmi.nl/data/pa63726__yr.txt
# https://climexp.knmi.nl/data/pa63726_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63702.1.dat
# https://climexp.knmi.nl/data/pa63702.1__yr.txt
# https://climexp.knmi.nl/data/pa63702.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63702.dat
# https://climexp.knmi.nl/data/pa63702__yr.txt
# https://climexp.knmi.nl/data/pa63702_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63729.dat
# https://climexp.knmi.nl/data/pa63729__yr.txt
# https://climexp.knmi.nl/data/pa63729_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63729.5.dat
# https://climexp.knmi.nl/data/pa63729.5__yr.txt
# https://climexp.knmi.nl/data/pa63729.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63709.6.dat
# https://climexp.knmi.nl/data/pa63709.6__yr.txt
# https://climexp.knmi.nl/data/pa63709.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63733.1.dat
# https://climexp.knmi.nl/data/pa63733.1__yr.txt
# https://climexp.knmi.nl/data/pa63733.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63733.2.dat
# https://climexp.knmi.nl/data/pa63733.2__yr.txt
# https://climexp.knmi.nl/data/pa63733.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63733.3.dat
# https://climexp.knmi.nl/data/pa63733.3__yr.txt
# https://climexp.knmi.nl/data/pa63733.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63709.2.dat
# https://climexp.knmi.nl/data/pa63709.2__yr.txt
# https://climexp.knmi.nl/data/pa63709.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63709.3.dat
# https://climexp.knmi.nl/data/pa63709.3__yr.txt
# https://climexp.knmi.nl/data/pa63709.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63709.7.dat
# https://climexp.knmi.nl/data/pa63709.7__yr.txt
# https://climexp.knmi.nl/data/pa63709.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63709.9.dat
# https://climexp.knmi.nl/data/pa63709.9__yr.txt
# https://climexp.knmi.nl/data/pa63709.9_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63737.dat
# https://climexp.knmi.nl/data/pa63737__yr.txt
# https://climexp.knmi.nl/data/pa63737_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63695.1.dat
# https://climexp.knmi.nl/data/pa63695.1__yr.txt
# https://climexp.knmi.nl/data/pa63695.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63717.4.dat
# https://climexp.knmi.nl/data/pa63717.4__yr.txt
# https://climexp.knmi.nl/data/pa63717.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63717.6.dat
# https://climexp.knmi.nl/data/pa63717.6__yr.txt
# https://climexp.knmi.nl/data/pa63717.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63717.8.dat
# https://climexp.knmi.nl/data/pa63717.8__yr.txt
# https://climexp.knmi.nl/data/pa63717.8_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63720.3.dat
# https://climexp.knmi.nl/data/pa63720.3__yr.txt
# https://climexp.knmi.nl/data/pa63720.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63740.dat
# https://climexp.knmi.nl/data/pa63740__yr.txt
# https://climexp.knmi.nl/data/pa63740_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63740.4.dat
# https://climexp.knmi.nl/data/pa63740.4__yr.txt
# https://climexp.knmi.nl/data/pa63740.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63740.7.dat
# https://climexp.knmi.nl/data/pa63740.7__yr.txt
# https://climexp.knmi.nl/data/pa63740.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63741.3.dat
# https://climexp.knmi.nl/data/pa63741.3__yr.txt
# https://climexp.knmi.nl/data/pa63741.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63741.4.dat
# https://climexp.knmi.nl/data/pa63741.4__yr.txt
# https://climexp.knmi.nl/data/pa63741.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63741.5.dat
# https://climexp.knmi.nl/data/pa63741.5__yr.txt
# https://climexp.knmi.nl/data/pa63741.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63741.6.dat
# https://climexp.knmi.nl/data/pa63741.6__yr.txt
# https://climexp.knmi.nl/data/pa63741.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63741.7.dat
# https://climexp.knmi.nl/data/pa63741.7__yr.txt
# https://climexp.knmi.nl/data/pa63741.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63741.8.dat
# https://climexp.knmi.nl/data/pa63741.8__yr.txt
# https://climexp.knmi.nl/data/pa63741.8_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63741.9.dat
# https://climexp.knmi.nl/data/pa63741.9__yr.txt
# https://climexp.knmi.nl/data/pa63741.9_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63741.10.dat
# https://climexp.knmi.nl/data/pa63741.10__yr.txt
# https://climexp.knmi.nl/data/pa63741.10_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63742.dat
# https://climexp.knmi.nl/data/pa63742__yr.txt
# https://climexp.knmi.nl/data/pa63742_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63742.2.dat
# https://climexp.knmi.nl/data/pa63742.2__yr.txt
# https://climexp.knmi.nl/data/pa63742.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63742.3.dat
# https://climexp.knmi.nl/data/pa63742.3__yr.txt
# https://climexp.knmi.nl/data/pa63742.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64180.1.dat
# https://climexp.knmi.nl/data/pa64180.1__yr.txt
# https://climexp.knmi.nl/data/pa64180.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64184.dat
# https://climexp.knmi.nl/data/pa64184__yr.txt
# https://climexp.knmi.nl/data/pa64184_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64184.1.dat
# https://climexp.knmi.nl/data/pa64184.1__yr.txt
# https://climexp.knmi.nl/data/pa64184.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64383.1.dat
# https://climexp.knmi.nl/data/pa64383.1__yr.txt
# https://climexp.knmi.nl/data/pa64383.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63729.4.dat
# https://climexp.knmi.nl/data/pa63729.4__yr.txt
# https://climexp.knmi.nl/data/pa63729.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63729.2.dat
# https://climexp.knmi.nl/data/pa63729.2__yr.txt
# https://climexp.knmi.nl/data/pa63729.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63729.3.dat
# https://climexp.knmi.nl/data/pa63729.3__yr.txt
# https://climexp.knmi.nl/data/pa63729.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63756.2.dat
# https://climexp.knmi.nl/data/pa63756.2__yr.txt
# https://climexp.knmi.nl/data/pa63756.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63756.1.dat
# https://climexp.knmi.nl/data/pa63756.1__yr.txt
# https://climexp.knmi.nl/data/pa63756.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63756.10.dat
# https://climexp.knmi.nl/data/pa63756.10__yr.txt
# https://climexp.knmi.nl/data/pa63756.10_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63733.4.dat
# https://climexp.knmi.nl/data/pa63733.4__yr.txt
# https://climexp.knmi.nl/data/pa63733.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63741.2.dat
# https://climexp.knmi.nl/data/pa63741.2__yr.txt
# https://climexp.knmi.nl/data/pa63741.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63737.1.dat
# https://climexp.knmi.nl/data/pa63737.1__yr.txt
# https://climexp.knmi.nl/data/pa63737.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63740.3.dat
# https://climexp.knmi.nl/data/pa63740.3__yr.txt
# https://climexp.knmi.nl/data/pa63740.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63740.6.dat
# https://climexp.knmi.nl/data/pa63740.6__yr.txt
# https://climexp.knmi.nl/data/pa63740.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63742.4.dat
# https://climexp.knmi.nl/data/pa63742.4__yr.txt
# https://climexp.knmi.nl/data/pa63742.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64390.dat
# https://climexp.knmi.nl/data/pa64390__yr.txt
# https://climexp.knmi.nl/data/pa64390_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64391.1.dat
# https://climexp.knmi.nl/data/pa64391.1__yr.txt
# https://climexp.knmi.nl/data/pa64391.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63729.1.dat
# https://climexp.knmi.nl/data/pa63729.1__yr.txt
# https://climexp.knmi.nl/data/pa63729.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63756.7.dat
# https://climexp.knmi.nl/data/pa63756.7__yr.txt
# https://climexp.knmi.nl/data/pa63756.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63756.12.dat
# https://climexp.knmi.nl/data/pa63756.12__yr.txt
# https://climexp.knmi.nl/data/pa63756.12_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63756.3.dat
# https://climexp.knmi.nl/data/pa63756.3__yr.txt
# https://climexp.knmi.nl/data/pa63756.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63756.9.dat
# https://climexp.knmi.nl/data/pa63756.9__yr.txt
# https://climexp.knmi.nl/data/pa63756.9_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63756.5.dat
# https://climexp.knmi.nl/data/pa63756.5__yr.txt
# https://climexp.knmi.nl/data/pa63756.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63789.3.dat
# https://climexp.knmi.nl/data/pa63789.3__yr.txt
# https://climexp.knmi.nl/data/pa63789.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63789.dat
# https://climexp.knmi.nl/data/pa63789__yr.txt
# https://climexp.knmi.nl/data/pa63789_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63789.6.dat
# https://climexp.knmi.nl/data/pa63789.6__yr.txt
# https://climexp.knmi.nl/data/pa63789.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63789.8.dat
# https://climexp.knmi.nl/data/pa63789.8__yr.txt
# https://climexp.knmi.nl/data/pa63789.8_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63790.dat
# https://climexp.knmi.nl/data/pa63790__yr.txt
# https://climexp.knmi.nl/data/pa63790_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63790.2.dat
# https://climexp.knmi.nl/data/pa63790.2__yr.txt
# https://climexp.knmi.nl/data/pa63790.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63791.1.dat
# https://climexp.knmi.nl/data/pa63791.1__yr.txt
# https://climexp.knmi.nl/data/pa63791.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64285.1.dat
# https://climexp.knmi.nl/data/pa64285.1__yr.txt
# https://climexp.knmi.nl/data/pa64285.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63801.1.dat
# https://climexp.knmi.nl/data/pa63801.1__yr.txt
# https://climexp.knmi.nl/data/pa63801.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63756.13.dat
# https://climexp.knmi.nl/data/pa63756.13__yr.txt
# https://climexp.knmi.nl/data/pa63756.13_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63832.1.dat
# https://climexp.knmi.nl/data/pa63832.1__yr.txt
# https://climexp.knmi.nl/data/pa63832.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63832.2.dat
# https://climexp.knmi.nl/data/pa63832.2__yr.txt
# https://climexp.knmi.nl/data/pa63832.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63832.6.dat
# https://climexp.knmi.nl/data/pa63832.6__yr.txt
# https://climexp.knmi.nl/data/pa63832.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63789.2.dat
# https://climexp.knmi.nl/data/pa63789.2__yr.txt
# https://climexp.knmi.nl/data/pa63789.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63789.1.dat
# https://climexp.knmi.nl/data/pa63789.1__yr.txt
# https://climexp.knmi.nl/data/pa63789.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64246.1.dat
# https://climexp.knmi.nl/data/pa64246.1__yr.txt
# https://climexp.knmi.nl/data/pa64246.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64276.dat
# https://climexp.knmi.nl/data/pa64276__yr.txt
# https://climexp.knmi.nl/data/pa64276_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63801.dat
# https://climexp.knmi.nl/data/pa63801__yr.txt
# https://climexp.knmi.nl/data/pa63801_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63801.2.dat
# https://climexp.knmi.nl/data/pa63801.2__yr.txt
# https://climexp.knmi.nl/data/pa63801.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63801.3.dat
# https://climexp.knmi.nl/data/pa63801.3__yr.txt
# https://climexp.knmi.nl/data/pa63801.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63832.7.dat
# https://climexp.knmi.nl/data/pa63832.7__yr.txt
# https://climexp.knmi.nl/data/pa63832.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63832.dat
# https://climexp.knmi.nl/data/pa63832__yr.txt
# https://climexp.knmi.nl/data/pa63832_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63832.3.dat
# https://climexp.knmi.nl/data/pa63832.3__yr.txt
# https://climexp.knmi.nl/data/pa63832.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63832.4.dat
# https://climexp.knmi.nl/data/pa63832.4__yr.txt
# https://climexp.knmi.nl/data/pa63832.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.4.dat
# https://climexp.knmi.nl/data/pa63862.4__yr.txt
# https://climexp.knmi.nl/data/pa63862.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.9.dat
# https://climexp.knmi.nl/data/pa63862.9__yr.txt
# https://climexp.knmi.nl/data/pa63862.9_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.1.dat
# https://climexp.knmi.nl/data/pa63862.1__yr.txt
# https://climexp.knmi.nl/data/pa63862.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.7.dat
# https://climexp.knmi.nl/data/pa63862.7__yr.txt
# https://climexp.knmi.nl/data/pa63862.7_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.10.dat
# https://climexp.knmi.nl/data/pa63862.10__yr.txt
# https://climexp.knmi.nl/data/pa63862.10_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.12.dat
# https://climexp.knmi.nl/data/pa63862.12__yr.txt
# https://climexp.knmi.nl/data/pa63862.12_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64285.dat
# https://climexp.knmi.nl/data/pa64285__yr.txt
# https://climexp.knmi.nl/data/pa64285_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63801.4.dat
# https://climexp.knmi.nl/data/pa63801.4__yr.txt
# https://climexp.knmi.nl/data/pa63801.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.3.dat
# https://climexp.knmi.nl/data/pa63862.3__yr.txt
# https://climexp.knmi.nl/data/pa63862.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.8.dat
# https://climexp.knmi.nl/data/pa63862.8__yr.txt
# https://climexp.knmi.nl/data/pa63862.8_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.11.dat
# https://climexp.knmi.nl/data/pa63862.11__yr.txt
# https://climexp.knmi.nl/data/pa63862.11_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.dat
# https://climexp.knmi.nl/data/pa63862__yr.txt
# https://climexp.knmi.nl/data/pa63862_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.2.dat
# https://climexp.knmi.nl/data/pa63862.2__yr.txt
# https://climexp.knmi.nl/data/pa63862.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.6.dat
# https://climexp.knmi.nl/data/pa63862.6__yr.txt
# https://climexp.knmi.nl/data/pa63862.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.13.dat
# https://climexp.knmi.nl/data/pa63862.13__yr.txt
# https://climexp.knmi.nl/data/pa63862.13_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63862.15.dat
# https://climexp.knmi.nl/data/pa63862.15__yr.txt
# https://climexp.knmi.nl/data/pa63862.15_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63866.2.dat
# https://climexp.knmi.nl/data/pa63866.2__yr.txt
# https://climexp.knmi.nl/data/pa63866.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64282.dat
# https://climexp.knmi.nl/data/pa64282__yr.txt
# https://climexp.knmi.nl/data/pa64282_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64282.1.dat
# https://climexp.knmi.nl/data/pa64282.1__yr.txt
# https://climexp.knmi.nl/data/pa64282.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64285.2.dat
# https://climexp.knmi.nl/data/pa64285.2__yr.txt
# https://climexp.knmi.nl/data/pa64285.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63866.1.dat
# https://climexp.knmi.nl/data/pa63866.1__yr.txt
# https://climexp.knmi.nl/data/pa63866.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63866.4.dat
# https://climexp.knmi.nl/data/pa63866.4__yr.txt
# https://climexp.knmi.nl/data/pa63866.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63866.6.dat
# https://climexp.knmi.nl/data/pa63866.6__yr.txt
# https://climexp.knmi.nl/data/pa63866.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64348.3.dat
# https://climexp.knmi.nl/data/pa64348.3__yr.txt
# https://climexp.knmi.nl/data/pa64348.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63932.1.dat
# https://climexp.knmi.nl/data/pa63932.1__yr.txt
# https://climexp.knmi.nl/data/pa63932.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63932.5.dat
# https://climexp.knmi.nl/data/pa63932.5__yr.txt
# https://climexp.knmi.nl/data/pa63932.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63932.4.dat
# https://climexp.knmi.nl/data/pa63932.4__yr.txt
# https://climexp.knmi.nl/data/pa63932.4_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63887.2.dat
# https://climexp.knmi.nl/data/pa63887.2__yr.txt
# https://climexp.knmi.nl/data/pa63887.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63887.5.dat
# https://climexp.knmi.nl/data/pa63887.5__yr.txt
# https://climexp.knmi.nl/data/pa63887.5_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63887.dat
# https://climexp.knmi.nl/data/pa63887__yr.txt
# https://climexp.knmi.nl/data/pa63887_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63887.6.dat
# https://climexp.knmi.nl/data/pa63887.6__yr.txt
# https://climexp.knmi.nl/data/pa63887.6_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63866.11.dat
# https://climexp.knmi.nl/data/pa63866.11__yr.txt
# https://climexp.knmi.nl/data/pa63866.11_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63887.1.dat
# https://climexp.knmi.nl/data/pa63887.1__yr.txt
# https://climexp.knmi.nl/data/pa63887.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64348.dat
# https://climexp.knmi.nl/data/pa64348__yr.txt
# https://climexp.knmi.nl/data/pa64348_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa64348.1.dat
# https://climexp.knmi.nl/data/pa64348.1__yr.txt
# https://climexp.knmi.nl/data/pa64348.1_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa67403.2.dat
# https://climexp.knmi.nl/data/pa67403.2__yr.txt
# https://climexp.knmi.nl/data/pa67403.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa67413.dat
# https://climexp.knmi.nl/data/pa67413__yr.txt
# https://climexp.knmi.nl/data/pa67413_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa67413.2.dat
# https://climexp.knmi.nl/data/pa67413.2__yr.txt
# https://climexp.knmi.nl/data/pa67413.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63932.dat
# https://climexp.knmi.nl/data/pa63932__yr.txt
# https://climexp.knmi.nl/data/pa63932_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63932.2.dat
# https://climexp.knmi.nl/data/pa63932.2__yr.txt
# https://climexp.knmi.nl/data/pa63932.2_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63932.3.dat
# https://climexp.knmi.nl/data/pa63932.3__yr.txt
# https://climexp.knmi.nl/data/pa63932.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Now processing...
# https://climexp.knmi.nl/data/pa63887.3.dat
# https://climexp.knmi.nl/data/pa63887.3__yr.txt
# https://climexp.knmi.nl/data/pa63887.3_a.txt
#
# Response Status: 200
#
# Response Status: 200
#
# Response Status: 200
#
# Done retrieving data from all stations.
# Raw DF List: 208 of 208
# Annual Cycle DF List: 208 of 208
# Anomaly DF List: 208 of 208

# %%
# all_raw_df = pd.concat(all_raw_df_list)
# all_annual_df = pd.concat(all_annual_df_list)
# all_anom_df = pd.concat(all_anom_df_list)

all_raw_df = concat_format_wide(all_raw_df_list, all_stations["Station Code"].tolist())
all_annual_df = concat_format_wide(all_annual_df_list, all_stations["Station Code"].tolist())
all_anom_df = concat_format_wide(all_anom_df_list, all_stations["Station Code"].tolist())

# %% [markdown]
# Run the cell below to download all the monthly raw, annual cycle, and anomaly data in three separate .csv files.

# %%
path = "for_analysis/"
filename = f"{path}all_monthly_raw.csv"
all_raw_df.to_csv(filename, index=False)

path = "for_analysis/"
filename = f"{path}all_annual_cycle.csv"
all_annual_df.to_csv(filename, index=False)

path = "for_analysis/"
filename = f"{path}all_anomaly.csv"
all_anom_df.to_csv(filename, index=False)

# %% [markdown]
# # analysis

# %%
 # Imports
import numpy as np
import pandas as pd
import sys

from bs4 import BeautifulSoup
from requests_html import HTMLSession
from pprint import pprint

from bs4 import BeautifulSoup
from pprint import pprint
from urllib.parse import urljoin
import webbrowser
import re

import requests
import datetime
import time

# %%
station_monthly_raws = pd.read_csv("for_analysis/all_monthly_raw.csv")
station_annual_raws = pd.read_csv("for_analysis/all_annual_cycle.csv")
station_anom_raws = pd.read_csv("for_analysis/all_anomaly.csv")
series_monthly_raws = pd.read_csv("for_analysis/all_timeseries_monthly_raw.csv")
series_annual_raws = pd.read_csv("for_analysis/all_timeseries_annual_cycle.csv")
series_anom_raws = pd.read_csv("for_analysis/all_timeseries_anomaly.csv")
coordinates = pd.read_csv("for_analysis/BoxCoordinates.csv")
stations = pd.read_csv("for_analysis/box_coordinate_stations.csv")

# %% [markdown]
# # utilities

# %% [markdown]
# # Unrelated Utilities
#
# Below are some utilities I used to organize my working files. Completely unrelated to the KNMI Climate Explorer web scraping tools.

# %%
# remove("raw_data\station_61045_raw_data")

from pathlib import Path

file_path = Path('C:\\Users\\Cecile Dai\\Downloads\\all_stations_lat=-5--4_lon=20-25.csv.csv')


try:
    # file_path.unlink()
    file_path.unlink()
except OSError as e:
    print("Error: %s : %s" % (file_path, e.strerror))

# %% [markdown]
# https://cosmosdb.github.io/labs/dotnet/labs/02-load_data_with_adf.html

# %% [markdown]
# # get_stations_SCRAPPED

# %% [markdown]
# # Working Code for KNMI Monthly Station Data Analysis
#
# Now outdated. Written by Cecile Dai.
#
# Uses information from https://climexp.knmi.nl/about.cgi?id=someone@somewhere

# %% [markdown]
# ## Stations
#
# Get the all stations in a specified latitude-longitude coordinate range.
#
# ### Setup
#
# Start by getting the form tags so that we know what we need to submit to obtain the desired information.

# %%
# Imports
import numpy as np
import pandas as pd
import sys

from bs4 import BeautifulSoup
from requests_html import HTMLSession
from pprint import pprint

# Link to the KNMI page where you select the stations and data to view a monthly time series
station_link = 'https://climexp.knmi.nl/selectstation.cgi?id=someone@somewhere'

# initialize HTTP session so data/cookies are persisted
session = HTMLSession()

# %% [markdown]
# Parse all tags from a web page.

# %%
# Function to get all form tags from a given web page
def get_all_forms(url):
    # GET request
    res = session.get(url)
    soup = BeautifulSoup(res.html.html, "html.parser")
    return soup.find_all("form")

# %% [markdown]
# Get all form details.

# %%
# Returns the HTML details of a form, including action, method and list of form controls (inputs, etc)
def get_form_details(form):
    details = {}
    # get the form action (requested URL)
    action = form.attrs.get("action").lower()
    # get the form method (POST, GET, DELETE, etc)
    # if not specified, GET is the default in HTML
    method = form.attrs.get("method", "get").lower()
    # get all form inputs
    inputs = []
    for input_tag in form.find_all("input"):
        # get type of input form control
        input_type = input_tag.attrs.get("type", "text")
        # get name attribute
        input_name = input_tag.attrs.get("name")
        # get the default value of that input tag
        input_value =input_tag.attrs.get("value", "")
        # add everything to that list
        inputs.append({"type": input_type, "name": input_name, "value": input_value})

    # Get all 'select' and 'textarea' input types
    for select in form.find_all("select"):
        # get the name attribute
        select_name = select.attrs.get("name")
        # set the type as select
        select_type = "select"
        select_options = []
        # the default select value
        select_default_value = ""
        # iterate over options and get the value of each
        for select_option in select.find_all("option"):
            # get the option value used to submit the form
            option_value = select_option.attrs.get("value")
            if option_value:
                select_options.append(option_value)
                if select_option.attrs.get("selected"):
                    # if 'selected' attribute is set, set this option as default    
                    select_default_value = option_value
        if not select_default_value and select_options:
            # if the default is not set, and there are options, take the first option as default
            select_default_value = select_options[0]
        # add the select to the inputs list
        inputs.append({"type": select_type, "name": select_name, "values": select_options, "value": select_default_value})
    for textarea in form.find_all("textarea"):
        # get the name attribute
        textarea_name = textarea.attrs.get("name")
        # set the type as textarea
        textarea_type = "textarea"
        # get the textarea value
        textarea_value = textarea.attrs.get("value", "")
        # add the textarea to the inputs list
        inputs.append({"type": textarea_type, "name": textarea_name, "value": textarea_value})
        # put everything to the resulting dictionary
    details["action"] = action
    details["method"] = method
    details["inputs"] = inputs
    return details

# %% [markdown]
# Run the following block to print out form details, with input types and values.

# %%
# get all form tags
forms = get_all_forms(station_link)
# iteratte over forms
for i, form in enumerate(forms, start=1):
    form_details = get_form_details(form)
    print("="*50, f"form #{i}", "="*50)
    print("action: {action}\n\n".format(action=form_details["action"]))
    print("method: {method}\n\n".format(method=form_details["method"]))
    for input in form_details["inputs"]:
        print("input: {i}\n".format(i=input))

# %% [markdown]
# ### Create Submission Form
#
# Start off by noting the submission values you want. For the purposes of only getting a monthly station list in a certain area for precipitation, only "select: precipitation_all", "text: lat1", "text: lat2", "text: "lon1", and "text: lon2" will be filled out. These inputs select the precipitation measurements under GHCN-M (all) for all stations within a selected latitude and longitude area.

# %%
# Imports
from bs4 import BeautifulSoup
from pprint import pprint
from urllib.parse import urljoin
import webbrowser


# Select precipitation_all

# Define desired latitude and longitude. Change this for different areas.
# lat1, lat2 = 0, 5
# lon1, lon2 = 30, 35

lat1, lat2 = 10, 15
lon1, lon2 = 10, 15

# %%
# the data body we want to submit
data = {}

data["email"] = "someone@somewhere"
data["climate"] = "precipitation_all"
data["name"] = ""
data["num"] = 10
data["lat"] = ""
data["lon"] = ""
data["lat1"] = lat1
data["lat2"] = lat2
data["lon1"] = lon1
data["lon2"] = lon2
data["list"] = """# lon1 lon2 lat1 lat2 (optional)
station number (one per line)"""
data["min"] = 10
data["sum"] = 1
data["month"] = -1
data["yr1"] = ""
data["yr2"] = ""
data["dist"] = ""
data["elevmin"] = ""
data["elevmax"] = ""

print(data)

# %% [markdown]
# ### Parse Submission Response
#
# Submit form with desired inputs and extract relevant information from HTTP response.

# %%
# join the url with the action (form request URL)
url = urljoin(station_link, form_details["action"])

# pprint(data)
# Submit form and get response in res
if form_details["method"] == "post":
    res = session.post(url, data=data)
elif form_details["method"] == "get":
    res = session.get(url, params=data)
elif form_details["method"] == "put":
    res = session.put(url, params=data)

soup = BeautifulSoup(res.content, "html.parser")

import re

start = re.search('</div>\n</form>', res.text)
stop = re.search('</div>\n<div class="col-md-4">', res.text)

# I will admit this is not the prettiest way to extract the desired text but the pure regex method just wasn't working :(
limit1 = re.split(', ', str(start.span()))
limit2 = re.split(', ', str(stop.span()))
l1 = int(limit1[1].replace(')', ''))
l2 = int(limit2[0].replace('(', ''))

print(res.text[l1:l2])

relevant_text = res.text[l1:l2]

# %% [markdown]
# ### Get Stations
#
# Parse through response data and retrieve station links in a dataframe.

# %%
lines = relevant_text.replace('\n', '').split('<br>')
        
header = ["Station Name", "Latitude", "Longitude", "Elevation", "Station Code", "Starting Year", "Ending Year", "Monthly Series Link"]
station_names = []
lats = []
lons = []
elevs = []
codes = []
start_year = []
end_year = []
links = []

stripped_lines = []

for i in range(len(lines)):
    if len("".join(lines[i].split())) != 0 and i >= 3:
        stripped_lines.append(lines[i])
        # print(lines[i])
    else:
        continue

for j in range(len(stripped_lines)):
    # Station names
    if j%4 == 0:
        # print(" ".join(stripped_lines[j].split()))
        station_names.append(" ".join(stripped_lines[j].split()))

    # Coordinates and elevation
    elif j%4 == 1:
        latitude = re.search('\s+(.*)N', stripped_lines[j])
        # print(latitude.group(0).strip())
        lats.append(latitude.group(0).strip())

        longitude = re.search(',\s+(.*)E', stripped_lines[j])
        # print(longitude.group(0).replace(',','').strip())
        lons.append(longitude.group(0).replace(',','').strip())

        elevation = re.search('E,\s+(.*m)', stripped_lines[j])
        # print(elevation.group(0).replace("E,", '').strip())
        elevs.append(elevation.group(0).replace("E,", '').strip())

    # Station code and monthly series link
    elif j%4 == 2:
        code = re.search('([0-9\.]+)', stripped_lines[j])
        # print(code.group(0))
        codes.append(code.group(0))

        link = re.search('\"(.*)\"', stripped_lines[j])
        # print(link.group(0).replace('"', ''))
        links.append(link.group(0).replace('"', ''))

    # Data start and end year
    elif j%4 == 3:
        years = re.search('([0-9]{4}\-[0-9]{4})', stripped_lines[j])
        # print(years.group(0))
        # print(years.group(0)[:4])
        # print(years.group(0)[5:])
        start_year.append(years.group(0)[:4])
        end_year.append(years.group(0)[5:])

data = {'Station Name': station_names, 'Latitude': lats, 'Longitude': lons, 'Elevation': elevs, 'Station Code': codes, 'Starting Year': start_year, 'Ending Year': end_year, 'Monthly Series Link': links}

df = pd.DataFrame(data)
print(df)

# %% [markdown]
# ### Download Station Links in .csv File
#
# Run this code block to download the data as a .csv file.

# %%
path = "stations/"
filename_range = "{p}all_stations_lat={a}to{b}_lon={c}to{d}.csv".format(p = path, a = lat1, b = lat2, c = lon1, d = lon2)
df.to_csv(filename_range, index=False)

# %% [markdown]
# ## Station Data
#
# Get the monthly precipitation, annual cycle, and anomaly data per station in the previously specified latitude-longitude coordinate range.
#
# ### Get Station Data
#
# Gets the raw data for monthly precipitation, annual cycles, and anomalies, and puts it into dataframes.

# %%
import requests
import datetime
import time

raw_df_list = []
annual_df_list = []
anom_df_list = []

# Visit all links, use array indices to keep track of stations
for i in range(len(links)):
    station_data_url = "https://climexp.knmi.nl/" + links[i]
    station_data_name = station_names[i]
    station_data_code = codes[i]
    print("{a} | {b} | {c}".format(a=station_data_name, b=station_data_code, c=station_data_url))
    print("================================================================")

    raw_data_link = "https://climexp.knmi.nl/data/pa" + station_data_code + ".dat"
    annual_cycle_link = "https://climexp.knmi.nl/data/pa"+ station_data_code +"__yr.txt"
    anom_link = "https://climexp.knmi.nl/data/pa"+ station_data_code +"_a.txt"

    print("Station {a} of {b}".format(a = i + 1, b = len(links)))

    # wait if there is no response (due to timeouts)
    code = requests.head(raw_data_link)
    print("Response Status: {a}\n".format(a=code.status_code))
    if requests.head(raw_data_link).status_code == 404:
        time.sleep(60)

    datapage = requests.get(raw_data_link)

    # print(datapage.text)
    # raw_data_headers = ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    raw_data_list = []
    lines = datapage.text.split("\n")
    for line in lines:
        elements = line.split()
        # print(elements)
        if len(elements) == 0:
            continue
        if elements[0] == "#":
            continue
        else:
            # csvline = ','.join(elements)
            # print(csvline)
            raw_data_list.append(elements)
    raw_data_df = pd.DataFrame(raw_data_list, columns = ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
    raw_df_list.append(raw_data_df)
    print(raw_data_df)
    # print("confirm")

    annualpage = requests.get(annual_cycle_link)
    # print(annualpage.text)
    raw_data_yr_list = []
    lines = annualpage.text.split("\n")
    for line in lines:
        elements = line.split()
        if len(elements) == 0:
            continue
        if elements[0] == "#":
            continue
        else:
            monthint = re.findall('2{1}0{3,4}([1-9]{1}[012]?)01', elements[0])
            # print(monthint)
            if monthint and len(monthint) != 0:
                elements[0] = datetime.date(1900, int(monthint[0]), 1).strftime('%B')
                # print(len(elements))
                # print(elements)
                raw_data_yr_list.append(elements)
    raw_data_yr_df = pd.DataFrame(raw_data_yr_list, columns = ['Month', 'Mean', '2.5%', '17%', '50%', '83%', '97.5%'])
    annual_df_list.append(raw_data_yr_df)
    print(raw_data_yr_df)
    # print("confirm")

    anompage = requests.get(anom_link)
    # print(anompage.text)
    # raw_data_anom_list = {'Year': [], 'January': [], 'February': [], 'March': [], 'April': [], 'May': [], 'June': [], 'July': [], 'August': [], 'September': [], 'October': [], 'November': [], 'December': []}
    raw_data_anom_dict = {}
    raw_data_anom_list = []
    lines = anompage.text.split("\n")
    for line in lines:
        elements = line.split()
        if len(elements) == 0:
            continue
        if elements[0] == "#":
            continue
        else:
            date = re.findall('([0-9]{4})\.([0-9]{4})', elements[0])
            if date and len(date[0]) == 2:
                if date[0][0] not in raw_data_anom_dict:
                    raw_data_anom_dict[date[0][0]] = {'January': '-999.9', 'February': '-999.9', 'March':'-999.9', 'April': '-999.9', 'May': '-999.9', 'June': '-999.9', 'July': '-999.9', 'August': '-999.9', 'September': '-999.9', 'October': '-999.9', 'November': '-999.9', 'December': '-999.9'}
                monthint = round((float('0.' + date[0][1]) * 12) + 1)
                monthint = datetime.date(1900, int(monthint), 1).strftime('%B')
                raw_data_anom_dict[date[0][0]][monthint] = elements[1]
    for key in raw_data_anom_dict:
        dlist = []
        dlist.append(key)
        for d in raw_data_anom_dict[key]:
            dlist.append(raw_data_anom_dict[key][d])
        raw_data_anom_list.append(dlist)
    raw_data_anom_df = pd.DataFrame(raw_data_anom_list, columns = ['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
    anom_df_list.append(raw_data_anom_df)
    print(raw_data_anom_df)
    # print("confirm")

    # ######## not needed ##########
    # page = requests.get(station_data_url)
    # # print(page.text)
    
    # pagesoup = BeautifulSoup(page.text)
    # linkdivs = pagesoup.find_all("div", {"class": "bijschrift"})
    # print(linkdivs)
    # print("")
    # ##############################

# %% [markdown]
# ### Download Station Data as .csv Files
#
# Run this block to download all raw precipitation data as separate .csv files.

# %%
for df in range(len(links)):
    # Change path to save to another directory
    path = "raw_data/"
    filename_station_data = "{p}station_{a}_raw_data.csv".format(p = path, a = codes[df])
    raw_df_list[df].to_csv(filename_station_data, index=False)

# %% [markdown]
# Run this block to download all annual cycle data as separate .csv files.

# %%
for df in range(len(links)):
    # Change path to save to another directory
    path = 'annual_data/'
    filename_annual_data = "{p}station_{a}_annual_cycle_data.csv".format(p = path, a = codes[df])
    annual_df_list[df].to_csv(filename_annual_data, index=False)

# %% [markdown]
# Run this block to download all anomaly data as separate .csv files.

# %%
for df in range(len(links)):
    # Change path to save to another directory
    path = 'anomalies_data/'
    filename_anom_data = "{p}station_{a}_anomaly_data.csv".format(p = path, a = codes[df])
    anom_df_list[df].to_csv(filename_anom_data, index=False)

# %% [markdown]
# Run this block to concatenate all the raw data into one .csv file, or to add it into an existing file

# %%
def concat_raw_format_long(raw_df_list, existing_file=''):
    full_raw_list = []
    columns = ["Year", "Month", "Precipitation (mm)"]
    for df in raw_df_list:
        for row in range(df.shape[0]):
            row_data = df.iloc[row]
            for element in range(len(row_data)):
                if element == 0:    # element 0 is year
                    pass
                else:
                    month = datetime.date(1900, int(element), 1).strftime('%B')
                    full_raw_list.append([row_data[0], month, row_data[element]])
                    print([row_data[0], month, row_data[element]])
    return full_raw_list
    # print(full_raw_list)

def concat_raw_format_wide(raw_df_list, station_list, existing_file=''):
    full_raw_list_df = []
    dfs = []    #list of dataframes to concatenate
    columns = ['Station', 'Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    for station_df in range(len(station_list)):
        codes = [station_list[station_df] for row in range(raw_df_list[station_df].shape[0])]
        new_df = raw_df_list[station_df].copy()
        new_df.insert(0, 'Station', codes)
        dfs.append(new_df)
    if len(existing_file) != 0:
        existing_df = pd.read_csv(existing_file)
        # Check if this data already exists in the file, remove from list to be concatenated if so
        for station in range(len(station_list)):
            if not existing_df.loc(station_list[station]):
                dfs.remove(dfs[station])
        dfs.append(existing_df)
    full_raw_list_df = pd.concat(dfs)
    return full_raw_list_df
    # print(full_raw_list)

# concat_raw_format_long(raw_df_list)
full_raw_list = concat_raw_format_wide(raw_df_list, codes)

print(full_raw_list)
print(full_raw_list.shape)

# %%
# Run to download file
full_raw_data_df = pd.DataFrame(full_raw_list, columns = ['Station', 'Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
print(full_raw_data_df)

# %% [markdown]
# Run this block to concatenate all the annual cycle data into one .csv file, or to add it into an existing file.

# %%
def concat_raw_annual_format_wide(raw_df_list, station_list, existing_file=''):
    full_raw_list = []
    for station_df in range(len(station_list)):
        df = raw_df_list[station_df]
        for row in range(df.shape[0]):
            new_row_data = [station_list[station_df]]
            for element in range(len(df.iloc[row])):
                new_row_data.append(df.iloc[row][element])
            full_raw_list.append(new_row_data)
    # if len(existing_file) != 0:
    #     existing_df = pd.read_csv(existing_file)
    #     # Check if this data already exists in the file
    #     for station in station_list:
    #         if not existing_df.loc[station]:

    return full_raw_list
    # print(full_raw_list)

full_raw_annual_list = concat_raw_annual_format_wide(annual_df_list, codes)

for element in full_raw_annual_list:
    print(element)

# %%
# Run to download file
full_annual_data_df = pd.DataFrame(full_raw_annual_list, columns = ['Station', 'Month', 'Mean', '2.5%', '17%', '50%', '83%', '97.5%'])
print(full_annual_data_df)

# %% [markdown]
# Run this block to concatenate all the anomaly data into one .csv file, or to add it into an existing file.

# %%
# Work in progress
# def concat_raw_anom_format_long(raw_df_list, existing_file=''):
#     full_raw_list = []
#     columns = ["Year", "Month", "Precipitation (mm)"]
#     for df in raw_df_list:
#         for row in range(df.shape[0]):
#             row_data = df.iloc[row]
#             for element in range(len(row_data)):
#                 if element == 0:    # element 0 is year
#                     pass
#                 else:
#                     month = datetime.date(1900, int(element), 1).strftime('%B')
#                     full_raw_list.append([row_data[0], month, row_data[element]])
#                     print([row_data[0], month, row_data[element]])
#     return full_raw_list
#     # print(full_raw_list)

def concat_raw_anom_format_wide(raw_df_list, station_list, existing_file=''):
    full_raw_list = []
    columns = ['Station', 'Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    for station_df in range(len(station_list)):
        df = raw_df_list[station_df]
        for row in range(df.shape[0]):
            new_row_data = [station_list[station_df]]
            for element in range(len(df.iloc[row])):
                new_row_data.append(df.iloc[row][element])
            full_raw_list.append(new_row_data)
    return full_raw_list
    # print(full_raw_list)

# concat_raw_anom_format_long(raw_df_list)
full_raw_anom_list = concat_raw_anom_format_wide(anom_df_list, codes)

for element in full_raw_anom_list:
    print(element)

# %%
# Run to download file
full_anom_data_df = pd.DataFrame(full_raw_anom_list, columns = ['Station', 'Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
print(full_anom_data_df)

# %% [markdown]
# ## References
#
# Code adapted from: https://www.thepythoncode.com/article/extracting-and-submitting-web-page-forms-in-python
#
# Other Resources:
