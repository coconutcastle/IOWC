# %%
import netCDF4 as nc

all_file = 'da_hydro_AprMar_r.1-2000_d.05-Jan-2018.nc'
all_data = nc.Dataset(all_file)

all_data
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     history_of_appended_files: Wed Mar 14 16:04:33 2018: Appended file ./input-recon/cesm_latlon.nc had following "history" attribute:
# Thu Nov 30 14:56:30 2017: ncks -A -v lat,lon b.e11.BLMTRC5CN.f19_g16.010.cam.h0.TREFHT.085001-184912.nc /home/nsteiger/MATLAB/hydro-recon/cesm_latlon.nc
#
#     author: Nathan Steiger, LDEO Columbia University, Mar 2018
#     history: Wed Mar 14 16:04:45 2018: ncatted -O --glb_att_add citation=https://doi.org/10.5281/zenodo.1154913 da_hydro_AprMar_r.1-2000_d.05-Jan-2018.nc
# Wed Mar 14 16:04:45 2018: ncatted -O --glb_att_add author=Nathan Steiger, LDEO Columbia University, Mar 2018 da_hydro_AprMar_r.1-2000_d.05-Jan-2018.nc
# Wed Mar 14 16:04:33 2018: ncks -A -v lat,lon ./input-recon/cesm_latlon.nc da_hydro_AprMar_r.1-2000_d.05-Jan-2018.nc
#     NCO: "4.6.2"
#     citation: https://doi.org/10.5281/zenodo.1154913
#     dimensions(sizes): lat(96), lon(144), time(2000), tmon(24000), prctl(3)
#     variables(dimensions): float64 lat(lat), float64 lon(lon), float64 time(time), float64 tmon(tmon), float64 tas_mn(time, lat, lon), float64 tas_sg(time, lat, lon), float64 tas_pc(prctl, time, lat, lon), float64 pdsi_mn(time, lat, lon), float64 pdsi_sg(time, lat, lon), float64 pdsi_pc(prctl, time, lat, lon), float64 spei_mn(time, lat, lon), float64 spei_sg(time, lat, lon), float64 spei_pc(prctl, time, lat, lon), float64 Nino_12_mn(tmon), float64 Nino_12_sg(tmon), float64 Nino_12_pc(prctl, tmon), float64 Nino_3_mn(tmon), float64 Nino_3_sg(tmon), float64 Nino_3_pc(prctl, tmon), float64 Nino_3.4_mn(tmon), float64 Nino_3.4_sg(tmon), float64 Nino_3.4_pc(prctl, tmon), float64 Nino_4_mn(tmon), float64 Nino_4_sg(tmon), float64 Nino_4_pc(prctl, tmon), float64 PacDelSST_mn(tmon), float64 PacDelSST_sg(tmon), float64 PacDelSST_pc(prctl, tmon), float64 Atl_mn(time), float64 Atl_sg(time), float64 Atl_pc(prctl, time), float64 Pac130_mn(time), float64 Pac130_sg(time), float64 Pac130_pc(prctl, time), float64 Pac160_mn(time), float64 Pac160_sg(time), float64 Pac160_pc(prctl, time), float64 EPac_mn(time), float64 EPac_sg(time), float64 EPac_pc(prctl, time), float64 WPac_mn(time), float64 WPac_sg(time), float64 WPac_pc(prctl, time), float64 SAsia_mn(time), float64 SAsia_sg(time), float64 SAsia_pc(prctl, time), float64 IndOcn_mn(time), float64 IndOcn_sg(time), float64 IndOcn_pc(prctl, time), float64 SAmer_mn(time), float64 SAmer_sg(time), float64 SAmer_pc(prctl, time), float64 Ind_mn(time), float64 Ind_sg(time), float64 Ind_pc(prctl, time), float64 Afr_mn(time), float64 Afr_sg(time), float64 Afr_pc(prctl, time), float64 EAfr_mn(time), float64 EAfr_sg(time), float64 EAfr_pc(prctl, time), float64 gmt_mn(time), float64 gmt_sg(time), float64 gmt_pc(prctl, time), float64 amo_mn(time), float64 amo_sg(time), float64 amo_pc(prctl, time)
#     groups:

# %%
print(all_data.variables)
# sc variables are
# Out:
# {'lat': <class 'netCDF4._netCDF4.Variable'>
# float64 lat(lat)
#     long_name: latitude
#     units: degrees_north
# unlimited dimensions:
# current shape = (96,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'lon': <class 'netCDF4._netCDF4.Variable'>
# float64 lon(lon)
#     long_name: longitude
#     units: degrees_east
# unlimited dimensions:
# current shape = (144,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'time': <class 'netCDF4._netCDF4.Variable'>
# float64 time(time)
#     long_name: Years CE
#     units: Annual mean starting from April to the next calendar year March
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tmon': <class 'netCDF4._netCDF4.Variable'>
# float64 tmon(tmon)
#     long_name: Fractional years CE
#     units: Monthly mean
# unlimited dimensions:
# current shape = (24000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tas_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 tas_mn(time, lat, lon)
#     long_name: 2 m temperature (reconstruction mean)
#     units: degC
# unlimited dimensions:
# current shape = (2000, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tas_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 tas_sg(time, lat, lon)
#     long_name: 2 m temperature (1 standard deviation of ensemble)
#     units: degC
# unlimited dimensions:
# current shape = (2000, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tas_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 tas_pc(prctl, time, lat, lon)
#     long_name: 2 m temperature (ensemble percentiles: 5th, 50th, 95th)
#     units: degC
# unlimited dimensions:
# current shape = (3, 2000, 96, 144)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pdsi_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 pdsi_mn(time, lat, lon)
#     _FillValue: nan
#     long_name: PDSI (land only) (reconstruction mean)
#     units: Standardized units of relative dry and wet
#     missing_value: nan
# unlimited dimensions:
# current shape = (2000, 96, 144)
# filling on, 'pdsi_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 pdsi_sg(time, lat, lon)
#     _FillValue: nan
#     long_name: PDSI (land only) (1 standard deviation of ensemble)
#     units: Standardized units of relative dry and wet
#     missing_value: nan
# unlimited dimensions:
# current shape = (2000, 96, 144)
# filling on, 'pdsi_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 pdsi_pc(prctl, time, lat, lon)
#     _FillValue: nan
#     long_name: PDSI (land only) (ensemble percentiles: 5th, 50th, 95th)
#     units: Standardized units of relative dry and wet
#     missing_value: nan
# unlimited dimensions:
# current shape = (3, 2000, 96, 144)
# filling on, 'spei_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 spei_mn(time, lat, lon)
#     _FillValue: nan
#     long_name: SPEI 12 months (land only) (reconstruction mean)
#     units: Standardized units of relative dry and wet
#     missing_value: nan
# unlimited dimensions:
# current shape = (2000, 96, 144)
# filling on, 'spei_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 spei_sg(time, lat, lon)
#     _FillValue: nan
#     long_name: SPEI 12 months (land only) (1 standard deviation of ensemble)
#     units: Standardized units of relative dry and wet
#     missing_value: nan
# unlimited dimensions:
# current shape = (2000, 96, 144)
# filling on, 'spei_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 spei_pc(prctl, time, lat, lon)
#     _FillValue: nan
#     long_name: SPEI 12 months (land only) (ensemble percentiles: 5th, 50th, 95th)
#     units: Standardized units of relative dry and wet
#     missing_value: nan
# unlimited dimensions:
# current shape = (3, 2000, 96, 144)
# filling on, 'Nino_12_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_12_mn(tmon)
#     long_name: Nino 1+2 (reconstruction mean)
#     units: degC
# unlimited dimensions:
# current shape = (24000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Nino_12_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_12_sg(tmon)
#     long_name: Nino 1+2 (1 standard deviation of ensemble)
#     units: degC
# unlimited dimensions:
# current shape = (24000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Nino_12_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_12_pc(prctl, tmon)
#     long_name: Nino 1+2 (ensemble percentiles: 5th, 50th, 95th)
#     units: degC
# unlimited dimensions:
# current shape = (3, 24000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Nino_3_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_3_mn(tmon)
#     long_name: Nino 3 (reconstruction mean)
#     units: degC
# unlimited dimensions:
# current shape = (24000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Nino_3_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_3_sg(tmon)
#     long_name: Nino 3 (1 standard deviation of ensemble)
#     units: degC
# unlimited dimensions:
# current shape = (24000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Nino_3_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_3_pc(prctl, tmon)
#     long_name: Nino 3 (ensemble percentiles: 5th, 50th, 95th)
#     units: degC
# unlimited dimensions:
# current shape = (3, 24000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Nino_3.4_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_3.4_mn(tmon)
#     long_name: Nino 3.4 (reconstruction mean)
#     units: degC
# unlimited dimensions:
# current shape = (24000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Nino_3.4_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_3.4_sg(tmon)
#     long_name: Nino 3.4 (1 standard deviation of ensemble)
#     units: degC
# unlimited dimensions:
# current shape = (24000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Nino_3.4_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_3.4_pc(prctl, tmon)
#     long_name: Nino 3.4 (ensemble percentiles: 5th, 50th, 95th)
#     units: degC
# unlimited dimensions:
# current shape = (3, 24000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Nino_4_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_4_mn(tmon)
#     long_name: Nino 4 (reconstruction mean)
#     units: degC
# unlimited dimensions:
# current shape = (24000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Nino_4_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_4_sg(tmon)
#     long_name: Nino 4 (1 standard deviation of ensemble)
#     units: degC
# unlimited dimensions:
# current shape = (24000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Nino_4_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 Nino_4_pc(prctl, tmon)
#     long_name: Nino 4 (ensemble percentiles: 5th, 50th, 95th)
#     units: degC
# unlimited dimensions:
# current shape = (3, 24000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'PacDelSST_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 PacDelSST_mn(tmon)
#     long_name: Pacific del SST west minus east (reconstruction mean)
#     units: degC
# unlimited dimensions:
# current shape = (24000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'PacDelSST_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 PacDelSST_sg(tmon)
#     long_name: Pacific del SST west minus east (1 standard deviation of ensemble)
#     units: degC
# unlimited dimensions:
# current shape = (24000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'PacDelSST_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 PacDelSST_pc(prctl, tmon)
#     long_name: Pacific del SST west minus east (ensemble percentiles: 5th, 50th, 95th)
#     units: degC
# unlimited dimensions:
# current shape = (3, 24000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Atl_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 Atl_mn(time)
#     long_name: ITCZ Atlantic (reconstruction mean)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Atl_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 Atl_sg(time)
#     long_name: ITCZ Atlantic (1 standard deviation of ensemble)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Atl_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 Atl_pc(prctl, time)
#     long_name: ITCZ Atlantic (ensemble percentiles: 5th, 50th, 95th)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Pac130_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 Pac130_mn(time)
#     long_name: ITCZ Pacific (reconstruction mean)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Pac130_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 Pac130_sg(time)
#     long_name: ITCZ Pacific (1 standard deviation of ensemble)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Pac130_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 Pac130_pc(prctl, time)
#     long_name: ITCZ Pacific (ensemble percentiles: 5th, 50th, 95th)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Pac160_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 Pac160_mn(time)
#     long_name: ITCZ Pacific (Schneider 2014) (reconstruction mean)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Pac160_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 Pac160_sg(time)
#     long_name: ITCZ Pacific (Schneider 2014) (1 standard deviation of ensemble)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Pac160_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 Pac160_pc(prctl, time)
#     long_name: ITCZ Pacific (Schneider 2014) (ensemble percentiles: 5th, 50th, 95th)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'EPac_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 EPac_mn(time)
#     long_name: ITCZ East Pacific (reconstruction mean)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'EPac_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 EPac_sg(time)
#     long_name: ITCZ East Pacific (1 standard deviation of ensemble)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'EPac_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 EPac_pc(prctl, time)
#     long_name: ITCZ East Pacific (ensemble percentiles: 5th, 50th, 95th)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'WPac_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 WPac_mn(time)
#     long_name: ITCZ West Pacific (reconstruction mean)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'WPac_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 WPac_sg(time)
#     long_name: ITCZ West Pacific (1 standard deviation of ensemble)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'WPac_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 WPac_pc(prctl, time)
#     long_name: ITCZ West Pacific (ensemble percentiles: 5th, 50th, 95th)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'SAsia_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 SAsia_mn(time)
#     long_name: ITCZ South Asian Monsoon (Schneider 2014) (reconstruction mean)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'SAsia_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 SAsia_sg(time)
#     long_name: ITCZ South Asian Monsoon (Schneider 2014) (1 standard deviation of ensemble)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'SAsia_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 SAsia_pc(prctl, time)
#     long_name: ITCZ South Asian Monsoon (Schneider 2014) (ensemble percentiles: 5th, 50th, 95th)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'IndOcn_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 IndOcn_mn(time)
#     long_name: ITCZ Indian (reconstruction mean)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'IndOcn_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 IndOcn_sg(time)
#     long_name: ITCZ Indian (1 standard deviation of ensemble)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'IndOcn_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 IndOcn_pc(prctl, time)
#     long_name: ITCZ Indian (ensemble percentiles: 5th, 50th, 95th)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'SAmer_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 SAmer_mn(time)
#     long_name: ITCZ South America (reconstruction mean)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'SAmer_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 SAmer_sg(time)
#     long_name: ITCZ South America (1 standard deviation of ensemble)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'SAmer_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 SAmer_pc(prctl, time)
#     long_name: ITCZ South America (ensemble percentiles: 5th, 50th, 95th)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Ind_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 Ind_mn(time)
#     long_name: ITCZ Indonesia (reconstruction mean)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Ind_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 Ind_sg(time)
#     long_name: ITCZ Indonesia (1 standard deviation of ensemble)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Ind_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 Ind_pc(prctl, time)
#     long_name: ITCZ Indonesia (ensemble percentiles: 5th, 50th, 95th)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Afr_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 Afr_mn(time)
#     long_name: ITCZ Africa (reconstruction mean)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Afr_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 Afr_sg(time)
#     long_name: ITCZ Africa (1 standard deviation of ensemble)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'Afr_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 Afr_pc(prctl, time)
#     long_name: ITCZ Africa (ensemble percentiles: 5th, 50th, 95th)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'EAfr_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 EAfr_mn(time)
#     long_name: ITCZ East Africa (reconstruction mean)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'EAfr_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 EAfr_sg(time)
#     long_name: ITCZ East Africa (1 standard deviation of ensemble)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'EAfr_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 EAfr_pc(prctl, time)
#     long_name: ITCZ East Africa (ensemble percentiles: 5th, 50th, 95th)
#     units: lat (deg)
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'gmt_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 gmt_mn(time)
#     long_name: global mean 2 m temperature (reconstruction mean)
#     units: degC
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'gmt_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 gmt_sg(time)
#     long_name: global mean 2 m temperature (1 standard deviation of ensemble)
#     units: degC
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'gmt_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 gmt_pc(prctl, time)
#     long_name: global mean 2 m temperature (ensemble percentiles: 5th, 50th, 95th)
#     units: degC
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'amo_mn': <class 'netCDF4._netCDF4.Variable'>
# float64 amo_mn(time)
#     long_name: AMO (NASST index) (reconstruction mean)
#     units: degC
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'amo_sg': <class 'netCDF4._netCDF4.Variable'>
# float64 amo_sg(time)
#     long_name: AMO (NASST index) (1 standard deviation of ensemble)
#     units: degC
# unlimited dimensions:
# current shape = (2000,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'amo_pc': <class 'netCDF4._netCDF4.Variable'>
# float64 amo_pc(prctl, time)
#     long_name: AMO (NASST index) (ensemble percentiles: 5th, 50th, 95th)
#     units: degC
# unlimited dimensions:
# current shape = (3, 2000)
# filling on, default _FillValue of 9.969209968386869e+36 used}
